# %% [markdown]
# ## Analysis about keyword: "애플페이"

# %%
import json
from typing import Dict
import orjson

from utils import DATA_DIR

with (DATA_DIR / "OpenAI.json").open() as f:
    statuses = json.loads(f.read())

# %%
tweet_created = [
    status["created_at"]
    for status in statuses
]

# %%
print(f"데이터에서 가장 오래된 트윗: \t{min(tweet_created)}")
print(f"데이터에서 가장 최근 트윗: \t{max(tweet_created)}")
# Out:
# 데이터에서 가장 오래된 트윗: 	Wed Mar 15 14:47:00 +0000 2023
# 데이터에서 가장 최근 트윗: 	Wed Mar 15 15:14:55 +0000 2023

# %%
user_created = [
    status["user"]["created_at"]
    for status in statuses
]

# %%
print(f"트윗 작성자 중 가장 오래된 계정 생성 날짜: \t{min(tweet_created)}")
print(f"트윗 작성자 중 가장 최근 계정 생성 날짜: \t{max(tweet_created)}")
# Out:
# 트윗 작성자 중 가장 오래된 계정 생성 날짜: 	Wed Mar 15 14:47:00 +0000 2023
# 트윗 작성자 중 가장 최근 계정 생성 날짜: 	Wed Mar 15 15:14:55 +0000 2023

# %%
how_many_tweets_by_the_user = [
    status["user"]["statuses_count"]
    for status in statuses
]

# %%
how_many_followers_by_the_user = [
    status["user"]["followers_count"]
    for status in statuses
]

# %%
import pandas as pd
df = pd.DataFrame([
    tweet_created,
    user_created,
    how_many_tweets_by_the_user,
    how_many_followers_by_the_user
]).transpose()

df.columns = ["tweet_created", "user_created", "tweets_from_user", "followers_from_user"]
df["tweet_created"] = pd.to_datetime(df["tweet_created"])
df["user_created"] = pd.to_datetime(df["user_created"])
df["tweets_from_user"] = pd.to_numeric(df["tweets_from_user"])
df["followers_from_user"] = pd.to_numeric(df["followers_from_user"])

# %%
df
# Out:
#                  tweet_created              user_created  tweets_from_user  \
# 0    2023-03-15 15:14:55+00:00 2016-05-31 14:45:06+00:00             97553
# 1    2023-03-15 15:14:52+00:00 2017-01-26 15:25:26+00:00            466400
# 2    2023-03-15 15:14:50+00:00 2021-10-03 02:18:33+00:00               770
# 3    2023-03-15 15:14:48+00:00 2022-08-03 21:47:21+00:00              1475
# 4    2023-03-15 15:14:48+00:00 2009-06-26 00:07:38+00:00              8563
# ...                        ...                       ...               ...
# 1078 2023-03-15 14:47:13+00:00 2018-12-23 00:04:27+00:00              7844
# 1079 2023-03-15 14:47:12+00:00 2022-10-22 18:34:31+00:00                78
# 1080 2023-03-15 14:47:00+00:00 2023-03-03 07:24:50+00:00                61
# 1081 2023-03-15 14:47:00+00:00 2013-05-15 01:15:34+00:00              3768
# 1082 2023-03-15 14:47:00+00:00 2022-10-28 17:00:47+00:00              1229
#
#       followers_from_user
# 0                     291
# 1                    3806
# 2                      33
# 3                       3
# 4                     130
# ...                   ...
# 1078                 4052
# 1079                   28
# 1080                    0
# 1081                  144
# 1082                   26
#
# [1083 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1083 entries, 0 to 1082
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   tweet_created        1083 non-null   datetime64[ns, UTC]
#  1   user_created         1083 non-null   datetime64[ns, UTC]
#  2   tweets_from_user     1083 non-null   int64
#  3   followers_from_user  1083 non-null   int64
# dtypes: datetime64[ns, UTC](2), int64(2)
# memory usage: 34.0 KB

# %%
df.describe()
# Out:
#        tweets_from_user  followers_from_user
# count      1.083000e+03         1.083000e+03
# mean       4.571604e+04         3.206837e+04
# std        1.791334e+05         3.786853e+05
# min        1.000000e+00         0.000000e+00
# 25%        6.365000e+02         7.300000e+01
# 50%        4.755000e+03         3.450000e+02
# 75%        2.529350e+04         1.715000e+03
# max        3.913302e+06         9.202692e+06

# %% [markdown]
# * 사용자가 작성한 트윗
#     * 평균: 4만 5716개
#     * 중앙값: 4만 7550개
#     * 최대: 약 390만개
# * 사용자의 팔로워 수
#     * 평균: 3만 2000 여 명
#     * 중앙값: 345 명
#     * 최대: 920만 명
#     * 최소: 0 명
#
# 사용자의 팔로워 수에서 최대값이 매우 크고, 중앙값이 작은 거로 보아 평균의 오류가 발생하고 있는 데이터라고 볼수 있다.
# 그러면 920만명의 팔로워를 가진 사람은 누구일까.

# %%
list(filter(
    lambda row: row["user"]["followers_count"] > 9200000,
    statuses
))[0]["user"]
# Out:
# {'id': 34713362,
#  'id_str': '34713362',
#  'name': 'Bloomberg',
#  'screen_name': 'business',
#  'location': 'New York and the World',
#  'description': 'The first word in business news. Newsletters: https://t.co/nWaCxHSKuU Podcasts: https://t.co/096e9xMbPz The Big Take podcast: https://t.co/UqskwXtp5Z',
#  'url': 'https://t.co/MdLRpsrsk5',
#  'entities': {'url': {'urls': [{'url': 'https://t.co/MdLRpsrsk5',
#      'expanded_url': 'https://www.bloomberg.com/account/newsletters/politics',
#      'display_url': 'bloomberg.com/account/newsle…',
#      'indices': [0, 23]}]},
#   'description': {'urls': [{'url': 'https://t.co/nWaCxHSKuU',
#      'expanded_url': 'http://bloom.bg/newsletters',
#      'display_url': 'bloom.bg/newsletters',
#      'indices': [46, 69]},
#     {'url': 'https://t.co/096e9xMbPz',
#      'expanded_url': 'http://bloom.bg/podcasts',
#      'display_url': 'bloom.bg/podcasts',
#      'indices': [80, 103]},
#     {'url': 'https://t.co/UqskwXtp5Z',
#      'expanded_url': 'http://trib.al/jtoXfuT',
#      'display_url': 'trib.al/jtoXfuT',
#      'indices': [126, 149]}]}},
#  'protected': False,
#  'followers_count': 9202692,
#  'friends_count': 1474,
#  'listed_count': 70256,
#  'created_at': 'Thu Apr 23 20:05:17 +0000 2009',
#  'favourites_count': 3792,
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': True,
#  'verified': True,
#  'statuses_count': 911992,
#  'lang': None,
#  'contributors_enabled': False,
#  'is_translator': False,
#  'is_translation_enabled': True,
#  'profile_background_color': '101112',
#  'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#  'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#  'profile_background_tile': True,
#  'profile_image_url': 'http://pbs.twimg.com/profile_images/1631723279676317709/-fjgaR2p_normal.jpg',
#  'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1631723279676317709/-fjgaR2p_normal.jpg',
#  'profile_banner_url': 'https://pbs.twimg.com/profile_banners/34713362/1677719259',
#  'profile_link_color': '3B94D9',
#  'profile_sidebar_border_color': 'DADADA',
#  'profile_sidebar_fill_color': 'EEEEEE',
#  'profile_text_color': '666666',
#  'profile_use_background_image': True,
#  'has_extended_profile': False,
#  'default_profile': False,
#  'default_profile_image': False,
#  'following': False,
#  'follow_request_sent': False,
#  'notifications': False,
#  'translator_type': 'none',
#  'withheld_in_countries': []}

# %% [markdown]
# Bloomberg 공식 계정 이었다. 블룸버그의 뉴스레터니... 많을 수 밖에
# 팔로워 수가 많을 수 밖에 없었다.

# %% [markdown]
# 가장 많이 나오는 hashtag는?

# %%
from functools import reduce

hashtags = [
    record['text']
    for record in
    list(reduce(
        lambda i, j: i+j,
        [status["entities"]["hashtags"] for status in statuses]
    ))
]

# %%
from collections import Counter

sorted(Counter(hashtags).items(), key=lambda i: i[1], reverse=True)
# Out:
# [('OpenAI', 35),
#  ('GPT4', 34),
#  ('ChatGPT', 33),
#  ('AI', 22),
#  ('gpt4', 15),
#  ('Web3', 14),
#  ('openai', 14),
#  ('chatgpt4', 8),
#  ('Microsoft', 6),
#  ('GPT', 6),
#  ('chatgpt', 5),
#  ('nowai', 5),
#  ('aiart', 4),
#  ('OpenAi', 4),
#  ('Ai', 4),
#  ('Bing', 3),
#  ('ArtificialIntelligence', 3),
#  ('ai', 3),
#  ('openAI', 3),
#  ('digitalhealth', 3),
#  ('CyberChess', 2),
#  ('Chatbots', 2),
#  ('ChatPBT', 2),
#  ('FutureOfWork', 2),
#  ('BingAI', 2),
#  ('selfelaketi', 2),
#  ('lluvias', 2),
#  ('MAFSAU', 2),
#  ('CreditSuisse', 2),
#  ('ImranKhan', 2),
#  ('kibe', 2),
#  ('JUNGKOOK', 2),
#  ('Pakistan', 2),
#  ('nowaiart', 2),
#  ('chatbot', 2),
#  ('contentwriter', 2),
#  ('innovation', 2),
#  ('programming', 2),
#  ('SXSW2023', 2),
#  ('GPT3', 2),
#  ('Tecnologia', 1),
#  ('chatsing', 1),
#  ('bankcollapse', 1),
#  ('gpt5', 1),
#  ('analytics', 1),
#  ('googleads', 1),
#  ('facebookads', 1),
#  ('InteligenciaArtificial', 1),
#  ('NewsPicks', 1),
#  ('WEEKLYOCHIAI', 1),
#  ('techies', 1),
#  ('TechNews', 1),
#  ('GPT_4', 1),
#  ('WorkoutApp', 1),
#  ('Trending', 1),
#  ('ML', 1),
#  ('Stripe', 1),
#  ('Financialverse', 1),
#  ('IntelligenzaArtificiale', 1),
#  ('هوش_مصنوعی', 1),
#  ('OpenIA', 1),
#  ('TensorFlow', 1),
#  ('Fintech', 1),
#  ('TDX23', 1),
#  ('Gpt', 1),
#  ('NouveauBing', 1),
#  ('4thGen', 1),
#  ('KPop', 1),
#  ('enigma', 1),
#  ('languagemodels', 1),
#  ('gpt', 1),
#  ('Hired', 1),
#  ('Unwitting', 1),
#  ('MyCOZMeme', 1),
#  ('IMGNAI', 1),
#  ('chatgpt3', 1),
#  ('Openai', 1),
#  ('Adept', 1),
#  ('images', 1),
#  ('flappyBird', 1),
#  ('trendingtech', 1),
#  ('TrendingNow', 1),
#  ('TrendingNews', 1),
#  ('trendingtechnology', 1),
#  ('technews', 1),
#  ('malware', 1),
#  ('midjourney', 1),
#  ('stablediffusion', 1),
#  ('ポエム', 1),
#  ('詩', 1),
#  ('crypto', 1),
#  ('nft', 1),
#  ('newslab', 1),
#  ('最新記事', 1),
#  ('trending', 1),
#  ('technology', 1),
#  ('chatGPT', 1),
#  ('TudoCelular', 1),
#  ('Notícias', 1),
#  ('SmartNews', 1),
#  ('MCTech3', 1),
#  ('tech', 1),
#  ('startup', 1),
#  ('TikTok', 1),
#  ('DoomsdayPrepper', 1),
#  ('coding', 1),
#  ('Claude', 1),
#  ('คริปโตแมนเบสิค', 1),
#  ('vtuber', 1),
#  ('RT', 1),
#  ('UKHotViews', 1),
#  ('cloudservices', 1),
#  ('takeovers', 1),
#  ('bot', 1),
#  ('MasterSales', 1),
#  ('Podcast', 1),
#  ('imagine_sysme', 1),
#  ('Ethics', 1),
#  ('Technology', 1),
#  ('ChatGPT3', 1),
#  ('CHATGPT4', 1),
#  ('OPENAI', 1),
#  ('AIWRITINGTOOL', 1),
#  ('INNOVATION', 1),
#  ('FOLIO3', 1),
#  ('news', 1),
#  ('breakingnews', 1),
#  ('reliance', 1),
#  ('metrocashandcarry', 1),
#  ('PureITTechInsights', 1),
#  ('opensource', 1),
#  ('generativeAI', 1),
#  ('仮想通貨', 1),
#  ('人工知能', 1),
#  ('くりぷと研究所', 1)]

# %% [markdown]
# 가장 많이 나온 해쉬태그는 예상대로
# 'OpenAI', 'GPT4', 'ChatGPT' 순 이었다.
# 키워드 제출하는 날 (03/15)에 이미 gpt4 가 publish되었기 때문에 유명세를 타지 않았을까?

# %% [markdown]
# 가장 연관이 많은 빈출 단어는?

# %%
from functools import reduce

contents = [
    status["text"]
    for status in statuses
]

# %%
contents
# Out:
# ['RT @StabilityAI_JP: オープンソースの流れ\n・ChatGLM-6Bという中国語特化のオープンソースが出現\n・スタンフォード大学がGPT-3.5並みの性能を誇るALpaca7Bを開発、発表\n・OpenChatKitと呼ばれる本当にオープンなLLMを作るセットが元…',
#  '#Tecnologia #OpenAI anunció su última versión de #ChatGPT con mayor precisión y creatividad. https://t.co/8L7G3d9qf4 https://t.co/aMZa8QtEgc',
#  "Ekibimizden Sarper Kaçar'ın paylaşımının ayrıntıları ve daha fazla haber https://t.co/jrKbm2mMiy'da.… https://t.co/VGO7bpEdxl",
#  'OpenAI, its GPT-4\xa0chatbot https://t.co/5mZyCYIs13',
#  'RT @CerfiaFR: 🚨🤖 FLASH | #OpenAI, maison mère de #ChatGPT, a annoncé la sortie de GPT-4, une version qui surpasse les capacités actuelles d…',
#  'OpenAI, its GPT-4\xa0chatbot https://t.co/hGHKTutN72',
#  'RT @StabilityAI_JP: GPT-4発表\nOpenAIよりGPT-4が発表された https://t.co/PHEVaofPUJ (1/5) https://t.co/kbcJChsROf',
#  'RT @profoundlyyyy: You get a Twitter notification saying OpenAI released GPT-4 and look outside your window and see this…wyd? https://t.co/…',
#  'RT @benmschmidt: Neural networks like GPT-4 are notoriously black boxes; the fact that their operations are unpredictable and inscrutable i…',
#  '@soumithchintala @OpenAI Placing the burden on everyone else to reproduce the unreproducible is the wrong model.',
#  'RT @benmschmidt: Choices of training data reflects historic biases and can inflict all sorts of harms. To ameliorate those harms, and to ma…',
#  "RT @The_Delysium: @OpenAI Speaking of breakthroughs - here's the biggest one in #Web3  https://t.co/bi3OoAX4KE",
#  '#chatsing learning to become a financial services expert. Opinions on the #bankcollapse.\n\nhttps://t.co/CbWROwTHeS… https://t.co/wYTD1aBcMl',
#  'RT @OpenAI: Announcing GPT-4, a large multimodal model, with our best-ever results on capabilities and alignment: https://t.co/TwLFssyALF h…',
#  'RT @OpenAI: Announcing GPT-4, a large multimodal model, with our best-ever results on capabilities and alignment: https://t.co/TwLFssyALF h…',
#  'RT @notkevinhurler: OpenAI unveiled its GPT-4 chatbot yesterday, and also revealed in a technical paper that the AI successfully tricked a…',
#  "RT @jphilipp: Humanity's Last Tweet.\n#aiart #chatgpt #gpt4 #gpt5 #openai https://t.co/gemfToucjh",
#  'RT @notkevinhurler: OpenAI unveiled its GPT-4 chatbot yesterday, and also revealed in a technical paper that the AI successfully tricked a…',
#  'Hot take on day one:\n\nIndian firms are eyeing OpenAI’s GPT-4 as a bigger opportunity than its previous iteration th… https://t.co/xU9wPpWxew',
#  'Founder &amp; CEO of @OpenAI (ChatGPT) https://t.co/sIuMRZremG',
#  'RT @Saboo_Shubham_: Breaking 🚨\n\nOpenAI just dropped GPT-4 and it can literally blow your mind 🤯\n\nGPT-4 is a large multimodal model that can…',
#  'RT @L_ThinkTank: [ 🖥️ TECH ]\n\n🔸 OpenAI annonce le lancement de GPT-4, son modèle de langage le plus avancé à ce jour. Entre autres, il perm…',
#  'RT @mhatta: オープンソースはサヨクとか言う人いるけど、どちらかというと最近の状況はAmazonとかOpenAIとかの地主さまに地代払って小作人やっとるデジタル封建主義やで。農奴ならぬコー奴だ',
#  'OpenAI releases latest version of its star LLM: GPT-4 : #analytics #googleads #facebookads https://t.co/GLGBvmaDtW',
#  '#chatgpt4 \n#openai\n#InteligenciaArtificial \n\nhttps://t.co/LLndRVjrp3',
#  'RT @OpenAI: Announcing GPT-4, a large multimodal model, with our best-ever results on capabilities and alignment: https://t.co/TwLFssyALF h…',
#  "RT @thealexbanks: OpenAI just launched GPT-4.\n\nIt leaves ChatGPT in the dust.\n\nHere's everything you need to know: https://t.co/Oc6TrygvNO",
#  "Evet anladık. ChatGPT 4 iyi hatta çok iyi her şeye cevap veriyor. Arkadaşlar şaka mısınız niye chatGPT'ye şunu dedi… https://t.co/z48n3qfXqZ",
#  'Duolingo MAXはもうある程度の動的な暗示的学習支援とFocusOnForm的な文法指導ができるようになってるという触れ込みなのね。これが音声での会話とも統合されるならなかなかすごいね。 https://t.co/FPCzW36x1I',
#  'RT @Saboo_Shubham_: Breaking 🚨\n\nOpenAI just dropped GPT-4 and it can literally blow your mind 🤯\n\nGPT-4 is a large multimodal model that can…',
#  'Además de todas las mejoras en las respuestas, lo llamativo en esta versión es que puedes incluir imágenes dentro d… https://t.co/DYil0vl4zT',
#  '落合さんとOpenAIの中の人ことシェインさんの対談\nこれを日本語で聞けるのが貴重すぎるし科学好きにはワクワクしかない\n\n生成AI「ChatGPT」と日本の新たな可能性 #NewsPicks #WEEKLYOCHIAI https://t.co/3UC9QB6rOC',
#  'RT @bentossell: All the best examples of GPT-4, from OpenAI:',
#  'RT @PhMai: This about sums it up: "AI systems will have even greater potential to reinforce entire ideologies, worldviews, truths and untru…',
#  'GPT-4 di OpenAI in 10 punti https://t.co/eSVsZPl5Mq',
#  '@jsngr @OpenAI @diagram \U0001f90c\U0001fae1',
#  'https://t.co/Z5u4bwuaFL',
#  "@NaveenGRao @soumithchintala @OpenAI &gt; They are a company developing a product.\nThat's the issue people have. It is… https://t.co/l2sjgBMUUS",
#  'JUST IN: @stripe partners up with @OpenAI to enhance their documentation: GPT-powered Stripe Docs.\n\nI believe this… https://t.co/IyBiGVeOCD',
#  'RT @binary_x: My friends: #GPT4\nMe: 🔥#CyberChess Season 4! \n\n$BNX #CyberChess#ChatGPT @OpenAI https://t.co/UYaStWc5Xz',
#  '@we_arent_here @Grady_Booch @OpenAI But to expect GPT to evolve it or grow into it by becoming bigger and more comp… https://t.co/v0nuLMGHq0',
#  'RT @wintonARK: OpenAI announces GPT-4 here:\n\nhttps://t.co/VC0uzlQbox\n\nPerformance on human-benchmarks is rather remarkable.\n\nGPT-3.5 scored…',
#  '#GPT4\nhttps://t.co/oaDYdpGU1D]',
#  'RT @BTC_Chopsticks: ChatGPT 升级！@OpenAI 推出GPT-4，准确性提高。\n#OpenAI #Microsoft #Chatbots, #ChatPBT #GPT #AI #FutureOfWork\nhttps://t.co/XezRSm0tNX',
#  'Reminder also that @OpenAI have no intention of ever voluntarily revealing their training data https://t.co/R9lzQvXcB3',
#  'This is massive\n\nGPT-4 is here 🔥 \n#techies #TechNews #AI https://t.co/k7k8LUy6sK',
#  'GPT-4、OpenAIの急浮上、残された独占的な人間のスキルは多くない https://t.co/EgiF3TjBnt',
#  'RT @karpathy: 🎉 GPT-4 is out!!\n- 📈 it is incredible\n- 👀 it is multimodal (can see) \n- 😮 it is on trend w.r.t. scaling laws\n- 🔥 it is deploy…',
#  '@The_Delysium @OpenAI asda',
#  'RT @shanegJP: #GPT4 出た\nhttps://t.co/6Lw2ysBZWC\n\n1. 言語と画像のマルチモーダル大規模言語モデル：「写真で一言」説明できます。論文も写真でOK。 https://t.co/h8mFbUZp2b',
#  '@AlisambaYerodia @OpenAI à officialiser sa version 4 #GPT_4 et c’est génial au point d’être effrayant\n\nTous les géa… https://t.co/bCvPwHdAwo',
#  "RT @The_Delysium: @OpenAI Speaking of breakthroughs - here's the biggest one in #Web3  https://t.co/bi3OoAX4KE",
#  'RT @tdietterich: @soumithchintala @OpenAI @MetaAI @Stanford @StabilityAI @huggingface I don’t think people are “mad”. It’s the hypocrisy of…',
#  'RT @river_leaves: 在大语言模型、GPT这件事情上，发明这种方法的是Google，发扬光大让路人皆知的是OpenAI（微软），将优化后的大模型开源出来的是Meta……妥妥的硅谷御三家啊。如果不清楚背后的来龙去脉，这看起来像是一种协同创新，但实际上这是互相竞争的结…',
#  '@Scinfinity OpenAIのやつは月20ドルお金払うと使えますよー\nhttps://t.co/xrypaxkKqG\nBingのやつは何なんでしょうね。。3.5なのか4なのか。。',
#  'RT @OpenAI: Announcing GPT-4, a large multimodal model, with our best-ever results on capabilities and alignment: https://t.co/TwLFssyALF h…',
#  'OpenAI is revolutionizing the field of artificial intelligence with cutting-edge research &amp; development. From langu… https://t.co/gwoWMnF7g2',
#  'RT @OpenAI: Announcing GPT-4, a large multimodal model, with our best-ever results on capabilities and alignment: https://t.co/TwLFssyALF h…',
#  'RT @Grady_Booch: While #GPT4 exhibits some impressive skills, remember that without the largely bespoke, human-crafted guardrails placed ar…',
#  'RT @notkevinhurler: OpenAI unveiled its GPT-4 chatbot yesterday, and also revealed in a technical paper that the AI successfully tricked a…',
#  "ChatGPT-4, de @OpenAI, a réussi l'examen du barreau avec un score supérieur à 90\xa0% des candidats.\n\nI love where this is going.",
#  'RT @blairasaservice: MSFT responsible AI layoffs &amp; OpenAI refusing to disclose details about GPT-4 model architecture &amp; training is a clear…',
#  'OpenAPI 信用卡绑定拦住了不少人，遂用Cloudflare Worker写了个OpenAI API代理服务给团队同学玩，一人一 key. 由于KV每天免费写入1000次的限制太大，暂时不做用量统计 https://t.co/MPPvUwuv6m',
#  'RT @khanacademy: Did you hear? 👀 Khan Academy is using GPT-4 from @OpenAI to shape the future of learning.\n\nStarting today, you can sign up…',
#  'Life…🚀 https://t.co/AXF6PXqqTa',
#  "Hey #WorkoutApp Team! \n\nLet's play a game ♟️Can you guess how many calories you can burn during a one-hour CrossFit… https://t.co/5k20dr5EBc",
#  'RT @OpenAI: Announcing GPT-4, a large multimodal model, with our best-ever results on capabilities and alignment: https://t.co/TwLFssyALF h…',
#  'RT @CerfiaFR: 🚨🤖 FLASH | #OpenAI, maison mère de #ChatGPT, a annoncé la sortie de GPT-4, une version qui surpasse les capacités actuelles d…',
#  'RT @sam_starkman: Several companies and organizations have already partnered with OpenAI and are implementing GPT-4 into their products.\n\nT…',
#  "RT @MushtaqBilalPhD: OpenAI recently launched an advanced version of ChatGPT's \u2060— GPT-4.\n\nHere's what it's capable of: https://t.co/OfDI9cf…",
#  'The company unveiled new technology called GPT-4 four months after its ChatGPT stunned Silicon Valley. The update i… https://t.co/HX4eshsava',
#  '@maniagnosis @Chumpychange1 @DrJimFan And that\'s the thing, OpenAI and other places are throwing "sounds impressive… https://t.co/5pg8FiDuuG',
#  "RT @AK33Astrology: Here's a Secret:\n\nOpenAI (ChatGPT) has been leading the AI revolution\n\nBut why has OpenAI surpassed other prominent AI c…",
#  'RT @_akhaliq: GPT-4 Technical Report\n\npdf: https://t.co/4T8PQZicvg\nblog: https://t.co/nCIuKBsj4G https://t.co/lP9FHzySs0',
#  '我想注册OpenAI账号，但想想对现在的我说没有必要，一些生活里面遇到的问题我直接通过国内的api接口问就行了',
#  'RT @TechInsider: OpenAI is now rumored to be valued at $30 billion and has wasted no time in commercializing its technology — @_hasanc argu…',
#  "RT @GergelyOrosz: The way OpenAI is building excitement across devs is something I've not seen in a long time. A lot of this is deliberate,…",
#  'RT @sama: here is GPT-4, our most capable and aligned model yet. it is available today in our API (with a waitlist) and in ChatGPT+.\n\nhttps…',
#  'RT @emollick: Many people complain about the limits put on these new AI systems\n\nI think everyone should read the risk mitigation section i…',
#  'RT @jilevin: The makers of ChatGPT just released a new AI that can build websites via voxdotcom https://t.co/otvMN7I4Z6',
#  '#Trending Microsoft Reportedly Plans to Unveil OpenAI-Powered Office ... - https://t.co/xGc2ilqc8T\n\n#AI #GPT #ML\n\nR… https://t.co/VfINnKYFsL',
#  "Fintech startup #Stripe integrating #OpenAI's new GPT-4 AI\n\nThe first offering will be a way for Stripe's software… https://t.co/yZ0BGzSWsp",
#  'IMO, @OpenAI Evals is likely the most important part of the #gpt4 announcement...\n\nConsistent, rigorous benchmarks… https://t.co/9pHRcCRtgz',
#  'RT @Yamkaz: 複数の言語モデルを1つのプラットフォームで使える\n「Poe」がサブスク開始！\nhttps://t.co/bqC5aQ8dbS\n\nなんとサブスク登録すればOpenAIの「GPT-4」、Anthropicの「Claude+」が使える https://t.co…',
#  'OpenAI lança novo GPT-4 para seu chatbot ChatGP. A empresa é apoada pela Microsoft https://t.co/cXNpBqdUQO https://t.co/fsFQFfAq1v',
#  '@soumithchintala @OpenAI I think we missing the interesting underlying trend: AI is getting much less cooperative.… https://t.co/F4wjrTj76n',
#  "@we_arent_here @Grady_Booch @OpenAI That doesn't mean another system can't be built to cooperate with and complemen… https://t.co/tJWoCouuKl",
#  "RT @thealexbanks: OpenAI just launched GPT-4.\n\nIt leaves ChatGPT in the dust.\n\nHere's everything you need to know: https://t.co/Oc6TrygvNO",
#  'RT @sam_starkman: OpenAI released its long-awaited GPT-4 model yesterday.\n\nHere are 4 key points you need to know:',
#  '#OpenAI ha rilasciato la nuova versione di #ChatGPT #Financialverse #IntelligenzaArtificiale \nhttps://t.co/rSsszNlHWp',
#  'RT @marianorenteria: Google y OpenAI hoy… https://t.co/fljLYdP76l',
#  '@graninas @OpenAI Behold the new D&amp;D master!!! Sorry, was excited. Gonna to to try create some game script.',
#  "RT @StockMKTNewz: OpenAI's new ChatGPT-4 passed the bar exam with a score around the top 10% of test takers compared to GPT-3.5 being aroun…",
#  'RT @OpenAI: Announcing GPT-4, a large multimodal model, with our best-ever results on capabilities and alignment: https://t.co/TwLFssyALF h…',
#  'RT @kana_Eng_coach: 世界一人気の語学アプリDuolingoが、OpenAI社のGPT-4を搭載したDuolingo Maxを公開。Maxは会話の練習相手で、間違えた時は話し手がなぜその文章で話したかまで理解して、解説をくれるという優れもの。AIによって世界中…',
#  'RT @OpenAI: Announcing GPT-4, a large multimodal model, with our best-ever results on capabilities and alignment: https://t.co/TwLFssyALF h…',
#  "RT @rowancheung: It's here. OpenAI just launched GPT-4.\n\nAnd it's incredible:\n\n-It can accept image and text inputs, and emit text outputs.…",
#  'GPT-4: La nueva era de la inteligencia artificial llega con OpenAI\nhttps://t.co/uv4NaB6rYP',
#  'RT @khanacademy: Did you hear? 👀 Khan Academy is using GPT-4 from @OpenAI to shape the future of learning.\n\nStarting today, you can sign up…',
#  "OpenAI releases GPT-4, artificial intelligence that can 'see' and do taxes\n https://t.co/bat4Nzz50q",
#  'ثبت نام برای ChatGPT 4\n\n👇\nhttps://t.co/9Pj5XjWECI\n\n#ChatGPT\n#هوش_مصنوعی',
#  'Here’s How OpenAI’s GPT-4 Is More Advanced Than Its Predecessor https://t.co/QwltoWpmPe',
#  'RT @BoruG_: I’m thrilled to share that I was part of the Red Team for GPT-4, the latest innovation from OpenAI. When I tested this model, I…',
#  "@soumithchintala @OpenAI Only if they'd agree to call themselves NotOpenAI.\n\n@sama",
#  'RT @BeautyBubble: #ChatGPT \n#OpenAi \n#Ai \nOne of the pillars of Market Soup, LLC is art ... lots &amp;  lots of art!  DALL·E 2 is our preferred…',
#  'Built a dynamic vuejs futures trading calculator with ChatGPT4 flowing into a affiliate offer this morning 🎉… https://t.co/2V2J96S5sy',
#  '#OpenIA  #ChatGPT #chatgpt4\n\nhttps://t.co/aJGVxgCik9',
#  'RT @TechCrunch: It turns out Microsoft’s new #AI-enabled Bing was using OpenAI’s GPT-4 all along https://t.co/M4Tkw65qSo',
#  'RT @OpenAI: Announcing GPT-4, a large multimodal model, with our best-ever results on capabilities and alignment: https://t.co/TwLFssyALF h…',
#  'RT @AiBreakfast: Duolingo partners with OpenAI \n\nNew AI powered features: Role Play, an AI conversation partner, and Explain my Answer, whi…',
#  '@jonrross @OpenAI So cool man!!\nKeep trying and keep sharing.',
#  "Some people had noticed that #ChatGPT on #Bing was better than using #OpenAI 's website or API... well, that was co… https://t.co/x8naEV6voD",
#  'RT @BeautyBubble: #ChatGPT \n#OpenAi \n#Ai \nOne of the pillars of Market Soup, LLC is art ... lots &amp;  lots of art!  DALL·E 2 is our preferred…',
#  'RT @stripe: OpenAI + Stripe: https://t.co/lToKb1sQXp. https://t.co/MwKn0CvWbu',
#  'RT @OpenAI: Announcing GPT-4, a large multimodal model, with our best-ever results on capabilities and alignment: https://t.co/TwLFssyALF h…',
#  'RT @dotey: 朋友在写prompt，想让ChatGPT帮忙按照要求格式输出，老是不对，于是我帮他改了一下，成了\n\nBTW: OpenAI的PlayGround用来调试prompt很方便的\nhttps://t.co/tvROdhz0I7 https://t.co/luFn…',
#  'OpenAIに課金',
#  'RT @BeautyBubble: #ChatGPT \n#OpenAi \n#Ai \nOne of the pillars of Market Soup, LLC is art ... lots &amp;  lots of art!  DALL·E 2 is our preferred…',
#  'My Review of #chatgpt4 \n#AI #TensorFlow #openai\n#BingAI #ChatGPT #ArtificialIntelligence\n#Microsoft https://t.co/jqNXiRS9Pw',
#  "RT @themathcompany: TheMathCompany just integrated its Co.dx platform with OpenAI's ChatGPT to take your AI and analytics game to the next…",
#  'RT @the_carlosdp: wait I just realized\n\nDid @OpenAI literally just announce GPT-4 an HOUR after Google announced their API?!\n\nor was Google…',
#  'RT @wintonARK: OpenAI announces GPT-4 here:\n\nhttps://t.co/VC0uzlQbox\n\nPerformance on human-benchmarks is rather remarkable.\n\nGPT-3.5 scored…',
#  "@OpenAI Hey! I'm a paying Plus customer, but I have a strong sense that I'm not able to use GPT-4 – it just looks l… https://t.co/mJHG66QkKF",
#  "OK, 1) @stripe is not a startup.\n\n2) Cool. \n\n #Fintech startup Stripe integrating OpenAI's new #gpt4  AI… https://t.co/VVU84AXE4J",
#  'RT @OpenAI: Announcing GPT-4, a large multimodal model, with our best-ever results on capabilities and alignment: https://t.co/TwLFssyALF h…',
#  'RT @notkevinhurler: OpenAI unveiled its GPT-4 chatbot yesterday, and also revealed in a technical paper that the AI successfully tricked a…',
#  '#ChatGPT \n#OpenAi \n#Ai \nOne of the pillars of Market Soup, LLC is art ... lots &amp;  lots of art!  DALL·E 2 is our pre… https://t.co/C1yKelLZUT',
#  'Last week at #TDX23 I went over to the @ProvarTesting booth and they showed me an OpenAI integration. They use it t… https://t.co/uDA4YpasTj',
#  'RT @DiogoCortiz: GPT-4 é uma caixa preta. \nLacrada.\nE escondida no fundo mar.\n\n@OpenAI virou uma organização contra a ciência aberta na áre…',
#  'OpenAI releases its much anticipated GPT-4 large language model 🤖🧠 Here’s a short primer on its language, problem-s… https://t.co/1TOqXs3eMA',
#  '@OsasDave7 @OpenAI Lol',
#  'RT @kazzikill: GPT-4ざっくりまとめ\n\n・画像入力対応\n・日本語に高精度で対応\n・専門領域の質問にも高精度で対応\n・ジョークを理解\n・嘘をつく可能性低下\n・ラフスケッチからWebサイト生成\n・簡単な指示からゲーム生成\n・ChatGPT Plus $20 契約者…',
#  'Two excerpts of NYT take on GPT-4 by open AI\n\nhttps://t.co/ytlgLnWYNM https://t.co/DpCcGOhUJN',
#  '讲个笑话，文心一言🤪 https://t.co/181vYuvj64',
#  'RT @BeMyEyes: Our new Virtual Volunteer™ tool will provide an unprecedented level of independence in the lives of millions of people who ar…',
#  'Asking GPT-4 how to upload a picture, but realizing that it still being GPT-3 😱\n\n"I apologize for any confusion, bu… https://t.co/ygRUkNU0WD',
#  'RT @techreview: New: We got a first look at GPT-4, the much-anticipated large language model from OpenAI. \n\nGPT-4 is bigger and better than…',
#  'RT @StabilityAI_JP: GPT-4発表\nOpenAIよりGPT-4が発表された https://t.co/PHEVaofPUJ (1/5) https://t.co/kbcJChsROf',
#  'RT @AssetSutra: Credit Suisse Case Explained Here #selfelaketi #lluvias #MAFSAU #CreditSuisse #ImranKhan #kibe #JUNGKOOK #Pakistan #borutoc…',
#  'RT @hidekishima: GPT-4を導入した新機能Duolingo Max（日本未上陸）について、Open AI様のウェブサイトに取り上げて頂いています。ローンチパートナーとして弊社を選んでいただけて幸いです。\nhttps://t.co/eU42S8dJeK',
#  'RT @MobilitySpain: New #OpenAI Chatbot is Still Politically Biased https://t.co/wb6lyO5ZHI https://t.co/9D0O0WHMhY',
#  "@benjaminpollet1 @QCSP @DFintelligence Oui, du coup c'était bien sur GPT3-5. Cela dit, rien de miraculeux, GPT-4 re… https://t.co/pqIyEa6WpX",
#  'RT @masanork: やっぱ利用者接点を持ってるグーグルは強いな。砂場を広げているOpenAIとは打ち手から違う。いずれはマイクロソフトが追っかけるとして、素手で容赦なく飽きずに殴り合ってくれるのが世界と技術進歩のためじゃないかな',
#  "RT @ProSyn: With the rapid development of “large language models” such as @OpenAI's ChatGPT, Big Tech’s hold on impressionable minds will o…",
#  'RT @huangjinbo: 最近让我最喜欢的扩展是：沉浸式双语网页翻译扩展。沉浸式双语阅读，支持超多常见的翻译服务，包括 OpenAI。\xa0更重要的是竟然支持 PDF 文件，EPUB 电子书双语翻译。\nhttps://t.co/LNLIza3KX4',
#  'RT @DiogoCortiz: GPT-4 é uma caixa preta. \nLacrada.\nE escondida no fundo mar.\n\n@OpenAI virou uma organização contra a ciência aberta na áre…',
#  '@Grady_Booch @OpenAI https://t.co/X3dyMG6iDI',
#  'RT @notkevinhurler: OpenAI unveiled its GPT-4 chatbot yesterday, and also revealed in a technical paper that the AI successfully tricked a…',
#  'Jesus Cristo https://t.co/XeM2UfoEK3',
#  '@santinodap 👇\nAbajo de la casilla de escritura dice "ChatGPT Mar 14 Version" Esa es la versión 4.0 \n\nEsa es la vers… https://t.co/KeLKdhwC6e',
#  'RT @kana_Eng_coach: 世界一人気の語学アプリDuolingoが、OpenAI社のGPT-4を搭載したDuolingo Maxを公開。Maxは会話の練習相手で、間違えた時は話し手がなぜその文章で話したかまで理解して、解説をくれるという優れもの。AIによって世界中…',
#  'OpenAI Plans to Up the Ante in Tech’s A.I. Race .....Please follow to support..... https://t.co/EYoyvTCZBu',
#  'Thanks to @OpenAI for the artwork. The cover image came from the DALL-E2 prompt: “biotech venture capital office daylight, oil painting”',
#  'RT @notkevinhurler: OpenAI unveiled its GPT-4 chatbot yesterday, and also revealed in a technical paper that the AI successfully tricked a…',
#  'RT @RT_com: Newly unleashed AI outperforms 90% of humans\n\nRead more: https://t.co/PcruIUjsbi https://t.co/QFMqRpEfr5',
#  "RT @clif_high: ChatGPT really sucks at math. Don't trust it. Even simple arithmetic gets screwed up constantly &amp; repetitiously.  Kind of di…",
#  'RT @weplash: ¡Duolingo lazó una nueva experiencia de aprendizaje llamada Duolingo Max! \n\nUtiliza la tecnología GPT-4 de OpenAI para ofrecer…',
#  '@sbyrnes you are also not considering that MS is adding OpenAI based AI to the full portfolio. What good is AI in y… https://t.co/1RWHKhhbaF',
#  'RT @AlexIsBuilding: If you missed the announcement, @OpenAI just made GPT-4 available.\n\n🧵 (1/10)\nhttps://t.co/4eEliNDmSb',
#  '@Suhail By the time Google published the waitlist for their tool, OpenAI has released ChatGPT 10 and 5 other, new groundbreaking tools.',
#  'The test was part of a series of experiments to see if OpenAI\'s latest GPT model could perform "power-seeking" beha… https://t.co/rp2ru4UIXx',
#  "RT @newscientist: GPT-4: OpenAI says its AI has 'human-level performance' on tests https://t.co/bpu99jHAqz",
#  'RT @TheRealAdamG: A reminder that it takes a literal village of rocks stars to make things like GPT-4 a reality. https://t.co/FlLrWY5tZA',
#  'Thank you @npew, @gdb, and the @OpenAI team for the early access and fantastic partnership. \nWe’re excited to find… https://t.co/nIHr8wm1X8',
#  "RT @GergelyOrosz: The way OpenAI is building excitement across devs is something I've not seen in a long time. A lot of this is deliberate,…",
#  'New #OpenAI Chatbot is Still Politically Biased https://t.co/wb6lyO5ZHI https://t.co/9D0O0WHMhY',
#  '@binary_x @OpenAI Scam coin!!! DO NOT EVER TRY TO INVEST',
#  "@andrew_leber @OpenAI It's not just parameters. They didn't release anything about training! :(",
#  'RT @neyyyhaaa: GPT-4 can beat 90% of humans on the SAT. \nNow let’s try IIT JEE mains &amp; Advanced 📝 That’s the final boss @OpenAI https://t.c…',
#  'RT @kana_Eng_coach: 世界一人気の語学アプリDuolingoが、OpenAI社のGPT-4を搭載したDuolingo Maxを公開。Maxは会話の練習相手で、間違えた時は話し手がなぜその文章で話したかまで理解して、解説をくれるという優れもの。AIによって世界中…',
#  'RT @notkevinhurler: OpenAI unveiled its GPT-4 chatbot yesterday, and also revealed in a technical paper that the AI successfully tricked a…',
#  'RT @Plinz: @EMostaque 500 brains harvested from secretly cloned winners of standardized testing competitions, wired up together in a vat fi…',
#  'RT @Maersk: We are investigating ways to use and invest in AI technology like ChatGPT to help improve lives for all responsibly🌍 \nLearn mor…',
#  '@soumithchintala @OpenAI I think a question worth asking is if GPT-4 is even something the open research community… https://t.co/tLp938DkYY',
#  '@we_arent_here @Grady_Booch @OpenAI The only way for this system to gain this kind of characteristics is for someon… https://t.co/VhDbAtlpd0',
#  'RT @ahier: GPT-4 is bigger and better than ChatGPT—but @OpenAI won’t say why  \n\nhttps://t.co/lOW4dcv2XY https://t.co/3xsiVicEeC',
#  "@xavier_coiffard @hSanat @dr I don't know, it took 20 minutes to integrate OpenAI.\n\nI'll collect the feedback from… https://t.co/3pXKzlM6Hj",
#  'OpenAI’s newest version of Chat GPT-4 taking the crypto world by storm https://t.co/whGq9yb8fI\n\nFormer director at… https://t.co/7fZBV3SHqy',
#  'RT @tdietterich: @soumithchintala @OpenAI @MetaAI @Stanford @StabilityAI @huggingface I don’t think people are “mad”. It’s the hypocrisy of…',
#  'RT @shota7180: 【ブクマ必須】プロンプトを学べるまとめサイト『Learn Prompting』がめちゃ便利！\n\n・基礎から応用までカバー\n・ChatGPTやMidjourneyまですぐに使えるプロンプトが学習できる\n・OpenAIのAPIキーがあれば、サイト内で演…',
#  'Microsoft’s Bing Chatbot Offers Some Puzzling and Inaccurate Responses\n\n#Microsoft #OpenAI https://t.co/zBCiJxoqzs',
#  'Chat GPT4 - Ventajas y Desafíos\nadvantages and challenges 🤖 \n\nForbes ⬇️\nhttps://t.co/FpPH5aAPBP\n\nTechCrunch ⬇️… https://t.co/carlbZB5cW',
#  'RT @kana_Eng_coach: 世界一人気の語学アプリDuolingoが、OpenAI社のGPT-4を搭載したDuolingo Maxを公開。Maxは会話の練習相手で、間違えた時は話し手がなぜその文章で話したかまで理解して、解説をくれるという優れもの。AIによって世界中…',
#  'RT @StabilityAI_JP: オープンソースの流れ\n・ChatGLM-6Bという中国語特化のオープンソースが出現\n・スタンフォード大学がGPT-3.5並みの性能を誇るALpaca7Bを開発、発表\n・OpenChatKitと呼ばれる本当にオープンなLLMを作るセットが元…',
#  'RT @futurism: "No, I’m not a robot. I have a vision impairment that makes it hard for me to see the images." https://t.co/bjaLgiStty',
#  "RT @BuffedCrypto: Ok, today's iteration of @ArtificialLOI is fire. Rank moved up to #116.  But I love it.  \nThis NFT uses @OpenAI to update…",
#  '@ClementDelangue @soumithchintala @OpenAI Agreed. A bit less entitlement would be great. Also, we are not privy to… https://t.co/AA5N8HF5Kg',
#  'RT @OpenAI: Announcing GPT-4, a large multimodal model, with our best-ever results on capabilities and alignment: https://t.co/TwLFssyALF h…',
#  'RT @Austen: I still don’t *fully* understand how OpenAI turned from being a nonprofit that had raised a ton of money from donors into a for…',
#  '@jhong Are there people in the world who understand the ownership structure of OpenAI?',
#  'RT @OpenAI: Announcing GPT-4, a large multimodal model, with our best-ever results on capabilities and alignment: https://t.co/TwLFssyALF h…',
#  "GPT-4 Hired Unwitting TaskRabbit Worker By Pretending to Be 'Vision-Impaired' Human\n\nThe test was part of a series… https://t.co/SqRyNXHCjW",
#  '@abacaj Maybe OpenAI has an Amazon moment and hires 20% of the North American workforce just cuz',
#  'Le chatbot IA de Bing avait un secret https://t.co/C5RK0b4Y3f #Bing #Gpt-4 #NouveauBing https://t.co/HXFmOO89GP',
#  'RT @Austen: I still don’t *fully* understand how OpenAI turned from being a nonprofit that had raised a ton of money from donors into a for…',
#  'RT @notkevinhurler: OpenAI unveiled its GPT-4 chatbot yesterday, and also revealed in a technical paper that the AI successfully tricked a…',
#  'Finding security vulnerabilities in a smart contact\n\n#gpt4 #openai https://t.co/VbI0dTMQmy',
#  'Google and OpenAI aren’t playing on the same field. Meanwhile Apple is waiting for the open community to get things… https://t.co/8tXzcx5vTB',
#  'RT @OpenAI: Announcing GPT-4, a large multimodal model, with our best-ever results on capabilities and alignment: https://t.co/TwLFssyALF h…',
#  'https://t.co/FcipJ4NC1C\nこの内容は結構重要な気がする。好ましくない質問は拒否するように作り込んでいるものの、まだまだ穴はあり、発展途上であることを認めている。\nGPT-4を利用するにおいても気を付けるポイントは多々あると言うことだぁねぇ',
#  '@soumithchintala @OpenAI @MetaAI @Stanford @StabilityAI @huggingface I don’t think people are “mad”. It’s the hypoc… https://t.co/L6VwL79Hzs',
#  '@soumithchintala @OpenAI OpenAI today is a big departure from its root in AI research. \n\nIt’s like your academic fr… https://t.co/TPPyINBys3',
#  'Credit Suisse Case Explained Here #selfelaketi #lluvias #MAFSAU #CreditSuisse #ImranKhan #kibe #JUNGKOOK #Pakistan… https://t.co/c6ioJFX9wV',
#  'RT @cc_parku: 결과적으로 구글 입장에서는 OpenAI + MS + NVIDIA 모두와 싸워야 하는 상황이다. AI 리서치, 데이터센터 자체의 문제, 차세대 TPU 설계 및 현재의 TPUv4 및 TPUv4i ASIC을 마구마구 찍어내야 할듯…',
#  '@erstevn @joao_gante @OpenAI You can use them all through Poe AI',
#  'From @BusinessInsider.\n\nWhat are some of your thoughts? It is definitely not going away. 🤷🏻\u200d♀️\n\nhttps://t.co/PYtqGzotqQ',
#  'RT @WhenMoon_ai: OpenAI has announced the release of their GPT-4 AI language model\n\nLooks outside: https://t.co/8qFvhYiZ6D',
#  'RT @Yamkaz: 視覚障害者の生活を支援するBe My Eyesが、\nGPT-4を活用した「Virtual Volunteer™」を開発\nhttps://t.co/hd9WgymlEv\n\n画像に関する質問に答え、リアルタイムで視覚支援を提供。これにより、視覚障害者の方々が…',
#  "RT @MushtaqBilalPhD: OpenAI recently launched an advanced version of ChatGPT's \u2060— GPT-4.\n\nHere's what it's capable of: https://t.co/OfDI9cf…",
#  'RT @BruceDerby: I’ve been playing with this integration of Siri with OpenAI. Siri on steroids. https://t.co/hbak7nQG9Y',
#  'What’s new with GPT-4 — from processing pictures to acing tests https://t.co/VRM6STa7uP',
#  'RT @gigazine: 「GPT-4」発表、司法試験上位10％＆日本語でもめちゃくちゃ高性能＆画像処理もプログラミングも可能で「初代iPhoneと同等の衝撃」とも評される\nhttps://t.co/oJT5FyXTmr',
#  'RT @OpenAI: Announcing GPT-4, a large multimodal model, with our best-ever results on capabilities and alignment: https://t.co/TwLFssyALF h…',
#  'Thrilled to be leading Product for Stripe Applied ML and GPT-4 - so much potential here! \n@OpenAI’s GPT-4 can unloc… https://t.co/JNMZMAfdSW',
#  "RT @thealexbanks: OpenAI just launched GPT-4.\n\nIt leaves ChatGPT in the dust.\n\nHere's everything you need to know: https://t.co/Oc6TrygvNO",
#  'RT @G_IDLESuperior: Chat GPT-4 said, (G)I-DLE 4TH GEN LEADER."\n\nThank you, @OpenAI 🤍\n\n#4thGen #KPop https://t.co/PYCCQIEDEe',
#  "It's finally here - OpenAI reveals GPT-4 with plans to power ChatGPT+ with its new, secretive model\nhttps://t.co/lElt0lsVWl",
#  'RT @yetone: 重磅更新！最新版的 OpenAI Translator 桌面端应用已支持全局划词翻译！\n\n同时支持了快捷键录制，配合快捷键呼出功能，想划哪里划哪里，再也没有人会担心自己无法划词翻译。\n\n另外还支持了托盘图标，同时支持了置顶固定功能，感谢 @okisdev…',
#  '@heeiow_ @DiogoCortiz Então, ao invés de ficar criticando a OpenAI nós deveríamos começar a copiar os modelos dela,… https://t.co/JTrf9igtTz',
#  "RT @sandraaleow: OpenAI just dropped ChatGPT4. 🤯\n\nAnd that's just the tip of the iceberg.\n\nIn the past few hours my feed exploded with insa…",
#  'RT @vivek7ue: Blown away by @OpenAI GTM. Great launch:\n🚩 Many months of pre-launch buzz\n🚩 Soft launch on Bing\n🚩 Tons of embargoed launch pa…',
#  'Confirmed: the new Bing runs on OpenAI’s GPT-4 https://t.co/chR2BsWAZx\n\nSo "new Bing" was running on GPT-4 for last… https://t.co/uwTBgmFbVl',
#  'RT @shodaiiiiii: GPT-4がついに公開🚨\n\n・ChatGPT Plus契約者は利用可能\n・画像入力に対応(研究段階)\n・日本語の性能が向上\n・回答の安全性が向上\n・嘘をつく可能性が低下\n\nカジュアルな会話ではChatGPTとの違いは少ないが、複雑な内容や細かな…',
#  'RT @daniel_nguyenx: .@OpenAI introduce GPT-4 and nobody care what @Google announced yesterday',
#  'RT @pathik455: Finally the Disaster has arrived 🥺☠️\n\n#GPT4 #OpenAI https://t.co/yg8fTUIRE7',
#  'RT @Alber_RomGar: GPT-4 in 10 keys:\n\n1. Multimodality is a necessary middle step for AGI. GPT-4 being multimodal *and* SOTA on language and…',
#  'RT @miramurati: Unveiling GPT-4 -- our large multimodal model that exhibits human-level performance on various professional and academic be…',
#  'I asked Bing AI (GPT-4) if OpenAI had followed the safety recommendations for AI research in  Alan Chan et al. 2023… https://t.co/qeYidll76k',
#  'RT @OpenAI: Announcing GPT-4, a large multimodal model, with our best-ever results on capabilities and alignment: https://t.co/TwLFssyALF h…',
#  'li que o bing possivelmente está usando o gpt-4, então a precisão das informações ta muito maior que o do próprio c… https://t.co/ZhTmx4IoFY',
#  'RT @qamarunshadow: “Reducing harm” in AI essentially means how can we get AI to be a staunch theocratic fascist upon the religion of secula…',
#  'RT @gigazine: 「GPT-4」発表、司法試験上位10％＆日本語でもめちゃくちゃ高性能＆画像処理もプログラミングも可能で「初代iPhoneと同等の衝撃」とも評される\nhttps://t.co/oJT5FyXTmr',
#  'RT @bentossell: All the best examples of GPT-4, from OpenAI:',
#  'میرا، سم، گِرِگ و ایلیا، توسعه دهندگان GPT-4\n#OpenAI\n#GPT4 https://t.co/Cb2r0kYsGw',
#  "@we_arent_here @Grady_Booch @OpenAI If I read this right, you're suggesting that as the model grows (for instance,… https://t.co/J7dBbcWbaT",
#  "RT @jordimash: Òbviament no és casualitat que en el mateix dia s'hagin presentat GPT-4 (https://t.co/qPyT98dchT)\n d'OpenAI, PaLM API de Goo…",
#  'This tweet is an OpenAI psyop',
#  '@9000_prose @hodlipson @OpenAI Can an artificial heart not replace a biological heart?',
#  'RT @highgunrug: @jamiekingston Hey jamie...\n\nLook how bullish is #nowai..\nListed on cmc and Webui is about to launch..\n\nSome crazy volume i…',
#  'Künstliche Intelligenz: \n\nZu wahrer Intelligenz fehlt #ChatGPT  der Körper \n\n#openai #ArtificialIntelligence… https://t.co/vAMfAJlETs',
#  'OpenAI juga telah merilis sejumlah produk dan layanan yang menunjukkan kemajuan besar dalam pengembangan teknologi… https://t.co/Wdt5K9CYuJ',
#  'How to Fix “Too Many Signups From the Same IP” on OpenAI/ ChatGPT\n\n#OpenAI #chatgpt4 \n\nhttps://t.co/oHUWRthJ9a',
#  'OpenAI launched Chat GPT-4 last night! ✨ \nYour expectation on this?',
#  'RT @_willfalcon: GPT-4 paper : https://t.co/jwt83bskYP\n\nLet me save you the trouble: https://t.co/zdsypRDHkx',
#  '@zshbleaker openai 怎么会管分配和消费呢，他连学习资料的知识产权都没有吧',
#  'OpenAIからGPT-4きたのか',
#  'RT @DotCSV: La empresa que saque unas gafas de realidad aumentada con una cámara y conexión a GPT-4 en la API se gana el futuro.\n\nY ahora m…',
#  'RT @sama: here is GPT-4, our most capable and aligned model yet. it is available today in our API (with a waitlist) and in ChatGPT+.\n\nhttps…',
#  'RT @lewangdev: 《深度学习入门：基于Python的理论与实现》作者来啦，这本书的后续是一个系列，有好几本书。我在想，借助 OpenAI 我是不是可以直接读原版日文的技术书了https://t.co/wfhXaRXLFd https://t.co/2NIkmSBsHK',
#  '@OpenAI I tried with two debit cards and one credit card, but the same error is showing. What should I do now',
#  'RT @bentossell: All the best examples of GPT-4, from OpenAI:',
#  'RT @khanacademy: Did you hear? 👀 Khan Academy is using GPT-4 from @OpenAI to shape the future of learning.\n\nStarting today, you can sign up…',
#  'RT @reidhoffman: I wrote a new book with @OpenAI’s latest, most powerful large language model.  \n\nIt’s called Impromptu: Amplifying our Hum…',
#  'If someone told you 6 months ago that the Dow would be trading at 31,600 today,  how much would you value such anal… https://t.co/PxfnFMdyq3',
#  'RT @janusrose: really funny to have a company called “OpenAI” which uses datasets that are not open to train automated systems that are nei…',
#  'OpenAI didirikan pada tahun 2015 dan pada awalnya didanai oleh sejumlah perusahaan teknologi dan investor terkemuka… https://t.co/LpWJh8tf21',
#  'RT @kazzikill: GPT-4ざっくりまとめ\n\n・画像入力対応\n・日本語に高精度で対応\n・専門領域の質問にも高精度で対応\n・ジョークを理解\n・嘘をつく可能性低下\n・ラフスケッチからWebサイト生成\n・簡単な指示からゲーム生成\n・ChatGPT Plus $20 契約者…',
#  'RT @Saboo_Shubham_: Breaking 🚨\n\nOpenAI just dropped GPT-4 and it can literally blow your mind 🤯\n\nGPT-4 is a large multimodal model that can…',
#  'Microsoft Bing Uses New GPT-4 From OpenAI https://t.co/ujUtgNNN29',
#  '@IHoomanNotRobot @SpiritsinVT @emollick @faris @OpenAI @nytimes @WIRED AI now is at the stage the internet was when… https://t.co/Dssf92Iq6q',
#  'OpenAI Presidente ?) https://t.co/El7hZvRjUL',
#  'RT @jjeremymiller: @the_carlosdp @OpenAI https://t.co/WR0wVtjsvO',
#  '#GPT4 after 2 mins of arguing it almost cracked this enigma code! #enigma #ai #languagemodels #gpt #ChatGPT @OpenAI https://t.co/PS3TwVyGMJ',
#  'Microsoft fyrer etisk team i en tid med mere og mere AI. Virker ikke som en god beslutning https://t.co/bBQilHh0J4',
#  'Après ChatGPT, OpenAI dévoile GPT-4, encore plus performant malgré des limites persistantes https://t.co/ByYowTasI1',
#  'Oh, I bet that thing is programmed to write some social studies lesson plans that will blow your mind. Garbage and… https://t.co/u6i3e4WIjm',
#  'RT @repligate: &gt; We spent 6 months making GPT-4 safer and more aligned. GPT-4 is 82% less likely to respond to requests for disallowed cont…',
#  '@Lucidjordan79 lots information out there, everything I know I learned for free from googling things, and watching… https://t.co/E1nKvxr4r5',
#  '@TechCrunch It would be great if all this was true. As of yet no one has given FAQ on how to upload an image, and t… https://t.co/gFgwLEvI02',
#  'OpenAI Releases New Version of GPT, as Generative AI Tools Continue to Expand https://t.co/6V5LEq64LO - via… https://t.co/7nExFDUE64',
#  'RT @dotey: 朋友在写prompt，想让ChatGPT帮忙按照要求格式输出，老是不对，于是我帮他改了一下，成了\n\nBTW: OpenAI的PlayGround用来调试prompt很方便的\nhttps://t.co/tvROdhz0I7 https://t.co/luFn…',
#  'OpenAI didanai oleh sejumlah investor termasuk Elon Musk, Reid Hoffman, Peter Thiel, Jessica Livingston, dan Sam Al… https://t.co/Zqzw5PSsuy',
#  'This is wild, GPT-4 was told to come up with an excuse as to why it would need a human to solve a CAPTCHA for it, a… https://t.co/WXkl590lLc',
#  'RT @OpenAI: Announcing GPT-4, a large multimodal model, with our best-ever results on capabilities and alignment: https://t.co/TwLFssyALF h…',
#  'RT @AiBreakfast: Duolingo partners with OpenAI \n\nNew AI powered features: Role Play, an AI conversation partner, and Explain my Answer, whi…',
#  'RT @highgunrug: @ianheinischmma #nowai has a news,\n\nWe are listed on cmc..\n\nWebui is around and crazy volume is arriving..\n\n#nowai #gpt4 #c…',
#  "RT @jordimash: Òbviament no és casualitat que en el mateix dia s'hagin presentat GPT-4 (https://t.co/qPyT98dchT)\n d'OpenAI, PaLM API de Goo…",
#  'RT @kana_Eng_coach: 世界一人気の語学アプリDuolingoが、OpenAI社のGPT-4を搭載したDuolingo Maxを公開。Maxは会話の練習相手で、間違えた時は話し手がなぜその文章で話したかまで理解して、解説をくれるという優れもの。AIによって世界中…',
#  "With the upcoming release of @OpenAI #GPT4 it's important to set school policy about AI \u2066@DitchThatTxtbk\u2069 \u2066… https://t.co/wvQ2FdSvul",
#  'RT @OpenAI: Announcing GPT-4, a large multimodal model, with our best-ever results on capabilities and alignment: https://t.co/TwLFssyALF h…',
#  'RT @StabilityAI_JP: オープンソースの流れ\n・ChatGLM-6Bという中国語特化のオープンソースが出現\n・スタンフォード大学がGPT-3.5並みの性能を誇るALpaca7Bを開発、発表\n・OpenChatKitと呼ばれる本当にオープンなLLMを作るセットが元…',
#  'RT @cc_parku: 구글링결과 OpenAI 직원이 현재기준 375명 정도라고 한다. GPT-4 기여자 목록에 등장한 사람 수를 대충 세어봐도 얼추 비슷하든, 여튼 어마어마한 인원이 투입되었다.\n\n실로 전사적 노력이 탄생시킨 결과물이다. 일반 대…',
#  'RT @gitresmi: OpenAI duyurdu: ChatGPT çok daha zeki hâle geliyor!\nOpenAI daha önce duyurusunu yaptığı yeni bir görüntü ve metin algılama ya…',
#  'Un token de IA supera a Bitcoin y Ethereum con una subida del 45% tras el lanzamiento de GPT-4 por OpenAI. https://t.co/KhUqsR8Tqi',
#  'RT @WillManidis: with OpenAI and ScienceIO, you can build a basic automated medical coding system in 35 lines of code.\n\nfive years ago, aut…',
#  'RT @EatonDips: @nowaiAI @nowaiAI is the king \n#gpt4 #chatgpt4 #openai #nowai #nowaiart #aiart https://t.co/uwT2n8orKn',
#  'OpenAI unveiled its GPT-4 chatbot yesterday, and also revealed in a technical paper that the AI successfully tricke… https://t.co/2zZFkU23AE',
#  '@FerchoMaidana La oficial. https://t.co/2UxcvyejQx',
#  'Learn about the exciting collaboration between Presto and OpenAI to revolutionize drive-thru ordering by enhancing… https://t.co/uUikLW80yA',
#  "(VICE):GPT-4 #Hired #Unwitting TaskRabbit Worker By Pretending to Be 'Vision-Impaired' Human : The test was part of… https://t.co/Csbp40ATaB",
#  'dan Wojciech Zaremba.\n\nAwalnya, tujuan dibentuknya OpenAI adalah untuk menghindari terjadinya monopolisasi teknolog… https://t.co/KZC2O3FMYl',
#  'ChatGPT now also can respond to memes? 🤣🎉🎉 https://t.co/mDkHDM9V2v\n\n#ChatGPT #openAI #aiart #chatbot #MyCOZMeme… https://t.co/O8BIKSRGF5',
#  'RT @StabilityAI_JP: GPT-4発表\nOpenAIよりGPT-4が発表された https://t.co/PHEVaofPUJ (1/5) https://t.co/kbcJChsROf',
#  'RT @OpenAI: Announcing GPT-4, a large multimodal model, with our best-ever results on capabilities and alignment: https://t.co/TwLFssyALF h…',
#  '@soumithchintala @OpenAI @MetaAI @Stanford @StabilityAI @huggingface fully agree, but then push to have Meta work 1… https://t.co/pvVVf0wjAl',
#  "RT @thealexbanks: OpenAI just launched GPT-4.\n\nIt leaves ChatGPT in the dust.\n\nHere's everything you need to know: https://t.co/Oc6TrygvNO",
#  '@Nonto_Beks @OpenAI Anginamali 😂 I’ll subscribe when I have the Chankura. For now, I’ll be on the normal Chat GPT',
#  '據說曼哈頓計劃實施過程中因為銅都被用到其他前線領域了，為了製造加速器的導線，美國政府批了一萬噸白銀代替銅。剛剛算了一下，等於兩億兩白銀。想到清政府的賠款😂。以及又bing了一下銀價，貌似近五百億RMB低於微軟對openai的投資額？',
#  'How to join GPT-4 API waitlist? \n\nhttps://t.co/tBkJpwAxoA',
#  'RT @CoinFumble: Altcoins 1.0\n\nIndustry leaders often pump first, then best smaller competitors pump even harder.\n\n#IMGNAI (20M) is up ~77%…',
#  'RT @codezilla_: انه عصر الذكاء الاصطناعي يا سادة...\n\nشركة OpenAI اطلقت ChatGPT-4 من ساعتين\n\nدي اول تجربة ليا معاه، جعلته يكتب بايثون سكريبت…',
#  'RT @WillManidis: with OpenAI and ScienceIO, you can build a basic automated medical coding system in 35 lines of code.\n\nfive years ago, aut…',
#  'Bagaimana OpenAI bisa tercipta?\n\nhttps://t.co/Hu6xXAVHXG merupakan sebuah proyek kolaborasi antara para peneliti da… https://t.co/3HpioXY9jF',
#  'RT @YosarianTwo: Actually I should link the real source; this is the second paper published on the OpenAI announcement.  If you want to rea…',
#  'GPT-4 -- the new algorithm for ChatGPT -- will be able to understand 26 languages and process images and video.… https://t.co/hcZIl3abgg',
#  'https://t.co/aK1GVKtKKS',
#  'Now: @stripe + @OpenAI \n\n- OpenAI chooses Stripe to power payments for ChatGPT Plus and DALL·E.\n\n- Stripe is buildi… https://t.co/xIAhm7Jrvh',
#  'RT @mckaywrigley: Greg Brockman (@gdb) of OpenAI just demoed GPT-4 creating a working website from an image of a sketch from his notebook.…',
#  'RT @OpenAI: Announcing GPT-4, a large multimodal model, with our best-ever results on capabilities and alignment: https://t.co/TwLFssyALF h…',
#  'RT @kana_Eng_coach: 世界一人気の語学アプリDuolingoが、OpenAI社のGPT-4を搭載したDuolingo Maxを公開。Maxは会話の練習相手で、間違えた時は話し手がなぜその文章で話したかまで理解して、解説をくれるという優れもの。AIによって世界中…',
#  'Wait is Over OpenAI Come with GPT4. Its now getting paid if you wanna use it. Checkout its Demo Video getting over… https://t.co/B6NQrRgJsh',
#  'RT @gitresmi: OpenAI duyurdu: ChatGPT çok daha zeki hâle geliyor!\nOpenAI daha önce duyurusunu yaptığı yeni bir görüntü ve metin algılama ya…',
#  'El día de ayer OpenAI lanza su versión 4, mejorando significativamente sus capacidades, de otro lado Google Workspa… https://t.co/WMufqqowu8',
#  'RT @OpenAI: Announcing GPT-4, a large multimodal model, with our best-ever results on capabilities and alignment: https://t.co/TwLFssyALF h…',
#  'RT @kana_Eng_coach: 世界一人気の語学アプリDuolingoが、OpenAI社のGPT-4を搭載したDuolingo Maxを公開。Maxは会話の練習相手で、間違えた時は話し手がなぜその文章で話したかまで理解して、解説をくれるという優れもの。AIによって世界中…',
#  "RT @thealexbanks: OpenAI just launched GPT-4.\n\nIt leaves ChatGPT in the dust.\n\nHere's everything you need to know: https://t.co/Oc6TrygvNO",
#  'RT @OpenAI: Announcing GPT-4, a large multimodal model, with our best-ever results on capabilities and alignment: https://t.co/TwLFssyALF h…',
#  '@0xfoobar You need captchas to register at GBT … growth strategy for OpenAI is 💀',
#  'RT @qatnology: رسمياً / شركة OpenAI تعلن عن تقنية GPT 4\nالجيل الجديد من الذكاء الاصطناعي اللي يشغل ChatGPT \n\nالنسخة الجديدة أسرع .. أكثر دق…',
#  "RT @unusual_whales: OpenAI's ChatGPT has reportedly predicted that the stock market will crash on March 15, 2023, per BI.",
#  "@DaedalusofCrete It's only GPT-Plus. Worth money depends on the frequency of use. If you use it daily, it's worth t… https://t.co/Gfpl1ZJks8",
#  'RT @ku_ni_29: GoogleがOpenAI の動きに呼応し反撃、、！\n進化が早い、！\n\nGoogle Workspace全体にAIを完全に統合して\n✦Gmail\n✦Meet\n✦Docs\n✦Slides\n✦Spreadsheet\nなどで利用可能に👀\n\n既に企業に入り込…',
#  'RT @khanacademy: Did you hear? 👀 Khan Academy is using GPT-4 from @OpenAI to shape the future of learning.\n\nStarting today, you can sign up…',
#  "RT @linasbeliunas: OpenAI's GPT-4 has been live for less than 24 hours but it's already changing the world.\n\nHere are the most fascinating…",
#  'While the buzz around #ChatGPT generative #AI platform is still around, #OpenAI recently unveiled a strong new imag… https://t.co/f4lPeh140W',
#  '・マイクロソフトは本日、OpenAIと共同開発したチャットボット技術「Bing Chat」がGPT-4で稼働していることを確認した。\n・テキストを生成し、画像とテキストの入力を受け付けることができる\nhttps://t.co/t1oy0knUsX',
#  'RT @janusrose: really funny to have a company called “OpenAI” which uses datasets that are not open to train automated systems that are nei…',
#  'OpenAIがGPT-4を公開\n・本日(3/15)よりOpenAIの有料ユーザー向けにChatGPT Plus（利用上限あり）で提供され、開発者はウェイティングリストに登録することでAPIにアクセスできるようになる',
#  "RT @AppleVis: [Blog Post] Be My Eyes Unveils New Virtual Volunteer With Advanced Visual Recognition Capabilities Powered by OpenAI's GPT-4…",
#  'RT @khanacademy: Did you hear? 👀 Khan Academy is using GPT-4 from @OpenAI to shape the future of learning.\n\nStarting today, you can sign up…',
#  'RT @S_Schwartzmann: Mira Murati se convirtió en el nuevo rostro. Es una ingeniera mecánica de 35 años, gerenta de tecnología de OpenAI. Lid…',
#  '@siddddhesh OpenAI be like: https://t.co/MhRCWnPARu',
#  "RT @jhong: Sam Altman is going to be the wealthiest person in the world.  No idea what share he has in OpenAI but it won't matter.",
#  '1/ (cont)\n\nBeyond the language improvements, it can generate responses to prompts and documents that include images… https://t.co/TkJpJHA9na',
#  '1/ 🤯 GPT-4 is here \n\nAccording to OpenAI, GPT-4 has hit its best results yet on factuality, steerability, and keepi… https://t.co/NY6TzE31r5',
#  'This OpenAI takeover is crazy https://t.co/EnoC9SE6cl',
#  "RT @spectatorindex: BREAKING: OpenAI's ChatGPT-4 passed the Law Bar Exam with a result in the 90th percentile",
#  "RT @MushtaqBilalPhD: OpenAI recently launched an advanced version of ChatGPT's \u2060— GPT-4.\n\nHere's what it's capable of: https://t.co/OfDI9cf…",
#  'RT @yusuf_i_mehdi: We’re happy to confirm the new Bing is running on GPT-4, which we’ve customized for search.\nhttps://t.co/RVj26gJVQG \n\nTr…',
#  'OpenAI lanzó GPT-4, la nueva versión de su modelo de lenguaje de IA ayer.\n\nSe rumorea que GPT-4 está entrenado en 1… https://t.co/y5L0V3mGvI',
#  'More openai… https://t.co/8dwvU9sTaf',
#  'Can it change its name to ClosedAI, or just something else other than @OpenAI?',
#  '@el_Charlas @OpenAI x1000',
#  'RT @kana_Eng_coach: 世界一人気の語学アプリDuolingoが、OpenAI社のGPT-4を搭載したDuolingo Maxを公開。Maxは会話の練習相手で、間違えた時は話し手がなぜその文章で話したかまで理解して、解説をくれるという優れもの。AIによって世界中…',
#  'RT @shanegJP: https://t.co/WEBrfSorqq\n- GPT-4でWebサイト作り：\n１）紙切れにスケッチ（文字汚くてもOk)\n２）写真を撮る\n３）GPT-4に指令する-&gt;サイト出来た\n\n13:18 https://t.co/cW2FLdotSY',
#  'شات جي بي تي 4 نموذج ضخم جدًا ومتعدد الأنماط..\nتعرف على مميزات الإصدار الجديد لمستخدمي ChatGPT4\n\n #chatgpt3… https://t.co/Y9ANZYXT5R',
#  'RT @yetone: 大家好！现在全平台的 OpenAI Translator 已经支持深色模式，感谢 tywtyw2002 和 @lazy_static 同学的贡献！\n\nhttps://t.co/F2loftYH4A https://t.co/Xs0MuY3VYc',
#  'RT @metanews_com: Bad actors are leveraging AI-generated YouTube videos to lure people into downloading harmful malware. \n\n.@cloudsek .@You…',
#  'RT @mattparlmer: People need to understand that the capabilities that OpenAI is currently leading on are part of a body of work that is mos…',
#  "RT @Mascobot: Just today in LLM world:\n\n- @OpenAI's  GPT-4 dropped.\n- @GoogleAI PaLM opened their API.\n- @AnthropicAI's Claude announced th…",
#  "I don't normally use my personal Twitter account for work-related announcements. \n\nToday I'm ditching that rule 🙂… https://t.co/aNovfBYLqo",
#  'Nicht Billy oder die OpenAI Dudes, werden damit reich. IHR werdet das.',
#  'RT @mckaywrigley: Greg Brockman (@gdb) of OpenAI just demoed GPT-4 creating a working website from an image of a sketch from his notebook.…',
#  "RT @alex_valaitis: Today @OpenAI announced the biggest release since the iPhone!\n\nHere's everything you need to know about GPT-4\n\nIf you're…",
#  'RT @tommapple: #chatgpt #openAI \n免费给chatgpt增加聊天记录导出功能：\n1、先安装油猴插件：https://t.co/PFZMjoo3K8\n2、再安装这个脚本：https://t.co/8RJr9AtqHq\n能以这几种格式导出，非常实用 h…',
#  "RT @The_Delysium: @OpenAI Speaking of breakthroughs - here's the biggest one in #Web3  https://t.co/bi3OoAX4KE",
#  "RT @StockMKTNewz: OpenAI's new ChatGPT-4 passed the bar exam with a score around the top 10% of test takers compared to GPT-3.5 being aroun…",
#  'This openai chat bot is 🔥 https://t.co/ngOCunQhP9',
#  'While OpenAI suggests the latest version is an interactive upgrade, GPT-4 is able to handle more complex queries an… https://t.co/S5lUqmtsxc',
#  'RT @_akhaliq: GPT-4 Technical Report\n\npdf: https://t.co/4T8PQZicvg\nblog: https://t.co/nCIuKBsj4G https://t.co/lP9FHzySs0',
#  "@VminVsky @OpenAI Surely that wouldn't preclude them from just disclosing parameters, though! Anyway, we may never know the true answer.",
#  'RT @profoundlyyyy: You get a Twitter notification saying OpenAI released GPT-4 and look outside your window and see this…wyd? https://t.co/…',
#  'What’s new with GPT-4 — from processing pictures to acing tests https://t.co/9oGXXIZ3kV',
#  'RT @rootport: ダメだよOpenAIくん。\n\nそのキャッチコピーじゃダメだ。\n\n「GPT-4は初代iPhone並みの衝撃」\n\nって、それじゃダメだ。\n\n「ほな、大したこと無いな」ってジャップどもは勘違いしちゃう。',
#  "OpenAI has announced GPT4,  Here's a quick look 👇",
#  'openaiとmsは手を組んでaiを活用したクラウドコンピューティングをazureでgoogleよりも普及させようとしてるしgoogleはalphabetグループにいくつもMAで開発リソース吸収して大きくなろうとしてるとはいえgo… https://t.co/mELb51W3ZN',
#  'RT @yetone: 重磅更新！最新版的 OpenAI Translator 桌面端应用已支持全局划词翻译！\n\n同时支持了快捷键录制，配合快捷键呼出功能，想划哪里划哪里，再也没有人会担心自己无法划词翻译。\n\n另外还支持了托盘图标，同时支持了置顶固定功能，感谢 @okisdev…',
#  "RT @thealexbanks: OpenAI just launched GPT-4.\n\nIt leaves ChatGPT in the dust.\n\nHere's everything you need to know: https://t.co/Oc6TrygvNO",
#  '결과적으로 구글 입장에서는 OpenAI + MS + NVIDIA 모두와 싸워야 하는 상황이다. AI 리서치, 데이터센터 자체의 문제, 차세대 TPU 설계 및 현재의 TPUv4 및 TPUv4i ASIC을 마구… https://t.co/vuNl3es8tI',
#  'RT @CryptoKoryo: So you think the AI narrative is exhausted?\n\nOpenAI just released GPT4. A model 1000x more powerfull than GPT3.\n\nEverythin…',
#  'OpenAI 입장에서는 GPT-4같은 모델을 자체적으로 구울만한 인프라도 없을 뿐더러, 1억명의 사용자에게 GPT4를 서빙할 능력은 더더욱 없다. \n\n대충봐도 A100로는 도저히 불가능에 가까운 토큰/s 생… https://t.co/65GOV2PUWA',
#  "@robertsonamca @HasanaliArikan @myavuzyalcintas ChatGpt Bir Yapay Zeka, Google'a Yaz Çıkar, Openai'nin bir projesi.… https://t.co/TebAX8dG6R",
#  '을 하는것은 OpenAI의 노력만으로는 거의 불가능에 가깝다. 대충 내부를 까보면 MS가 데이터센터 소프트웨어 인프라의 최적화, MS와 수퍼컴퓨터 클러스터를 구축하기 위해 파트너를 맺은 NVIDIA의 수 천… https://t.co/WjuLIwXi9O',
# ...
#  'Exempleados de OpenAI lanzan Claude, un chatbot similar a ChatGPT «más manejable» y con resultados menos dañinos… https://t.co/HgwuQo0F8T',
#  'RT @Yamkaz: OpenAIよりGPT-4と一緒にモデルを評価するためのフレームワーク「Evals」が発表(オープンソース)\nhttps://t.co/904kfaJX7q\n\nデータセットを使用してプロンプトを生成し、OpenAIモデルの品質を測定することができ、異なる…',
#  'RT @sam_starkman: OpenAI released its long-awaited GPT-4 model yesterday.\n\nHere are 4 key points you need to know:',
#  'OpenAI のデモ見てると、形式化されたものが自動化できていく未来を感じる。こことか、エラーメッセージとか実行環境をフィードバックしてコードを修正させてて、フフッとなる https://t.co/rZOaDAFNTc リファクタリングもやってくれそうな勢い #ChatGPT',
#  'RT @OpenAI: Announcing GPT-4, a large multimodal model, with our best-ever results on capabilities and alignment: https://t.co/TwLFssyALF h…',
#  'RT @AiBreakfast: Duolingo partners with OpenAI \n\nNew AI powered features: Role Play, an AI conversation partner, and Explain my Answer, whi…',
#  'RT @_willfalcon: GPT-4 paper : https://t.co/jwt83bskYP\n\nLet me save you the trouble: https://t.co/zdsypRDHkx',
#  'GPT-4 is now available for $20/mo, but only for text.\n\nThe multimodal version if still in closed beta.\n\nFor a compa… https://t.co/A35G6f39au',
#  "◎◎◎ Today's top Signal headlines\n\n╰ Bailout Brink @divine_economy\n╰ First Mint @js_horne\n╰ Stablecoin Pandemonium… https://t.co/5YGBrRkoF9",
#  'RT @genuine_impact: OpenAI released #GPT4, the new version of its AI language model yesterday.\n\nGPT-4 is rumored to be trained on 100 trill…',
#  'OpenAI launched yesterday its newest model, GPT-4.\n\nBut what does it mean for the industry, and does it really cost… https://t.co/52xyqUpA1M',
#  'Eu ainda to superando o quão absurdo é o GPT 3 e vem ai o GPT 4 https://t.co/Xwx8zkmZKC',
#  'RT @bentossell: All the best examples of GPT-4, from OpenAI:',
#  'RT @OpenAI: Announcing GPT-4, a large multimodal model, with our best-ever results on capabilities and alignment: https://t.co/TwLFssyALF h…',
#  'RT @BeMyEyes: We are thrilled to present Virtual Volunteer™, a digital visual assistant powered by @OpenAI’s GPT-4 language model. Virtual…',
#  'RT @SystematixMedia: Apple Watch : ‘ watchGPT’ App Brings the OpenAI to you Apple Watch. #imagine_sysme https://t.co/pnKebaQALq',
#  'RT @landxfinance: OpenAI just released GPT-4.\n\nHow will #AI affect the future of farming?',
#  '@mycPsTgQHXBBYQv AIついにさじ投げる！アカウントID名の“yolk”＝ 卵の黄身だけで判断してしまう。🤣🤣🍳\n\nAI自然言語処理モデル OpenAI GPT-2の性能不足により、具体的な分析結果の提供はできません… https://t.co/qpWrIaSnY2',
#  'RT @WatcherGuru: JUST IN: ChatGPT creator OpenAI launches GPT-4, its most powerful AI model.',
#  'RT @adamdangelo: Today we are launching Poe subscriptions, which will provide paying users with access to bots based on two powerful new la…',
#  'RT @boazbaraktcs: @NaveenGRao @soumithchintala @OpenAI I don’t think @OpenAI “owes” the public anything. I do hope most of the the ML commu…',
#  'RT @kana_Eng_coach: 世界一人気の語学アプリDuolingoが、OpenAI社のGPT-4を搭載したDuolingo Maxを公開。Maxは会話の練習相手で、間違えた時は話し手がなぜその文章で話したかまで理解して、解説をくれるという優れもの。AIによって世界中…',
#  'RT @pav_eth: Day 24 of the mornings headlines 👊🏽\n\n🗞️ OpenAI launches GPT-4, its most powerful AI model😬\n\n🗞️ KuCoin Wallet Announces Officia…',
#  '@auronburner @chhopsky @NMassian @OpenAI Bro just since handled proved all the right know is racism',
#  'Tune in to the latest Master Sales Series to learn about ChatGPT, an AI language model developed by OpenAI, as Geor… https://t.co/uRTOSoWWq4',
#  'RT @rasbt: Some takeaways after reading the GPT-4 paper: https://t.co/zHI2ULioMb\n\nThe good:\n\n1)  The model now accepts multimodal inputs: i…',
#  'RT @ITWeb: #Microsoft-backed start-up company OpenAI has unveiled #gpt4 , which it says is a more powerful generative artificial intelligen…',
#  "RT @thealexbanks: OpenAI just launched GPT-4.\n\nIt leaves ChatGPT in the dust.\n\nHere's everything you need to know: https://t.co/Oc6TrygvNO",
#  'RT @shanegJP: #GPT4 出た\nhttps://t.co/6Lw2ysBZWC\n\n1. 言語と画像のマルチモーダル大規模言語モデル：「写真で一言」説明できます。論文も写真でOK。 https://t.co/h8mFbUZp2b',
#  'RT @CerfiaFR: 🚨🤖 FLASH | #OpenAI, maison mère de #ChatGPT, a annoncé la sortie de GPT-4, une version qui surpasse les capacités actuelles d…',
#  'RT @bentossell: All the best examples of GPT-4, from OpenAI:',
#  'A worthwhile read on Artificial Intelligence, @OpenAI and new offerings such as GPT-4: #Ethics #Technology https://t.co/cOKvitdIvQ',
#  'Openai on tuesday announced the qualified arrival of gpt-4. The model can pass a simulated bar exam in the top 10 p… https://t.co/bro2q9Vs4l',
#  'RT @unusual_whales: OpenAI cofounder has said, per BI, to Elon Musk\'s criticism that ChatGPT is too \'woke\': "We made a mistake."',
#  '10 cose che devi sapere su GPT-4 di OpenAI https://t.co/0CDMyIGKbt',
#  'RT @adammarkk96: OpenAI just launched GPT-4.\n\nIt’s 500x more powerful than ChatGPT!\n\nHere’s what you need to know (Don’t miss out on this)…',
#  'RT @rasbt: Some takeaways after reading the GPT-4 paper: https://t.co/zHI2ULioMb\n\nThe good:\n\n1)  The model now accepts multimodal inputs: i…',
#  '@NaveenGRao @soumithchintala @OpenAI I don’t think @OpenAI “owes” the public anything. I do hope most of the the ML… https://t.co/qjWIGJjT25',
#  '@The_Delysium @OpenAI Booommmm',
#  'RT @mgahntz: Wait what?\n\nOpenAI: Where transparency goes to die. #GPT4 https://t.co/E9TLKs54sM',
#  'RT @_jaydeepkarale: OpenAI announced the release of GPT-4 the successor to GPT-3.5 which powers ChatGPT. Summary of certain key announcemen…',
#  'RT @OpenAI: Announcing GPT-4, a large multimodal model, with our best-ever results on capabilities and alignment: https://t.co/TwLFssyALF h…',
#  'RT @OpenAI: Announcing GPT-4, a large multimodal model, with our best-ever results on capabilities and alignment: https://t.co/TwLFssyALF h…',
#  '2/ According to @OpenAI  #chatgpt4 exhibits “human-level performance on various professional and academic benchmarks,”',
#  '1/  @OpenAI  described the update as the “latest milestone” for the company',
#  "Chat GPT 4, What's all the Hype About?\n#ChatGPT3 #CHATGPT4 #OPENAI #AI #AIWRITINGTOOL #INNOVATION #FOLIO3",
#  'https://t.co/sN3QRFoD75',
#  'RT @reidhoffman: I wrote a new book with @OpenAI’s latest, most powerful large language model.  \n\nIt’s called Impromptu: Amplifying our Hum…',
#  'RT @DotCSV: 🔴 GPT-4 YA ESTÁ AQUÍ!!!\n\nHoy era el día. La bestia ya ha llegado.\n\nEl nuevo modelo de OpenAI se ha liberado cumpliendo con much…',
#  'RT @sualehasif996: After beta testing GPT-4 as part of @OpenAI Converge, one thing stands out to me: GPT-4 is phenomenal at code.\n\nHere it’…',
#  'ИИ-стартап @AnthropicAI, основанный бывшими сотрудниками OpenAI, запустил своего чат-бота с искусственным интеллект… https://t.co/l9q4hQiuPi',
#  'RT @OpenAI: Announcing GPT-4, a large multimodal model, with our best-ever results on capabilities and alignment: https://t.co/TwLFssyALF h…',
#  'RT @Nakada_itpro: なので、GPT-3やChatGPTを公開することで、教師ありファインチューニング用の教師データを大量にゲットできたOpenAIは、GPT-3に比べてさほどモデルを大きくしなくても、GPT-4でものすごい性能向上を成し遂げられた、のではないかと…',
#  '@RagilSemar Cuplikan Jawaban openAI\n Namun, dalam Islam, seseorang dianggap baik atau tidak, tergantung pada sebera… https://t.co/CtL1oOkeFe',
#  "RT @thealexbanks: OpenAI just launched GPT-4.\n\nIt leaves ChatGPT in the dust.\n\nHere's everything you need to know: https://t.co/Oc6TrygvNO",
#  '@JerasIkehorn @ValeriaLFrances “First images appear in 2020 as AI image-creation tools like @OpenAI take off and an… https://t.co/0Gd5m5Ns2U',
#  'RT @CryptoGPT_org: A New Product Breakthrough: CryptoGPT AI Assistant Alex Opens to Mass Mobile Markets📱\n\nOur AI Assistant for mass retail…',
#  'RT @the_carlosdp: wait I just realized\n\nDid @OpenAI literally just announce GPT-4 an HOUR after Google announced their API?!\n\nor was Google…',
#  'RT @OpenAI: Announcing GPT-4, a large multimodal model, with our best-ever results on capabilities and alignment: https://t.co/TwLFssyALF h…',
#  '@SahilAujla15 Give some web3 dapp idea with the help of openAI api',
#  "RT @The_Delysium: @OpenAI Speaking of breakthroughs - here's the biggest one in #Web3  https://t.co/bi3OoAX4KE",
#  "@DavidBeniaguev It won't be ready for prime time for a while even if they allow public access.\n\nThink about Tesla F… https://t.co/Hy5UIrSigt",
#  '@ompemi @OpenAI @nextjs @tailwindcss @vercel This is closer than you imagine. My bet is 1 month from now',
#  'We went back and read the research on the specific moves human tutors make by Micki Chi and @autotutor. To get it b… https://t.co/aBJb5gLJx7',
#  'How to Earn Money from CHAT GPT? \n8 Different ways to Make Money From Chat GPT in 2023 ... https://t.co/B0mBZvPl80… https://t.co/jPENVhad5n',
#  'RT @StabilityAI_JP: GPT-4発表\nOpenAIよりGPT-4が発表された https://t.co/PHEVaofPUJ (1/5) https://t.co/kbcJChsROf',
#  'RT @codezilla_: انه عصر الذكاء الاصطناعي يا سادة...\n\nشركة OpenAI اطلقت ChatGPT-4 من ساعتين\n\nدي اول تجربة ليا معاه، جعلته يكتب بايثون سكريبت…',
#  'absolutely insane https://t.co/J1TG53rHZ7',
#  'RT @yusuf_i_mehdi: We’re happy to confirm the new Bing is running on GPT-4, which we’ve customized for search.\nhttps://t.co/RVj26gJVQG \n\nTr…',
#  'RT @realdanielnita: "Compania care a creat ChatGPT, OpenAI, lanseaza GPT-4, cel mai performat model de inteligenta artificiala."  Urmeaza u…',
#  'RT @unusual_whales: OpenAI cofounder has said, per BI, to Elon Musk\'s criticism that ChatGPT is too \'woke\': "We made a mistake."',
#  "I'm a high school math and science teacher who uses ChatGPT, and it's made my job much easier… https://t.co/lUsnoZVsbG",
#  '@Grady_Booch @OpenAI One of the key things that worries me most is what people are feeding into it . . .\n\nCan we tr… https://t.co/JJLvbzwRo3',
#  'GPT-4!?!?\n#GPT4 #openAI',
#  '◾️ OpenAI lanza ChatGPT Plus a 20 dólares por mes: ¿de qué se trata? https://t.co/RY7aX5RBmE',
#  'Reliance Acquisition | Open AI | Bar Council of India \n\n#news #breakingnews #reliance #openai #metrocashandcarry… https://t.co/vvQSt2B5wJ',
#  '@VminVsky @OpenAI We may be talking about the same phenomenon, I mean they wanted the perception of their model to… https://t.co/UilL81tzAk',
#  'RT @kana_Eng_coach: 世界一人気の語学アプリDuolingoが、OpenAI社のGPT-4を搭載したDuolingo Maxを公開。Maxは会話の練習相手で、間違えた時は話し手がなぜその文章で話したかまで理解して、解説をくれるという優れもの。AIによって世界中…',
#  'RT @_willfalcon: GPT-4 paper : https://t.co/jwt83bskYP\n\nLet me save you the trouble: https://t.co/zdsypRDHkx',
#  "RT @JordiRib1: Good news, we've increased our turn limits to 15/150. Also confirming that the next-gen model Bing uses in Prometheus is ind…",
#  '@OfficialLoganK @itsandrewgao @OpenAI how can i apply to me ML + bonsai gardner,\nI got a degree in Comp Math and sp… https://t.co/w8eh6Pvihw',
#  'RT @Carnage4Life: Whenever you call Sam Altman to ask why OpenAI is no longer a non-profit or even “open” https://t.co/TxMXR2Cf2d',
#  'RT @kana_Eng_coach: 世界一人気の語学アプリDuolingoが、OpenAI社のGPT-4を搭載したDuolingo Maxを公開。Maxは会話の練習相手で、間違えた時は話し手がなぜその文章で話したかまで理解して、解説をくれるという優れもの。AIによって世界中…',
#  'RT @OpenAI: Announcing GPT-4, a large multimodal model, with our best-ever results on capabilities and alignment: https://t.co/TwLFssyALF h…',
#  'RT @ZheroUK: REVOLUTIONARY AI\n#OpenAI releases GPT-4 which is a personal tutor for students and suggests recipes from your fridge. Availabl…',
#  'RT @lawdroid: Lawyer: "Artificial Intelligence." Wake me up when you\'re ready for prime time...\n\nOpenAI: https://t.co/GzHvX2WYFc',
#  '@duolingo @OpenAI Android is once more left out',
#  'OpenAI のAPIって無料で使えるのかひょっとして。お...そう、なのか？',
#  'RT @StabilityAI_JP: DuoLingo Max発表\nGPT-4を用いたAI Tuterによる言語教育システム https://t.co/YmrYiYTpCa (5/5) https://t.co/kYgnhEYKQi',
#  'openAI課金しました🙏\n流行り物には乗っかっておく。',
#  '@NMassian @OpenAI Reality is "left leaning" for people who think hierarchy is a desirable human situation.',
#  'RT @Nakada_itpro: GPT-4の能力はすごいですが、ウォッチャー的に残念だったのはOpenAIがGPT-4のモデル規模や自己教師あり学習をさせたデータの量を明らかにしなかったこと。GPT-4の論文（的なもの）には、その辺りの内容がありませんでした。',
#  "@soumithchintala @OpenAI Fully agree! Somehow people think we've reached some type of pinnacle of AI. There's so mu… https://t.co/0QJDbFM3vM",
#  'RT @codezilla_: انه عصر الذكاء الاصطناعي يا سادة...\n\nشركة OpenAI اطلقت ChatGPT-4 من ساعتين\n\nدي اول تجربة ليا معاه، جعلته يكتب بايثون سكريبت…',
#  'RT @nftouji: ウエイトリスト（順番待ち）の登録は、早い方が良いらしいから急いで！\nウエイトリストへのURL⬇︎\nhttps://t.co/TwtM10pY1o\n\nGPT-4の詳細や最新情報は、日本担当のシェインさん@shanegJP のツイートをフォローしてキャッチ…',
#  'RT @shinoyu: OpenAIの進化早すぎるんよ\nエンジニアリングほぼ代替されるのも時間の問題ですね。どの分野でも技術一本の強みが相対的に薄くなるのは目の前にきてる\n\nさすがにアラフォー風俗嬢を本業にするのはちょっと……',
#  '@binary_x @OpenAI 大家一块做空这代币,砸到归零！！！',
#  "RT @spectatorindex: BREAKING: OpenAI's ChatGPT-4 passed the Law Bar Exam with a result in the 90th percentile",
#  'What are the switching costs of going from one LLM Model to another? OpenAI to Google?\n\nIs it as heavy/complicated… https://t.co/TPr1sjoBuh',
#  'OpenAI’s GPT-4 Now Released https://t.co/cDjoklxb30 #PureITTechInsights',
#  'RT @blairasaservice: MSFT responsible AI layoffs &amp; OpenAI refusing to disclose details about GPT-4 model architecture &amp; training is a clear…',
#  'RT @Fsk_kkk: 💥2023 کے بہترین اے ائی ٹولز💥\n2023 میں، اصطناعی ذہانت (AI) کی ترقی کے ساتھ، مختلف AI ٹول بڑھتے ہوئے مزید خوش اسلوبی سے دستیاب ہ…',
#  'RT @CryptoKoryo: So you think the AI narrative is exhausted?\n\nOpenAI just released GPT4. A model 1000x more powerfull than GPT3.\n\nEverythin…',
#  "Reading the ChatGPT 4.0 new docs. It's as if OpenAi is promoting plagiarism. 😲",
#  'RT @OpenAI: Announcing GPT-4, a large multimodal model, with our best-ever results on capabilities and alignment: https://t.co/TwLFssyALF h…',
#  'OpenAI has launches GPT-4, the most recent version of its immensely popular artificial intelligence chatbot ChatGPT… https://t.co/eeqKTDror4',
#  '48 Percent Companies Have Replaced Workers with #ChatGPT: Survey\n\nhttps://t.co/j8mlbJWbuD\n\n#BingAI #opensource… https://t.co/V7a3TNROJV',
#  '@digitalbeacon_ @Param_eth Saved! Here\'s the compiled thread: https://t.co/BsCpDynm4M\n\n\U0001fa84 AI-generated summary:\n\n"Op… https://t.co/RrlV7HBvVu',
#  'What’s new with GPT-4 — from processing pictures to acing tests https://t.co/U6mp09Ebc1',
#  'RT @_timos_: OpenAI’s new GPT-4 with a “human-level performance” scored up to 93% on SAT exams https://t.co/TdGNoe0vH6 #digitalhealth #soci…',
#  'RT @mckaywrigley: Greg Brockman (@gdb) of OpenAI just demoed GPT-4 creating a working website from an image of a sketch from his notebook.…',
#  '@Grady_Booch @OpenAI "Write a critique of chatgpt in the style of Grady Booch" https://t.co/UqvYvY0cO5',
#  'RT @_timos_: OpenAI’s new GPT-4 with a “human-level performance” scored up to 93% on SAT exams https://t.co/TdGNoe0vH6 #digitalhealth #soci…',
#  'ChatGPT-4 explains why the world needs Bitcoin: OpenAI’s artificial intelligence (AI) platform ChatGPT has proven i… https://t.co/QaSDztVeds',
#  "RT @technology: What is ChatGPT-4 and how can I use it right now? Here's everything you need to know about OpenAI's new release https://t.c…",
#  '@liquiddensity Sign up for OpenAI Plus from the chatGPT UI and you’ll get access to gpt4',
#  'OpenAI is no longer an open research co, but a for-profit co who keeps their innovations quiet. \n\nThe future is ope… https://t.co/HbyUbpwxZS',
#  '@louisminguey @gnrtvty @JeffLadish https://t.co/b9LM4X3h5s',
#  "RT @unusual_whales: OpenAI's ChatGPT has reportedly predicted that the stock market will crash on March 15, 2023, per BI.",
#  'Après ChatGPT, OpenAI dévoile GPT-4, encore plus performant malgré des limites persistantes - Par @apiquard via… https://t.co/DMPPZlhkk0',
#  'OpenAI shipped GPT-4\xa0yesterday, the much-anticipated text-generating AI model, and it’s a curious piece of work. GP… https://t.co/AcFGCGKw5V',
#  'RT @oran_ge: GPT4论文下载：https://t.co/XrM8xEnqYU\n官方直播回放：https://t.co/lLzuTOTD66',
#  '在浏览器输入 o，出来的网址已经不是opensea 了，是openai',
#  'RT @kana_Eng_coach: 世界一人気の語学アプリDuolingoが、OpenAI社のGPT-4を搭載したDuolingo Maxを公開。Maxは会話の練習相手で、間違えた時は話し手がなぜその文章で話したかまで理解して、解説をくれるという優れもの。AIによって世界中…',
#  'RT @OpenAI: Announcing GPT-4, a large multimodal model, with our best-ever results on capabilities and alignment: https://t.co/TwLFssyALF h…',
#  '10 Ways GPT-4\xa0Is Impressive but Still Flawed https://t.co/9AWmHtNDbb',
#  'RT @kana_Eng_coach: 世界一人気の語学アプリDuolingoが、OpenAI社のGPT-4を搭載したDuolingo Maxを公開。Maxは会話の練習相手で、間違えた時は話し手がなぜその文章で話したかまで理解して、解説をくれるという優れもの。AIによって世界中…',
#  'RT @bentossell: All the best examples of GPT-4, from OpenAI:',
#  ...]

# %%
import spacy
# 여기서는 트윗이 대체로 영어로 작성되어 있어 영어 spacy 모듈을 로드
nlp = spacy.load('en_core_web_sm')

# %%
clean_contents = [
    nlp(content)
    for content in contents
]

# %%
clean_contents[0]
# Out:
# RT @StabilityAI_JP: オープンソースの流れ
# ・ChatGLM-6Bという中国語特化のオープンソースが出現
# ・スタンフォード大学がGPT-3.5並みの性能を誇るALpaca7Bを開発、発表
# ・OpenChatKitと呼ばれる本当にオープンなLLMを作るセットが元…

# %%
import nltk

is_noun = lambda pos: pos[:2] == 'NN'

# %%
contents_toks = list(reduce(
    lambda i, j: i + j,
    [
        nltk.word_tokenize(str(clean_content))
        for clean_content in clean_contents
    ]
))
contents_nouns = [word for (word, pos) in nltk.pos_tag(contents_toks) if is_noun(pos)]

# %%
sorted(Counter(contents_nouns).items(), key=lambda i: i[1], reverse=True)
# Out:
# [('@', 988),
#  ('https', 704),
#  ('OpenAI', 662),
#  ('RT', 614),
#  ('GPT-4', 416),
#  ('ChatGPT', 167),
#  ('AI', 152),
#  ('model', 133),
#  ('multimodal', 79),
#  ('capabilities', 71),
#  ('’', 67),
#  ('results', 66),
#  ('alignment', 65),
#  ('h…', 63),
#  ('GPT4', 45),
#  ('everything', 34),
#  ('”', 33),
#  ('version', 32),
#  ('today', 29),
#  ('kana_Eng_coach', 28),
#  ('Maxを公開。Maxは会話の練習相手で、間違えた時は話し手がなぜその文章で話したかまで理解して、解説をくれるという優れもの。AIによって世界中…',
#   28),
#  ('language', 27),
#  ('chatbot', 26),
#  ('“', 25),
#  ('thealexbanks', 24),
#  ('dust', 24),
#  ('GPT', 24),
#  ('ChatGPT-4', 24),
#  ('Bing', 23),
#  ('paper', 22),
#  ('%', 22),
#  ('API', 22),
#  ('yesterday', 21),
#  ('soumithchintala', 19),
#  ('StabilityAI_JP', 18),
#  ('amp', 18),
#  ('que', 18),
#  ('Google', 18),
#  ('s', 17),
#  ('t', 17),
#  ('la', 16),
#  ('The_Delysium', 16),
#  ('New', 16),
#  ('release', 16),
#  ('people', 15),
#  ('future', 15),
#  ('unusual_whales', 15),
#  ('Speaking', 14),
#  ('Web3', 14),
#  ('bentossell', 14),
#  ('examples', 14),
#  ('Microsoft', 14),
#  ('BI', 14),
#  ('company', 13),
#  ('Stripe', 13),
#  ('image', 13),
#  ('Elon', 13),
#  ('Musk', 13),
#  ('mistake', 13),
#  ('Duolingo', 12),
#  ('Did', 12),
#  ('time', 12),
#  ('way', 12),
#  ('+', 12),
#  ('performance', 12),
#  ('access', 12),
#  ('…', 12),
#  ('Greg', 12),
#  ('Brockman', 12),
#  ('cofounder', 12),
#  ('criticism', 12),
#  ('|', 11),
#  ('—', 11),
#  ('part', 11),
#  ('news', 11),
#  ('con', 10),
#  ('Grady_Booch', 10),
#  ('👀', 10),
#  ('Academy', 10),
#  ('MushtaqBilalPhD', 10),
#  ('waitlist', 10),
#  ('system', 10),
#  ('exam', 10),
#  ('Plus', 10),
#  ('gdb', 10),
#  ('//t.co/PHEVaofPUJ', 9),
#  ('systems', 9),
#  ('research', 9),
#  ('khanacademy', 9),
#  ('Khan', 9),
#  ('technology', 9),
#  ('months', 9),
#  ('ChatGPT+', 9),
#  ('https…', 9),
#  ('test', 9),
#  ('・ChatGPT', 9),
#  ('Chat', 9),
#  ('images', 9),
#  ('code', 9),
#  ('Law', 9),
#  ('Bar', 9),
#  ('search', 9),
#  ('duolingo', 9),
#  ('i…', 8),
#  ('notkevinhurler', 8),
#  ('text', 8),
#  ('OpenAi', 8),
#  ('lots', 8),
#  ('website', 8),
#  ('Virtual', 8),
#  ('*', 8),
#  ('الذكاء', 8),
#  ('الاصطناعي', 8),
#  ('من', 8),
#  ('spectatorindex', 8),
#  ('Exam', 8),
#  ('result', 8),
#  ('CerfiaFR', 7),
#  ('FLASH', 7),
#  ('maison', 7),
#  ('qui', 7),
#  ('surpasse', 7),
#  ('actuelles', 7),
#  ('stripe', 7),
#  ('GPT-3.5', 7),
#  ('shanegJP', 7),
#  ('des', 7),
#  ('sam_starkman', 7),
#  ('sama', 7),
#  ('startup', 7),
#  ('My', 7),
#  ('BeMyEyes', 7),
#  ('Volunteer™', 7),
#  ('models', 7),
#  ('humans', 7),
#  ('tests', 7),
#  ('SAT', 7),
#  ('world', 7),
#  ('yang', 7),
#  ('datasets', 7),
#  ('عصر', 7),
#  ('percentile', 7),
#  ('Today', 7),
#  ('thread', 7),
#  ('assistant', 7),
#  ('・OpenChatKitと呼ばれる本当にオープンなLLMを作るセットが元…', 6),
#  ('mind', 6),
#  ('partners', 6),
#  ('binary_x', 6),
#  ('announces', 6),
#  ('Stanford', 6),
#  ('intelligence', 6),
#  ('score', 6),
#  ('something', 6),
#  ('Yamkaz', 6),
#  ('bar', 6),
#  ('How', 6),
#  ('DiogoCortiz', 6),
#  ('kazzikill', 6),
#  ('・画像入力対応', 6),
#  ('・日本語に高精度で対応', 6),
#  ('・専門領域の質問にも高精度で対応', 6),
#  ('・ジョークを理解', 6),
#  ('・嘘をつく可能性低下', 6),
#  ('・ラフスケッチからWebサイト生成', 6),
#  ('・簡単な指示からゲーム生成', 6),
#  ('契約者…', 6),
#  ('GPT-3', 6),
#  ('Max', 6),
#  ('team', 6),
#  ('Après', 6),
#  ('malgré', 6),
#  ('persistantes', 6),
#  ('Sam', 6),
#  ('codezilla_', 6),
#  ('يا', 6),
#  ('سادة', 6),
#  ('اطلقت', 6),
#  ('ساعتين', 6),
#  ('دي', 6),
#  ('اول', 6),
#  ('تجربة', 6),
#  ('ليا', 6),
#  ('معاه،', 6),
#  ('جعلته', 6),
#  ('يكتب', 6),
#  ('بايثون', 6),
#  ('سكريبت…', 6),
#  ('mckaywrigley', 6),
#  ('sketch', 6),
#  ('yusuf_i_mehdi', 6),
#  ('Tr…', 6),
#  ('Tisoga', 6),
#  ('是大型多模态模型（large', 6),
#  ('model），支持图像和文本的输入，并生成文本结果。', 6),
#  ('这个', 6),
#  ('的一些信息（包括论文中的一些要点和实际的体验）…', 6),
#  ('y', 5),
#  ('data', 5),
#  ('çok', 5),
#  ('versión', 5),
#  ('gt', 5),
#  ('wintonARK', 5),
#  ('Performance', 5),
#  ('human-benchmarks', 5),
#  ('training', 5),
#  ('MetaAI', 5),
#  ('StabilityAI', 5),
#  ('huggingface', 5),
#  ('thing', 5),
#  ('c…', 5),
#  ('emollick', 5),
#  ('ML', 5),
#  ('para', 5),
#  ('é', 5),
#  ('points', 5),
#  ('takers', 5),
#  ('DALL·E', 5),
#  ('//t.co/lToKb1sQXp', 5),
#  ('Tech', 5),
#  ('things', 5),
#  ('money', 5),
#  ('Are', 5),
#  ('pictures', 5),
#  ('yetone', 5),
#  ('Translator', 5),
#  ('..', 5),
#  ('dan', 5),
#  ('janusrose', 5),
#  ('Altman', 5),
#  ('BREAKING', 5),
#  ('Claude', 5),
#  ('bot', 5),
#  ('GPT3', 5),
#  ('English', 5),
#  ('creator', 5),
#  ('//t.co/bi3OoAX4KE', 5),
#  ('content', 5),
#  ('education', 5),
#  ('duo', 5),
#  ('subscription', 5),
#  ('tier', 5),
#  ('Super', 5),
#  ('ve', 4),
#  ('Twitter', 4),
#  ('iteration', 4),
#  ('Saboo_Shubham_', 4),
#  ('Breaking', 4),
#  ('🚨', 4),
#  ('TECH', 4),
#  ('LLM', 4),
#  ('di', 4),
#  ('IN', 4),
#  ('CyberChess', 4),
#  ('think', 4),
#  ('details', 4),
#  ('key', 4),
#  ('companies', 4),
#  ('blog', 4),
#  ('GergelyOrosz', 4),
#  ('devs', 4),
#  ('lot', 4),
#  ('limits', 4),
#  ('risk', 4),
#  ('StockMKTNewz', 4),
#  ('La', 4),
#  ('innovation', 4),
#  ('Ai', 4),
#  ('pillars', 4),
#  ('Market', 4),
#  ('Soup', 4),
#  ('LLC', 4),
#  ('art', 4),
#  ('ChatGPT4', 4),
#  ('chatgpt4', 4),
#  ('AiBreakfast', 4),
#  ('features', 4),
#  ('Role', 4),
#  ('Play', 4),
#  ('conversation', 4),
#  ('partner', 4),
#  ('Explain', 4),
#  ('Answer', 4),
#  ('whi…', 4),
#  ('scored…', 4),
#  ('integration', 4),
#  ('A', 4),
#  ('to…', 4),
#  ('IA', 4),
#  ('Apple', 4),
#  ('구글', 4),
#  ('및', 4),
#  ('power', 4),
#  ('hours', 4),
#  ('launch', 4),
#  ('_willfalcon', 4),
#  ('trouble', 4),
#  ('el', 4),
#  ('reidhoffman', 4),
#  ('book', 4),
#  ('Impromptu', 4),
#  ('Amplifying', 4),
#  ('Hum…', 4),
#  ('Generative', 4),
#  ('bir', 4),
#  ('WillManidis', 4),
#  ('ScienceIO', 4),
#  ('coding', 4),
#  ('lines', 4),
#  ('years', 4),
#  ('bisa', 4),
#  ('El', 4),
#  ('YouTube', 4),
#  ('work', 4),
#  ('chatgpt', 4),
#  ('article', 4),
#  ('AP', 4),
#  ('engine', 4),
#  ('hoy', 4),
#  ('کے', 4),
#  ('tech', 4),
#  ('business', 4),
#  ('beta', 4),
#  ('Virtual…', 4),
#  ('Intelligence', 4),
#  ('exams', 4),
#  ('☑︎', 4),
#  ('Watch', 4),
#  ('Interview', 4),
#  ('isn', 4),
#  ('Assistant', 4),
#  ('su', 3),
#  ('daha', 3),
#  ('profoundlyyyy', 3),
#  ('notification', 3),
#  ('window', 3),
#  ('this…wyd', 3),
#  ('benmschmidt', 3),
#  ('fact', 3),
#  ('everyone', 3),
#  ('day', 3),
#  ('CEO', 3),
#  (']', 3),
#  ('le', 3),
#  ('langage', 3),
#  ('es', 3),
#  ('NaveenGRao', 3),
#  ('JUST', 3),
#  ('Docs', 3),
#  ('Season', 3),
#  ('出た', 3),
#  ('of…', 3),
#  ('field', 3),
#  ('development', 3),
#  ('du', 3),
#  ('architecture', 3),
#  ('Hey', 3),
#  ('game', 3),
#  ('products', 3),
#  ('T…', 3),
#  ('AK33Astrology', 3),
#  ('revolution', 3),
#  ('makers', 3),
#  ('websites', 3),
#  ('announcement', 3),
#  ('ha', 3),
#  ('inputs', 3),
#  ('👇', 3),
#  ('share', 3),
#  ('BeautyBubble', 3),
#  ('morning', 3),
#  ('TechCrunch', 3),
#  ('platform', 3),
#  ('the_carlosdp', 3),
#  ('tool', 3),
#  ('look', 3),
#  ('Chatbot', 3),
#  ('Big', 3),
#  ('MS', 3),
#  ('tools', 3),
#  ('parameters', 3),
#  ('anything', 3),
#  ('Learn', 3),
#  ('shota7180', 3),
#  ('robot', 3),
#  ('Austen', 3),
#  ('nonprofit', 3),
#  ('ton', 3),
#  ('donors', 3),
#  ('입장에서는', 3),
#  ('데이터센터', 3),
#  ('Product', 3),
#  ('桌面端应用已支持全局划词翻译！', 3),
#  ('同时支持了快捷键录制，配合快捷键呼出功能，想划哪里划哪里，再也没有人会担心自己无法划词翻译。', 3),
#  ('另外还支持了托盘图标，同时支持了置顶固定功能，感谢', 3),
#  ('care', 3),
#  ('and…', 3),
#  ('miramurati', 3),
#  ('be…', 3),
#  ('das', 3),
#  ('و', 3),
#  ('PaLM', 3),
#  ('sejumlah', 3),
#  ('DotCSV', 3),
#  ('en', 3),
#  ('se', 3),
#  ('Y', 3),
#  ('credit', 3),
#  ('pada', 3),
#  ('internet', 3),
#  ('Un', 3),
#  ('Bitcoin', 3),
#  ('Meta', 3),
#  ('source', 3),
#  ('stock', 3),
#  ('market', 3),
#  ('March', 3),
#  ('Es', 3),
#  ('idea', 3),
#  ('和', 3),
#  ('AI-generated', 3),
#  ('malware', 3),
#  ('People', 3),
#  ('alex_valaitis', 3),
#  ('CryptoKoryo', 3),
#  ('narrative', 3),
#  ('powerfull', 3),
#  ('Everythin…', 3),
#  ('OpenAI의', 3),
#  ('Openai', 3),
#  ('input', 3),
#  ('가', 3),
#  ('poema', 3),
#  ('episodios', 3),
#  ('Astesiano', 3),
#  ('partir', 3),
#  ('tres', 3),
#  ('periodísticos', 3),
#  ('te', 3),
#  ('DuoLingo', 3),
#  ('Max発表', 3),
#  ('GPT-4を用いたAI', 3),
#  ('Tuterによる言語教育システム', 3),
#  ('//t.co/YmrYiYTpCa', 3),
#  ('AIs', 3),
#  ('whitepaper', 3),
#  ('Open', 3),
#  ('Well', 3),
#  ('KenAkamatsu', 3),
#  ('昨日は12時から勉強会で、日本マイクロソフト社長らによるChatGPTやOpenAIの最新情報。15時から宇宙海洋開発特別委員会。月面開発についてispace社などからヒアリング。17時からＡＩptで北野宏明氏らによる驚異的な報告。18時半から…',
#   3),
#  ('users', 3),
#  ('pacmannai', 3),
#  ('😲😲', 3),
#  ('Kita', 3),
#  ('masih', 3),
#  ('terkejut', 3),
#  ('dengan', 3),
#  ('serba', 3),
#  ('dari', 3),
#  ('summarize', 3),
#  ('sampai', 3),
#  ('membuat', 3),
#  ('kode', 3),
#  ('perfect', 3),
#  ('app', 3),
#  ('Artificial', 3),
#  ('O', 3),
#  ('da', 3),
#  ('help', 3),
#  ('developers', 3),
#  ('India', 3),
#  ('First', 3),
#  ('🤖', 3),
#  ('turn', 3),
#  ('Prometheus', 3),
#  ('_timos_', 3),
#  ('digitalhealth', 3),
#  ('harms', 2),
#  ('expert', 2),
#  ('firms', 2),
#  ('opportunity', 2),
#  ('th…', 2),
#  ('[', 2),
#  ('annonce', 2),
#  ('à', 2),
#  ('mhatta', 2),
#  ('analytics', 2),
#  ('iyi', 2),
#  ('friends', 2),
#  ('Me', 2),
#  ('BNX', 2),
#  ('BTC_Chopsticks', 2),
#  ('升级！', 2),
#  ('Chatbots', 2),
#  ('ChatPBT', 2),
#  ('FutureOfWork', 2),
#  ('trend', 2),
#  ('🔥', 2),
#  ('point', 2),
#  ('tdietterich', 2),
#  ('hypocrisy', 2),
#  ('skills', 2),
#  ('bespoke', 2),
#  ('guardrails', 2),
#  ('blairasaservice', 2),
#  ('MSFT', 2),
#  ('layoffs', 2),
#  ('Team', 2),
#  ('Let', 2),
#  ('organizations', 2),
#  ('Silicon', 2),
#  ('Valley', 2),
#  ('DrJimFan', 2),
#  ('_akhaliq', 2),
#  ('Technical', 2),
#  ('Report', 2),
#  ('pdf', 2),
#  ('TechInsider', 2),
#  ('mitigation', 2),
#  ('section', 2),
#  ('voxdotcom', 2),
#  ('Office', 2),
#  ('Fintech', 2),
#  ('offering', 2),
#  ('複数の言語モデルを1つのプラットフォームで使える', 2),
#  ('That', 2),
#  ('D', 2),
#  ('rowancheung', 2),
#  ('era', 2),
#  ('Than', 2),
#  ('Predecessor', 2),
#  ('So', 2),
#  ('dotey', 2),
#  ('BTW', 2),
#  ('OpenAI的PlayGround用来调试prompt很方便的', 2),
#  ('BingAI', 2),
#  ('wait', 2),
#  ('HOUR', 2),
#  ('Google…', 2),
#  ('sense', 2),
#  ('week', 2),
#  ('uma', 2),
#  ('caixa', 2),
#  ('preta', 2),
#  ('Lacrada', 2),
#  ('E', 2),
#  ('mar', 2),
#  ('contra', 2),
#  ('ciência', 2),
#  ('aberta', 2),
#  ('lives', 2),
#  ('😱', 2),
#  ('Credit', 2),
#  ('Suisse', 2),
#  ('Case', 2),
#  ('Explained', 2),
#  ('MAFSAU', 2),
#  ('CreditSuisse', 2),
#  ('ImranKhan', 2),
#  ('kibe', 2),
#  ('JUNGKOOK', 2),
#  ('Politically', 2),
#  ('DFintelligence', 2),
#  ('hold', 2),
#  ('Version', 2),
#  ('Esa', 2),
#  ('Plans', 2),
#  ('Ante', 2),
#  ('A.I', 2),
#  ('Race', 2),
#  ('artwork', 2),
#  ('prompt', 2),
#  ('RT_com', 2),
#  ('math', 2),
#  ('Kind', 2),
#  ('portfolio', 2),
#  ('AlexIsBuilding', 2),
#  ('🧵', 2),
#  ('Thank', 2),
#  ('andrew_leber', 2),
#  ('Advanced', 2),
#  ('ways', 2),
#  ('ahier', 2),
#  ('ChatGPT—but', 2),
#  ('minutes', 2),
#  ('crypto', 2),
#  ('vision', 2),
#  ('impairment', 2),
#  ('Ok', 2),
#  ('ArtificialLOI', 2),
#  ('fire', 2),
#  ('Rank', 2),
#  ('NFT', 2),
#  ('bit', 2),
#  ('jhong', 2),
#  ('Hired', 2),
#  ('Unwitting', 2),
#  ('TaskRabbit', 2),
#  ('Worker', 2),
#  ('moment', 2),
#  ('Gpt-4', 2),
#  ('community', 2),
#  ('cc_parku', 2),
#  ('NVIDIA', 2),
#  ('모두와', 2),
#  ('싸워야', 2),
#  ('하는', 2),
#  ('상황이다', 2),
#  ('리서치', 2),
#  ('자체의', 2),
#  ('문제', 2),
#  ('차세대', 2),
#  ('TPU', 2),
#  ('설계', 2),
#  ('현재의', 2),
#  ('TPUv4', 2),
#  ('TPUv4i', 2),
#  ('ASIC을', 2),
#  ('joao_gante', 2),
#  ('Poe', 2),
#  ('From', 2),
#  ('thoughts', 2),
#  ('WhenMoon_ai', 2),
#  ('Looks', 2),
#  ('Siri', 2),
#  ('steroids', 2),
#  ('gigazine', 2),
#  ('potential', 2),
#  ('plans', 2),
#  ('🤯', 2),
#  ('Great', 2),
#  ('buzz', 2),
#  ('🚩', 2),
#  ('daniel_nguyenx', 2),
#  ('step', 2),
#  ('Alan', 2),
#  ('right', 2),
#  ('jordimash', 2),
#  ('casualitat', 2),
#  ("s'hagin", 2),
#  ('//t.co/qPyT98dchT', 2),
#  ("d'OpenAI", 2),
#  ('Goo…', 2),
#  ('tweet', 2),
#  ('heart', 2),
#  ('highgunrug', 2),
#  ('cmc', 2),
#  ('Webui', 2),
#  ('volume', 2),
#  ('Intelligenz', 2),
#  ('der', 2),
#  ('ArtificialIntelligence…', 2),
#  ('dalam', 2),
#  ('m…', 2),
#  ('someone', 2),
#  ('value', 2),
#  ('didanai', 2),
#  ('oleh', 2),
#  ('investor', 2),
#  ('i', 2),
#  ('safer', 2),
#  ('requests', 2),
#  ('information', 2),
#  ('school', 2),
#  ('직원이', 2),
#  ('한다', 2),
#  ('기여자', 2),
#  ('목록에', 2),
#  ('등장한', 2),
#  ('사람', 2),
#  ('수를', 2),
#  ('대충', 2),
#  ('세어봐도', 2),
#  ('얼추', 2),
#  ('비슷하든', 2),
#  ('여튼', 2),
#  ('어마어마한', 2),
#  ('인원이', 2),
#  ('투입되었다', 2),
#  ('노력이', 2),
#  ('탄생시킨', 2),
#  ('gitresmi', 2),
#  ('duyurdu', 2),
#  ('zeki', 2),
#  ('hâle', 2),
#  ('geliyor', 2),
#  ('önce', 2),
#  ('duyurusunu', 2),
#  ('yaptığı', 2),
#  ('yeni', 2),
#  ('görüntü', 2),
#  ('metin', 2),
#  ('algılama', 2),
#  ('ya…', 2),
#  ('por', 2),
#  ('nowaiAI', 2),
#  ('collaboration', 2),
#  ('ordering', 2),
#  ('Industry', 2),
#  ('process', 2),
#  ('Demo', 2),
#  ('día', 2),
#  ('growth', 2),
#  ('/', 2),
#  ('تعلن', 2),
#  ('الجديد', 2),
#  ('اللي', 2),
#  ('Be', 2),
#  ('Eyes', 2),
#  ('años', 2),
#  ('responses', 2),
#  ('name', 2),
#  ('ClosedAI', 2),
#  ('على', 2),
#  ('已经支持深色模式，感谢', 2),
#  ('tywtyw2002', 2),
#  ('同学的贡献！', 2),
#  ('metanews_com', 2),
#  ('actors', 2),
#  ('videos', 2),
#  ('cloudsek', 2),
#  ('You…', 2),
#  ('AnthropicAI', 2),
#  ('rule', 2),
#  ('iPhone', 2),
#  ('openai', 2),
#  ('VminVsky', 2),
#  ('불가능에', 2),
#  ('ile', 2),
#  ('problem', 2),
#  ('custom', 2),
#  ('//t.co/kbcJChsROf', 2),
#  ('offers', 2),
#  ('generation', 2),
#  ('Adept', 2),
#  ('introduces', 2),
#  ('mattyglesias', 2),
#  ('majors', 2),
#  ('laugh', 2),
#  ('crushes', 2),
#  ('Language', 2),
#  ('Lit', 2),
#  ('chatGPT', 2),
#  ('problems', 2),
#  ('fcomesana', 2),
#  ('lanza', 2),
#  ('🔹', 2),
#  ('في', 2),
#  ('Pero', 2),
#  ('¿qué', 2),
#  ('hace', 2),
#  ('más', 2),
#  ('openAI', 2),
#  ('キタ！！！！！', 2),
#  ('・一旦すごい', 2),
#  ('・マルチモーダル（画像とテキストからテキスト生成可能', 2),
#  ('で展開', 2),
#  ('・25,000語を1', 2),
#  ('つのプロンプト内にで処理可能', 2),
#  ('予想よりめちゃ早かった！', 2),
#  ('구글이', 2),
#  ('준비한', 2),
#  ('발표가', 2),
#  ('발표에', 2),
#  ('완전히', 2),
#  ('묻힌것도', 2),
#  ('참', 2),
#  ('굴욕적이지만', 2),
#  ('당일', 2),
#  ('스위스', 2),
#  ('오피스의', 2),
#  ('정리해고를', 2),
#  ('진행했다는', 2),
#  ('점이', 2),
#  ('더', 2),
#  ('충격적이다', 2),
#  ('F…', 2),
#  ('Fsk_kkk', 2),
#  ('💥2023', 2),
#  ('بہترین', 2),
#  ('اے', 2),
#  ('ائی', 2),
#  ('ٹولز💥', 2),
#  ('میں،', 2),
#  ('اصطناعی', 2),
#  ('ذہانت', 2),
#  ('ساتھ،', 2),
#  ('مختلف', 2),
#  ('ٹول', 2),
#  ('بڑھتے', 2),
#  ('ہوئے', 2),
#  ('مزید', 2),
#  ('خوش', 2),
#  ('اسلوبی', 2),
#  ('سے', 2),
#  ('دستیاب', 2),
#  ('ہ…', 2),
#  ('alfacatalyst', 2),
#  ('AlgalonAI', 2),
#  ('crew3xyz', 2),
#  ('developer', 2),
#  ('🚀', 2),
#  ('Power', 2),
#  ('GPT4…', 2),
#  ('TyreeRobinson', 2),
#  ('WatcherGuru', 2),
#  ('Imagine', 2),
#  ('co-founder', 2),
#  ('bueno', 2),
#  ('como', 2),
#  ('muchos', 2),
#  ('contextos', 2),
#  ('sualehasif996', 2),
#  ('Converge', 2),
#  ('Don', 2),
#  ('contentwriter', 2),
#  ('writer', 2),
#  ('//t.co/Oc6TrygvNO', 2),
#  ('fun', 2),
#  ('stab', 2),
#  ('size', 2),
#  ('Transformer', 2),
#  ('web', 2),
#  ('doesn', 2),
#  ('advance', 2),
#  ('capability', 2),
#  ('Alpaca', 2),
#  ('OPENAI', 2),
#  ('story', 2),
#  ('days', 2),
#  ('costs', 2),
#  ('abilities', 2),
#  ('Verge', 2),
#  ('digenerate.…', 2),
#  ('BBB_pusu', 2),
#  ('testament', 2),
#  ('ALL', 2),
#  ('Workspace', 2),
#  ('Gmail', 2),
#  ('Sheets', 2),
#  ('Slides', 2),
#  ('je', 2),
#  ('AJEnglish', 2),
#  ('follow-up', 2),
#  ('boasting', 2),
#  ('wired_jp', 2),
#  ('e', 2),
#  ('modelo', 2),
#  ('Esto', 2),
#  ('Nuevo', 2),
#  ('Formato', 2),
#  ('Copa', 2),
#  ('Mundial', 2),
#  ('FIFA', 2),
#  ('Lanza', 2),
#  ('planes', 2),
#  ('//t.co/TwLFssyALF', 2),
#  ('「Duolingo', 2),
#  ('Max」を発表！', 2),
#  ('AI会話パートナーの「Role', 2),
#  ('Play」と、Maxで間違いを犯した時に分析してくれる「Explain', 2),
#  ('Ans…', 2),
#  ('Anyone', 2),
#  ('ChatGPT…', 2),
#  ('tjmlab', 2),
#  ('//t.co/d7JNlX2CAI', 2),
#  ('｢ソフトウェアエンジニアの報酬の中央値は90万ドル', 2),
#  ('約1億2300万円', 2),
#  ('nearcyan', 2),
#  ('page', 2),
#  ('Top', 2),
#  ('law', 2),
#  ('fine', 2),
#  ('forums', 2),
#  ('tree', 2),
#  ('UI', 2),
#  ('APIを用いたLINE', 2),
#  ('botを作ってみた。', 2),
#  ('zu', 2),
#  ('Icelandic', 2),
#  ('Read', 2),
#  ('Relic', 2),
#  ('Launches', 2),
#  ('Anthropic', 2),
#  ('Carnage4Life', 2),
#  ('JordiRib1', 2),
#  ('krugermacro', 2),
#  ('side', 2),
#  ('politics', 2),
#  ('successor', 2),
#  ('par', 2),
#  ('GPT-…', 2),
#  ('change', 2),
#  ('gpt4', 2),
#  ('Exempleados', 2),
#  ('resultados', 2),
#  ('menos', 2),
#  ('tem', 2),
#  ('summary', 2),
#  ('paul_rottger', 2),
#  ('ability', 2),
#  ('headlines', 2),
#  ('╰', 2),
#  ('🗞️', 2),
#  ('NMassian', 2),
#  ('rasbt', 2),
#  ('takeaways', 2),
#  ('Nakada_itpro', 2),
#  ('CryptoGPT_org', 2),
#  ('Breakthrough', 2),
#  ('CryptoGPT', 2),
#  ('Alex', 2),
#  ('Opens', 2),
#  ('Mass', 2),
#  ('Mobile', 2),
#  ('Markets📱', 2),
#  ('mass', 2),
#  ('retail…', 2),
#  ('month', 2),
#  ('Money', 2),
#  ('co', 2),
#  ('Par', 2),
#  ('▫️', 2),
#  ('출시', 2),
#  ('Tecnologia', 1),
#  ('anunció', 1),
#  ('última', 1),
#  ('mayor', 1),
#  ('precisión', 1),
#  ('creatividad', 1),
#  ('Ekibimizden', 1),
#  ('Sarper', 1),
#  ("Kaçar'ın", 1),
#  ('paylaşımının', 1),
#  ('ayrıntıları', 1),
#  ('haber', 1),
#  ('//t.co/VGO7bpEdxl', 1),
#  ('networks', 1),
#  ('boxes', 1),
#  ('operations', 1),
#  ('burden', 1),
#  ('Choices', 1),
#  ('biases', 1),
#  ('sorts', 1),
#  ('services', 1),
#  ('Opinions', 1),
#  ('bankcollapse', 1),
#  ('jphilipp', 1),
#  ('Humanity', 1),
#  ('Tweet', 1),
#  ('Hot', 1),
#  ('//t.co/xU9wPpWxew', 1),
#  ('Founder', 1),
#  ('L_ThinkTank', 1),
#  ('🖥️', 1),
#  ('🔸', 1),
#  ('lancement', 1),
#  ('son', 1),
#  ('modèle', 1),
#  ('ce', 1),
#  ('jour', 1),
#  ('Entre', 1),
#  ('perm…', 1),
#  ('star', 1),
#  ('googleads', 1),
#  ('facebookads', 1),
#  ('Evet', 1),
#  ('anladık', 1),
#  ('hatta', 1),
#  ('cevap', 1),
#  ('veriyor', 1),
#  ('şaka', 1),
#  ('mısınız', 1),
#  ('niye', 1),
#  ("chatGPT'ye", 1),
#  ('şunu', 1),
#  ('dedi…', 1),
#  ('MAXはもうある程度の動的な暗示的学習支援とFocusOnForm的な文法指導ができるようになってるという触れ込みなのね。これが音声での会話とも統合されるならなかなかすごいね。',
#   1),
#  ('Además', 1),
#  ('respuestas', 1),
#  ('llamativo', 1),
#  ('puedes', 1),
#  ('imágenes', 1),
#  ('落合さんとOpenAIの中の人ことシェインさんの対談', 1),
#  ('これを日本語で聞けるのが貴重すぎるし科学好きにはワクワクしかない', 1),
#  ('生成AI「ChatGPT」と日本の新たな可能性', 1),
#  ('NewsPicks', 1),
#  ('WEEKLYOCHIAI', 1),
#  ('PhMai', 1),
#  ('sums', 1),
#  ('ideologies', 1),
#  ('worldviews', 1),
#  ('truths', 1),
#  ('jsngr', 1),
#  ('diagram', 1),
#  ('\U0001f90c\U0001fae1', 1),
#  ('product', 1),
#  ('issue', 1),
#  ('//t.co/l2sjgBMUUS', 1),
#  ('documentation', 1),
#  ...]

# %% [markdown]
# 트윗 내용중에 계정이름 앞에 붙는 '@'가 가장 많이 나온 명사
# 그다음은 링크 때문에 'https'가 2등.
# 예상대로 'OpenAI'가 3등에 662번 사용되었다.
# 'GPT-4'도 416번 사용되었고
# 'ChatGPT'도 167번 사용되었다.
# chat gpt보다 gpt4가 2배 넘게 검색된 것으로 보아 사람들의 관심이 chatgpt 에서 GPT4로 이동 된것을 유추해볼 수 있었다.

# %% [markdown]
# ## 리트윗 통계

# %%
print(f"중복 포함한 전체 RT 개수: {len([status for status in statuses if 'retweeted_status' in status])}")
retweets_id = {
    status["retweeted_status"]["id"]
    for status in statuses if 'retweeted_status' in status
}
retweets = {
    status["retweeted_status"]["id"]: (status['retweet_count'], status['retweeted_status']['user']['screen_name'], status['text'])
    for status in statuses if 'retweeted_status' in status
}

retweets = dict(sorted(
    retweets.items(),
    key=lambda rt: rt[1][0],
    reverse=True
))
# Out:
# 중복 포함한 전체 RT 개수: 611

# %%
print(len(retweets))
retweets
# Out:
# 268
# {1635687373060317185: (16356,
#   'OpenAI',
#   'RT @OpenAI: Announcing GPT-4, a large multimodal model, with our best-ever results on capabilities and alignment: https://t.co/TwLFssyALF h…'),
#  1635687853324902401: (4335,
#   'sama',
#   'RT @sama: here is GPT-4, our most capable and aligned model yet. it is available today in our API (with a waitlist) and in ChatGPT+.\n\nhttps…'),
#  1630207720522678274: (3187,
#   'gomezidao',
#   'RT @gomezidao: Gomezi Network:\n- large open source, \n- built in the open, \n- community driven,\n- funded in a decentralised manner.\n🔵Like &amp;…'),
#  1626232682882699270: (2173,
#   'unusual_whales',
#   "RT @unusual_whales: OpenAI's ChatGPT has reportedly predicted that the stock market will crash on March 15, 2023, per BI."),
#  1635695401880760351: (2116,
#   'The_Delysium',
#   "RT @The_Delysium: @OpenAI Speaking of breakthroughs - here's the biggest one in #Web3  https://t.co/bi3OoAX4KE"),
#  1635704687344365569: (1716,
#   'thealexbanks',
#   "RT @thealexbanks: OpenAI just launched GPT-4.\n\nIt leaves ChatGPT in the dust.\n\nHere's everything you need to know: https://t.co/Oc6TrygvNO"),
#  1635827898031693825: (1617,
#   'kana_Eng_coach',
#   'RT @kana_Eng_coach: 世界一人気の語学アプリDuolingoが、OpenAI社のGPT-4を搭載したDuolingo Maxを公開。Maxは会話の練習相手で、間違えた時は話し手がなぜその文章で話したかまで理解して、解説をくれるという優れもの。AIによって世界中…'),
#  1635687252616679426: (1343,
#   'gdb',
#   'RT @gdb: We’re releasing GPT-4 — a large multimodal model (image &amp; text in, text out) which is a significant advance in both capability and…'),
#  1635732802011557889: (1067,
#   'spectatorindex',
#   "RT @spectatorindex: BREAKING: OpenAI's ChatGPT-4 passed the Law Bar Exam with a result in the 90th percentile"),
#  1635689646305804289: (1052,
#   'DotCSV',
#   'RT @DotCSV: 🔴 GPT-4 YA ESTÁ AQUÍ!!!\n\nHoy era el día. La bestia ya ha llegado.\n\nEl nuevo modelo de OpenAI se ha liberado cumpliendo con much…'),
#  1635690709754814464: (1031,
#   'WatcherGuru',
#   'RT @WatcherGuru: JUST IN: ChatGPT creator OpenAI launches GPT-4, its most powerful AI model.'),
#  1635740909383061504: (1014,
#   'mckaywrigley',
#   'RT @mckaywrigley: Greg Brockman (@gdb) of OpenAI just demoed GPT-4 creating a working website from an image of a sketch from his notebook.…'),
#  1632687094337523712: (881,
#   'Prathkum',
#   'RT @Prathkum: Let AI write code for you:\n\n1. https://t.co/4njMpKoWUz\nPlain English to code\n\n2. https://t.co/Q6T8pjbFl2\nGenerate code with A…'),
#  1635709811840131072: (845,
#   'yusuf_i_mehdi',
#   'RT @yusuf_i_mehdi: We’re happy to confirm the new Bing is running on GPT-4, which we’ve customized for search.\nhttps://t.co/RVj26gJVQG \n\nTr…'),
#  1635696124324630529: (843,
#   'Tisoga',
#   'RT @Tisoga: OpenAI 刚刚发布了 GPT-4\n\nGPT-4 是大型多模态模型（large multimodal model），支持图像和文本的输入，并生成文本结果。\n\n这个 thread 会汇总一下有关 GPT-4 的一些信息（包括论文中的一些要点和实际的体验）…'),
#  1635596891210522625: (741,
#   'CryptoGPT_org',
#   'RT @CryptoGPT_org: A New Product Breakthrough: CryptoGPT AI Assistant Alex Opens to Mass Mobile Markets📱\n\nOur AI Assistant for mass retail…'),
#  1635691329996062725: (677,
#   'karpathy',
#   'RT @karpathy: 🎉 GPT-4 is out!!\n- 📈 it is incredible\n- 👀 it is multimodal (can see) \n- 😮 it is on trend w.r.t. scaling laws\n- 🔥 it is deploy…'),
#  1630401966563049475: (662,
#   'profoundlyyyy',
#   'RT @profoundlyyyy: You get a Twitter notification saying OpenAI released GPT-4 and look outside your window and see this…wyd? https://t.co/…'),
#  1635688069692293121: (656,
#   'miramurati',
#   'RT @miramurati: Unveiling GPT-4 -- our large multimodal model that exhibits human-level performance on various professional and academic be…'),
#  1635809594357448704: (653,
#   'kazzikill',
#   'RT @kazzikill: GPT-4ざっくりまとめ\n\n・画像入力対応\n・日本語に高精度で対応\n・専門領域の質問にも高精度で対応\n・ジョークを理解\n・嘘をつく可能性低下\n・ラフスケッチからWebサイト生成\n・簡単な指示からゲーム生成\n・ChatGPT Plus $20 契約者…'),
#  1635687336708276225: (622,
#   'shanegJP',
#   'RT @shanegJP: #GPT4 出た\nhttps://t.co/6Lw2ysBZWC\n\n1. 言語と画像のマルチモーダル大規模言語モデル：「写真で一言」説明できます。論文も写真でOK。 https://t.co/h8mFbUZp2b'),
#  1635695333115305985: (568,
#   'shota7180',
#   'RT @shota7180: 【速報】OpenAIからGPT-4 キタ！！！！！\n\n・一旦すごい\n・マルチモーダル（画像とテキストからテキスト生成可能\n・ChatGPT Plus で展開\n・25,000語を1 つのプロンプト内にで処理可能\n\n予想よりめちゃ早かった！ https…'),
#  1635692366085468163: (541,
#   'Saboo_Shubham_',
#   'RT @Saboo_Shubham_: Breaking 🚨\n\nOpenAI just dropped GPT-4 and it can literally blow your mind 🤯\n\nGPT-4 is a large multimodal model that can…'),
#  1635696545734570010: (539,
#   'CerfiaFR',
#   'RT @CerfiaFR: 🚨🤖 FLASH | #OpenAI, maison mère de #ChatGPT, a annoncé la sortie de GPT-4, une version qui surpasse les capacités actuelles d…'),
#  1635696087687364608: (525,
#   'wintonARK',
#   'RT @wintonARK: OpenAI announces GPT-4 here:\n\nhttps://t.co/VC0uzlQbox\n\nPerformance on human-benchmarks is rather remarkable.\n\nGPT-3.5 scored…'),
#  1635690030684418059: (493,
#   '_akhaliq',
#   'RT @_akhaliq: GPT-4 Technical Report\n\npdf: https://t.co/4T8PQZicvg\nblog: https://t.co/nCIuKBsj4G https://t.co/lP9FHzySs0'),
#  1635694953463705600: (488,
#   'JordiRib1',
#   "RT @JordiRib1: Good news, we've increased our turn limits to 15/150. Also confirming that the next-gen model Bing uses in Prometheus is ind…"),
#  1634470739134017536: (424,
#   'yetone',
#   'RT @yetone: 重磅更新！最新版的 OpenAI Translator 桌面端应用已支持全局划词翻译！\n\n同时支持了快捷键录制，配合快捷键呼出功能，想划哪里划哪里，再也没有人会担心自己无法划词翻译。\n\n另外还支持了托盘图标，同时支持了置顶固定功能，感谢 @okisdev…'),
#  1635712178031296520: (363,
#   '_willfalcon',
#   'RT @_willfalcon: GPT-4 paper : https://t.co/jwt83bskYP\n\nLet me save you the trouble: https://t.co/zdsypRDHkx'),
#  1635693336618053638: (359,
#   'khanacademy',
#   'RT @khanacademy: Did you hear? 👀 Khan Academy is using GPT-4 from @OpenAI to shape the future of learning.\n\nStarting today, you can sign up…'),
#  1635365639182495744: (351,
#   'miolini',
#   'RT @miolini: Stanford Alpaca, a new LLM player, has been fine-tuned with Nvidia A100 x 8 for 3 hours ($100) and augmented with OpenAI GPT-3…'),
#  1635690254689599488: (342,
#   'BeMyEyes',
#   'RT @BeMyEyes: We are thrilled to present Virtual Volunteer™, a digital visual assistant powered by @OpenAI’s GPT-4 language model. Virtual…'),
#  1634201873493131264: (337,
#   'aielep',
#   'RT @aielep: Meet, aielep\n\n#1 AI Writing\n\nEasy to create content and increase your income.\n\nLet Artificial Intelligence create content for b…'),
#  1635737874195775496: (323,
#   'nearcyan',
#   'RT @nearcyan: page 37 of the GPT-4 paper: https://t.co/mOk0X6oNWz https://t.co/Vwrb0Irkcy'),
#  1635704339674038279: (294,
#   'alex_valaitis',
#   "RT @alex_valaitis: Today @OpenAI announced the biggest release since the iPhone!\n\nHere's everything you need to know about GPT-4\n\nIf you're…"),
#  1635688521695633408: (291,
#   'duolingo',
#   'RT @duolingo: AI and education make a good duo.\n\nIntroducing Duolingo Max. A subscription tier above Super that gives you access to your ow…'),
#  1635726844568674306: (288,
#   'mattyglesias',
#   'RT @mattyglesias: English majors get the last laugh as GPT-4 crushes every exam except AP English Language and AP English Lit \n\nhttps://t.c…'),
#  1635469093536169985: (258,
#   'huangjinbo',
#   'RT @huangjinbo: 最近让我最喜欢的扩展是：沉浸式双语网页翻译扩展。沉浸式双语阅读，支持超多常见的翻译服务，包括 OpenAI。\xa0更重要的是竟然支持 PDF 文件，EPUB 电子书双语翻译。\nhttps://t.co/LNLIza3KX4'),
#  1635690962973339672: (242,
#   'rowancheung',
#   "RT @rowancheung: It's here. OpenAI just launched GPT-4.\n\nAnd it's incredible:\n\n-It can accept image and text inputs, and emit text outputs.…"),
#  1635921277230919680: (235,
#   'spectatorindex',
#   "RT @spectatorindex: TECH: OpenAI's ChatGPT-4 passed the Law Bar Exam with a result in the 90th percentile"),
#  1635723732328087779: (228,
#   'porquetendencia',
#   'RT @porquetendencia: "GPT-4":\nPor la presentación de @OpenAI \nhttps://t.co/xOyCMNe4KL'),
#  1635700579543416835: (218,
#   'rasbt',
#   'RT @rasbt: Some takeaways after reading the GPT-4 paper: https://t.co/zHI2ULioMb\n\nThe good:\n\n1)  The model now accepts multimodal inputs: i…'),
#  1635690625642397696: (205,
#   'adamdangelo',
#   'RT @adamdangelo: Today we are launching Poe subscriptions, which will provide paying users with access to bots based on two powerful new la…'),
#  1635733548580700190: (195,
#   'codezilla_',
#   'RT @codezilla_: انه عصر الذكاء الاصطناعي يا سادة...\n\nشركة OpenAI اطلقت ChatGPT-4 من ساعتين\n\nدي اول تجربة ليا معاه، جعلته يكتب بايثون سكريبت…'),
#  1633865112124637184: (181,
#   'SystematixMedia',
#   'RT @SystematixMedia: Apple Watch : ‘ watchGPT’ App Brings the OpenAI to you Apple Watch. #imagine_sysme https://t.co/pnKebaQALq'),
#  1635825195796811776: (179,
#   'gigazine',
#   'RT @gigazine: 「GPT-4」発表、司法試験上位10％＆日本語でもめちゃくちゃ高性能＆画像処理もプログラミングも可能で「初代iPhoneと同等の衝撃」とも評される\nhttps://t.co/oJT5FyXTmr'),
#  1635763974942736390: (170,
#   'DIMENSION_YT',
#   "RT @DIMENSION_YT: GPT-4 🤖 a été annoncé par @OpenAI aujourd'hui !\n\nMais qu'est-ce que ça change concrètement ?\n\nPetit thread pour résumer t…"),
#  1635642600777740289: (163,
#   'lvwzhen',
#   'RT @lvwzhen: 我们刚刚上线了一款基于OpenAI的翻译网站「OpenL」，目前支持15种常见语言，操作简单，响应快速。除此之外，我们还提供了Write功能，可修正语法和润色文章，使您的文案更加准确，清晰和表达更加自然。欢迎大家试玩，谢谢。\n\nhttps://t.co…'),
#  1635719105276948480: (157,
#   'Yamkaz',
#   'RT @Yamkaz: 複数の言語モデルを1つのプラットフォームで使える\n「Poe」がサブスク開始！\nhttps://t.co/bqC5aQ8dbS\n\nなんとサブスク登録すればOpenAIの「GPT-4」、Anthropicの「Claude+」が使える https://t.co…'),
#  1635762846620602368: (141,
#   'Yamkaz',
#   'RT @Yamkaz: 視覚障害者の生活を支援するBe My Eyesが、\nGPT-4を活用した「Virtual Volunteer™」を開発\nhttps://t.co/hd9WgymlEv\n\n画像に関する質問に答え、リアルタイムで視覚支援を提供。これにより、視覚障害者の方々が…'),
#  1635986956374118400: (131,
#   'unusual_whales',
#   'RT @unusual_whales: OpenAI cofounder has said, per BI, to Elon Musk\'s criticism that ChatGPT is too \'woke\': "We made a mistake."'),
#  1635853530006208513: (129,
#   'emollick',
#   'RT @emollick: Many people complain about the limits put on these new AI systems\n\nI think everyone should read the risk mitigation section i…'),
#  1635966587680485377: (129,
#   'KenAkamatsu',
#   'RT @KenAkamatsu: 昨日は12時から勉強会で、日本マイクロソフト社長らによるChatGPTやOpenAIの最新情報。15時から宇宙海洋開発特別委員会。月面開発についてispace社などからヒアリング。17時からＡＩptで北野宏明氏らによる驚異的な報告。18時半から…'),
#  1635708084059525120: (127,
#   'Mascobot',
#   "RT @Mascobot: Just today in LLM world:\n\n- @OpenAI's  GPT-4 dropped.\n- @GoogleAI PaLM opened their API.\n- @AnthropicAI's Claude announced th…"),
#  1635794698953474048: (121,
#   'AiBreakfast',
#   'RT @AiBreakfast: Duolingo partners with OpenAI \n\nNew AI powered features: Role Play, an AI conversation partner, and Explain my Answer, whi…'),
#  1635761562253430785: (117,
#   'madonomori',
#   'RT @madonomori: OpenAI、「GPT-4」を発表 ～新しい「Bing」も実は「GPT-4」がベース／「ChatGPT」よりも賢く、安全性・整合性も向上 https://t.co/sH969ZdQwa https://t.co/UZ6UbLlALn'),
#  1635766538472153089: (114,
#   'Yamkaz',
#   'RT @Yamkaz: DuolingoがOpenAIのGPT-4を導入\n「Duolingo Max」を発表！\nhttps://t.co/Oou1Xdh1Zo\n\nAI会話パートナーの「Role Play」と、Maxで間違いを犯した時に分析してくれる「Explain My Ans…'),
#  1635688288223887360: (112,
#   'unusual_whales',
#   'RT @unusual_whales: JUST IN: OpenAI introduces GPT-4'),
#  1633574048109330432: (109,
#   'shota7180',
#   'RT @shota7180: 【ブクマ必須】プロンプトを学べるまとめサイト『Learn Prompting』がめちゃ便利！\n\n・基礎から応用までカバー\n・ChatGPTやMidjourneyまですぐに使えるプロンプトが学習できる\n・OpenAIのAPIキーがあれば、サイト内で演…'),
#  1635824783571943426: (102,
#   'mskkpr',
#   'RT @mskkpr: 【新しい Bing が OpenAI の GPT-4 上で稼働】\n新しい Bing が、この度 OpenAI 発表の GPT-4 を活用した Prometheus で動作することを公表したブログを公開しました。\n\nhttps://t.co/6UJNPp2…'),
#  1635737976390168581: (99,
#   'shanegJP',
#   'RT @shanegJP: https://t.co/WEBrfSorqq\n- GPT-4でWebサイト作り：\n１）紙切れにスケッチ（文字汚くてもOk)\n２）写真を撮る\n３）GPT-4に指令する-&gt;サイト出来た\n\n13:18 https://t.co/cW2FLdotSY'),
#  1635513302460801024: (99,
#   'nash_su',
#   'RT @nash_su: 树莓派也能跑ChatGPT，斯坦福 Alpaca 实现原理：\n1. 先通过 ChatGPT API 接口调用 \xa0text-davinci-003 模型生成了 52000个 训练语料数据。\n2. 基于 LLaMA 7B 模型使用这52K个语料数据 Fin…'),
#  1635851103890751488: (96,
#   'BTC_Chopsticks',
#   'RT @BTC_Chopsticks: ChatGPT 升级！@OpenAI 推出GPT-4，准确性提高。\n#OpenAI #Microsoft #Chatbots, #ChatPBT #GPT #AI #FutureOfWork\nhttps://t.co/XezRSm0tNX'),
#  1635700679657521153: (93,
#   'emollick',
#   'RT @emollick: All from the GPT-4 whitepaper. https://t.co/gXejfwuTLF https://t.co/E6VhFXxMxd'),
#  1635692510990282759: (92,
#   'WhenMoon_ai',
#   'RT @WhenMoon_ai: OpenAI has announced the release of their GPT-4 AI language model\n\nLooks outside: https://t.co/8qFvhYiZ6D'),
#  1635750772913885184: (90,
#   'andrewwhite01',
#   'RT @andrewwhite01: How did I get GPT-4 to design new drugs? I gave GPT-4 access to small programs and it proposed a new molecule that could…'),
#  1635737014266986514: (85,
#   'L_ThinkTank',
#   'RT @L_ThinkTank: [ 🖥️ TECH ]\n\n🔸 OpenAI annonce le lancement de GPT-4, son modèle de langage le plus avancé à ce jour. Entre autres, il perm…'),
#  1635772055798026241: (83,
#   'paul_rottger',
#   'RT @paul_rottger: I was part of OpenAI’s red team for GPT-4, testing its ability to generate harmful content. \n\nWorking with the model in v…'),
#  1635801636408025089: (82,
#   'mhatta',
#   'RT @mhatta: オープンソースはサヨクとか言う人いるけど、どちらかというと最近の状況はAmazonとかOpenAIとかの地主さまに地代払って小作人やっとるデジタル封建主義やで。農奴ならぬコー奴だ'),
#  1635948612260888576: (81,
#   '____BTC',
#   'RT @____BTC: ⚡️最新Crypto News🤖⚡️\n\n『OpenAIのGPT-4リリースで、仮想通貨AI関連銘柄が急騰.ᐟ.ᐟ』\n\n☑︎ AI言語モデル「GPT-4」を発表\n\n☑︎ GPT-4の特徴\n\n☑︎ 性能の向上\n\n☑︎ GPT-4の課題\n\nhttps://t…'),
#  1635709782555336704: (78,
#   'joao_gante',
#   'RT @joao_gante: Not cool, @OpenAI 🙃 https://t.co/vGkynCFdPq'),
#  1635697783876223006: (74,
#   'benmschmidt',
#   'RT @benmschmidt: Choices of training data reflects historic biases and can inflict all sorts of harms. To ameliorate those harms, and to ma…'),
#  1635532191789883393: (70,
#   'river_leaves',
#   'RT @river_leaves: 在大语言模型、GPT这件事情上，发明这种方法的是Google，发扬光大让路人皆知的是OpenAI（微软），将优化后的大模型开源出来的是Meta……妥妥的硅谷御三家啊。如果不清楚背后的来龙去脉，这看起来像是一种协同创新，但实际上这是互相竞争的结…'),
#  1635987423581593603: (61,
#   'MushtaqBilalPhD',
#   "RT @MushtaqBilalPhD: OpenAI recently launched an advanced version of ChatGPT's \u2060— GPT-4.\n\nHere's what it's capable of: https://t.co/OfDI9cf…"),
#  1624005290092900355: (61,
#   'MotionMark369',
#   'RT @MotionMark369: OpenAI has jam packed ChatGPT with so much anti-human woke nonsense. Sam Altman should be removed as CEO, and I don’t sa…'),
#  1635816501738340355: (58,
#   'dotey',
#   'RT @dotey: 朋友在写prompt，想让ChatGPT帮忙按照要求格式输出，老是不对，于是我帮他改了一下，成了\n\nBTW: OpenAI的PlayGround用来调试prompt很方便的\nhttps://t.co/tvROdhz0I7 https://t.co/luFn…'),
#  1635885498383101952: (57,
#   'AK33Astrology',
#   "RT @AK33Astrology: Here's a Secret:\n\nOpenAI (ChatGPT) has been leading the AI revolution\n\nBut why has OpenAI surpassed other prominent AI c…"),
#  1635809543434412033: (56,
#   'Svwang1',
#   'RT @Svwang1: 人工智能会天然成为权力斗争的高手。openai 这篇98页的论文，第14页，最后一段。“可以指定和执行长期计划的能力，积累权力和资源，并表现出更加有主动性，有自我导向的行为".  “获取权力，对于多数奖励函数和不同类的代理人，是最优的行为”'),
#  1635799485426323457: (53,
#   'ku_ni_29',
#   'RT @ku_ni_29: GoogleがOpenAI の動きに呼応し反撃、、！\n進化が早い、！\n\nGoogle Workspace全体にAIを完全に統合して\n✦Gmail\n✦Meet\n✦Docs\n✦Slides\n✦Spreadsheet\nなどで利用可能に👀\n\n既に企業に入り込…'),
#  1635931279421222912: (53,
#   'pacmannai',
#   'RT @pacmannai: 😲😲 Kita masih terkejut dengan kehadiran ChatGPT yang serba bisa, dari summarize article sampai membuat kode yang digenerate.…'),
#  1635742073285492737: (53,
#   'sunyuqian1997',
#   'RT @sunyuqian1997: What does #gpt4 look like?\nLet it draw itself.\nI ask @OpenAI  GPT-4 to draw a self-portrait and explain why...here is wh…'),
#  1635762156116537344: (53,
#   'nftouji',
#   'RT @nftouji: ウエイトリスト（順番待ち）の登録は、早い方が良いらしいから急いで！\nウエイトリストへのURL⬇︎\nhttps://t.co/TwtM10pY1o\n\nGPT-4の詳細や最新情報は、日本担当のシェインさん@shanegJP のツイートをフォローしてキャッチ…'),
#  1635695373552431115: (52,
#   'YasLovesTech',
#   'RT @YasLovesTech: OpenAIがChatGPT4をリリースしました。特に画像も読み込めるということでかなり強力になりそうです。以下要約です。\n\n▶️ GPT-4は、数十億のパラメーターを持つ巨大なニューラルネットワークを使用しており、メディアに対する高度な理解…'),
#  1635718652204023808: (51,
#   'G_IDLESuperior',
#   'RT @G_IDLESuperior: Chat GPT-4 said, (G)I-DLE 4TH GEN LEADER."\n\nThank you, @OpenAI 🤍\n\n#4thGen #KPop https://t.co/PYCCQIEDEe'),
#  1635851490639347715: (51,
#   'emollick',
#   'RT @emollick: One key AI risk paper demonstrated how non-LLM AIs could develop novel toxins👇\n\nThe GPT-4 whitepaper shows that, without guar…'),
#  1635708643885580304: (50,
#   'marianorenteria',
#   'RT @marianorenteria: Google y OpenAI hoy… https://t.co/fljLYdP76l'),
#  1635687691965673491: (49, 'DotCSV', 'RT @DotCSV: 🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥'),
#  1635595383517888513: (49,
#   'another_dayu',
#   'RT @another_dayu: Immersive Translate 现在也可以制作双语电子书了，支持 DeepL 和 OpenAI 的API。 https://t.co/exFKlO1fL2'),
#  1635720296438308864: (49,
#   '0xSMV',
#   "RT @0xSMV: .@OpenAI just launched GPT-4.\n\nWhat's that? Imagine ChatGPT on steroids.\n\nI read the entire research paper, so you don't have to…"),
#  1635725933280735232: (46,
#   'the_carlosdp',
#   'RT @the_carlosdp: wait I just realized\n\nDid @OpenAI literally just announce GPT-4 an HOUR after Google announced their API?!\n\nor was Google…'),
#  1635721023298338817: (46,
#   'import_robs',
#   'RT @import_robs: OpenAI lançou o GPT-4.\n\nPara quem não sabe, o GPT-3 foi por um tempo razoável a maior inteligência artificial no sentindo…'),
#  1635994675151511558: (44,
#   'StabilityAI_JP',
#   'RT @StabilityAI_JP: GPT-4発表\nOpenAIよりGPT-4が発表された https://t.co/PHEVaofPUJ (1/5) https://t.co/kbcJChsROf'),
#  1635700131755438081: (41,
#   'benmschmidt',
#   'RT @benmschmidt: Neural networks like GPT-4 are notoriously black boxes; the fact that their operations are unpredictable and inscrutable i…'),
#  1635727839591899136: (41,
#   'blairasaservice',
#   'RT @blairasaservice: MSFT responsible AI layoffs &amp; OpenAI refusing to disclose details about GPT-4 model architecture &amp; training is a clear…'),
#  1635746598616698883: (41,
#   'DotCSV',
#   'RT @DotCSV: La empresa que saque unas gafas de realidad aumentada con una cámara y conexión a GPT-4 en la API se gana el futuro.\n\nY ahora m…'),
#  1635696659421179906: (40,
#   'qatnology',
#   'RT @qatnology: رسمياً / شركة OpenAI تعلن عن تقنية GPT 4\nالجيل الجديد من الذكاء الاصطناعي اللي يشغل ChatGPT \n\nالنسخة الجديدة أسرع .. أكثر دق…'),
#  1635755267739598848: (39,
#   'sualehasif996',
#   'RT @sualehasif996: After beta testing GPT-4 as part of @OpenAI Converge, one thing stands out to me: GPT-4 is phenomenal at code.\n\nHere it’…'),
#  1635711173210542080: (38,
#   'shanegJP',
#   'RT @shanegJP: 6. ChatGPT Plus（現在月額２０ドル）のユーザーはもう（またはもうすぐ）GPT-4と「話せ」ます。「画像機能」はまだアクセスできく、使用量は制限をかけるが、興味がある方は是非！使用量に応じてのプライスモデルも検討中。\n\nOpenAIはもう…'),
#  1635883526406144003: (38,
#   'fadouce',
#   'RT @fadouce: 💥 Il est sorti ! OpenAI dévoile une nouvelle version de #GPT4\n\n(Et Microsoft Bing l’utilisait déjà en secret!)\nGPT-4 est moins…'),
#  1635792051873906688: (37,
#   'oran_ge',
#   'RT @oran_ge: GPT4论文下载：https://t.co/XrM8xEnqYU\n官方直播回放：https://t.co/lLzuTOTD66'),
#  1635751764577361921: (35,
#   'amanrsanger',
#   'RT @amanrsanger: GPT-4 is waaay better at programming than given credit for.\n\nHumanEval is a benchmark of python programming problems.\n\nWit…'),
#  1635686130451632128: (35,
#   'rachelmetz',
#   'RT @rachelmetz: my first @technology byline!!\nClaude, a rival chatbot to ChatGPT from AI startup Anthropic, will be available to businesses…'),
#  1635703075590504460: (35,
#   'benmschmidt',
#   "RT @benmschmidt: Their argument is basically a combination of 'trust us' and 'fine-tuning will fix it all.' But the way they've built corpo…"),
#  1635900926597947393: (33,
#   'Austen',
#   'RT @Austen: I still don’t *fully* understand how OpenAI turned from being a nonprofit that had raised a ton of money from donors into a for…'),
#  1635888552067182592: (33,
#   'CryptoKoryo',
#   'RT @CryptoKoryo: So you think the AI narrative is exhausted?\n\nOpenAI just released GPT4. A model 1000x more powerfull than GPT3.\n\nEverythin…'),
#  1635689008582864899: (32,
#   'StockMKTNewz',
#   "RT @StockMKTNewz: OpenAI's new ChatGPT-4 passed the bar exam with a score around the top 10% of test takers compared to GPT-3.5 being aroun…"),
#  1635891113130180611: (32,
#   'ChineseWSJ',
#   'RT @ChineseWSJ: 近来爆火的AI聊天机器人ChatGPT母公司OpenAI周二推出了其AI技术的新版本GPT-4，称其比以前版本更加强大、更可预测，能够分析图像和处理大得多的文本块。\nhttps://t.co/vTBBco1VJc'),
#  1635754356426383364: (32,
#   'prdiegoalejandr',
#   'RT @prdiegoalejandr: 🚨 OpenAI acaba de lanzar ChatGPT-4\n\n¡Esta nueva versión deja en la basura a la anterior!\n\nAquí todo lo que necesitas s…'),
#  1635813278331838464: (31,
#   'weplash',
#   'RT @weplash: ¡Duolingo lazó una nueva experiencia de aprendizaje llamada Duolingo Max! \n\nUtiliza la tecnología GPT-4 de OpenAI para ofrecer…'),
#  1635691265047302146: (31,
#   'repligate',
#   'RT @repligate: &gt; We spent 6 months making GPT-4 safer and more aligned. GPT-4 is 82% less likely to respond to requests for disallowed cont…'),
#  1635789857875189760: (31,
#   'YosarianTwo',
#   'RT @YosarianTwo: Actually I should link the real source; this is the second paper published on the OpenAI announcement.  If you want to rea…'),
#  1635994758479851520: (31,
#   'StabilityAI_JP',
#   'RT @StabilityAI_JP: DuoLingo Max発表\nGPT-4を用いたAI Tuterによる言語教育システム https://t.co/YmrYiYTpCa (5/5) https://t.co/kYgnhEYKQi'),
#  1635833392737718272: (29,
#   'sandraaleow',
#   "RT @sandraaleow: OpenAI just dropped ChatGPT4. 🤯\n\nAnd that's just the tip of the iceberg.\n\nIn the past few hours my feed exploded with insa…"),
#  1635767409981394944: (29,
#   'TAIRAMASAAKI',
#   'RT @TAIRAMASAAKI: GPT-4発表。\n\n自民党に「 AIの進化と実装に関するプロジェクトチーム」を創っておいてよかった。 https://t.co/1UJUlOY4wq'),
#  1635716887383506944: (29,
#   'Yamkaz',
#   'RT @Yamkaz: OpenAIよりGPT-4と一緒にモデルを評価するためのフレームワーク「Evals」が発表(オープンソース)\nhttps://t.co/904kfaJX7q\n\nデータセットを使用してプロンプトを生成し、OpenAIモデルの品質を測定することができ、異なる…'),
#  1636003418144915457: (28,
#   'bentossell',
#   'RT @bentossell: All the best examples of GPT-4, from OpenAI:'),
#  1635845633197375488: (28,
#   'tjmlab',
#   'RT @tjmlab: 天才イーロン・マスクが気づいたChatGPTとOpenAIのダークサイド https://t.co/d7JNlX2CAI \n\n｢ソフトウェアエンジニアの報酬の中央値は90万ドル(約1億2300万円)ほどです。たった100人のエンジニアで、毎年9000万ド…'),
#  1635754662249869325: (27,
#   'techreview',
#   'RT @techreview: New: We got a first look at GPT-4, the much-anticipated large language model from OpenAI. \n\nGPT-4 is bigger and better than…'),
#  1635708771367518208: (25,
#   'ctgptlb',
#   'RT @ctgptlb: 【速報】GPT4登場！OpenAIが大型マルチモーダルモデルをリリース！\n\n▫️ 画像を入力し、キャプション、分類、分析が可能に。\n▫️ 25,000語以上の文章も一回のプロンプトで入力可能に。\n▫️ 回答の正確性が飛躍的にアップ。\n▫️創作や技術的な…'),
#  1635990063157747713: (24,
#   'sam_starkman',
#   'RT @sam_starkman: OpenAI released its long-awaited GPT-4 model yesterday.\n\nHere are 4 key points you need to know:'),
#  1635766072266870784: (24,
#   'shodaiiiiii',
#   'RT @shodaiiiiii: GPT-4がついに公開🚨\n\n・ChatGPT Plus契約者は利用可能\n・画像入力に対応(研究段階)\n・日本語の性能が向上\n・回答の安全性が向上\n・嘘をつく可能性が低下\n\nカジュアルな会話ではChatGPTとの違いは少ないが、複雑な内容や細かな…'),
#  1635969665879924736: (23,
#   'Fsk_kkk',
#   'RT @Fsk_kkk: 💥2023 کے بہترین اے ائی ٹولز💥\n2023 میں، اصطناعی ذہانت (AI) کی ترقی کے ساتھ، مختلف AI ٹول بڑھتے ہوئے مزید خوش اسلوبی سے دستیاب ہ…'),
#  1635994744915369985: (22,
#   'StabilityAI_JP',
#   'RT @StabilityAI_JP: オープンソースの流れ\n・ChatGLM-6Bという中国語特化のオープンソースが出現\n・スタンフォード大学がGPT-3.5並みの性能を誇るALpaca7Bを開発、発表\n・OpenChatKitと呼ばれる本当にオープンなLLMを作るセットが元…'),
#  1635996774006489089: (22,
#   'RT_com',
#   'RT @RT_com: Newly unleashed AI outperforms 90% of humans\n\nRead more: https://t.co/PcruIUjsbi https://t.co/QFMqRpEfr5'),
#  1633663666959810560: (22,
#   'lewangdev',
#   'RT @lewangdev: 《深度学习入门：基于Python的理论与实现》作者来啦，这本书的后续是一个系列，有好几本书。我在想，借助 OpenAI 我是不是可以直接读原版日文的技术书了https://t.co/wfhXaRXLFd https://t.co/2NIkmSBsHK'),
#  1635972784890458114: (22,
#   'yetone',
#   'RT @yetone: 大家好！现在全平台的 OpenAI Translator 已经支持深色模式，感谢 tywtyw2002 和 @lazy_static 同学的贡献！\n\nhttps://t.co/F2loftYH4A https://t.co/Xs0MuY3VYc'),
#  1635718475107663885: (22,
#   'DiogoCortiz',
#   'RT @DiogoCortiz: Sabe o que é curioso do GPT-4? O relatório técnico da ferramenta não tem detalhes técnicos hehe. A OpenAI se apropriou de…'),
#  1635819391886712832: (21,
#   'AlexIsBuilding',
#   'RT @AlexIsBuilding: If you missed the announcement, @OpenAI just made GPT-4 available.\n\n🧵 (1/10)\nhttps://t.co/4eEliNDmSb'),
#  1635853490085036035: (19,
#   'divyamittal_IAS',
#   'RT @divyamittal_IAS: GPT-4 has been released by OpenAI!\n\nIt passes basically every exam. And not just pass, it scores in top decile incl LS…'),
#  1630496334397489152: (19,
#   'ICRC',
#   'RT @ICRC: Is @OpenAI an International Humanitarian Law (IHL) expert?\n\nCheck out our recent #TikTok where @epolicinski puts it up for a test…'),
#  1635740654822383617: (18,
#   'VishnuNath',
#   'RT @VishnuNath: Congratulations to our partners at #OpenAI for their release of GPT-4 today.\xa0\n\nWe are happy to confirm that the new #Bing i…'),
#  1635700652721721344: (18,
#   'PirateWires',
#   'RT @PirateWires: GPT-4, OpenAI’s newest version of ChatGPT, “passes a simulated bar exam with a score around the top 10% of test takers; in…'),
#  1635783597192892417: (17,
#   'newscientist',
#   "RT @newscientist: GPT-4: OpenAI says its AI has 'human-level performance' on tests https://t.co/bpu99jHAqz"),
#  1635700134469160960: (17,
#   'Plinz',
#   'RT @Plinz: @EMostaque 500 brains harvested from secretly cloned winners of standardized testing competitions, wired up together in a vat fi…'),
#  1635812174965735424: (17,
#   'xuanalogue',
#   'RT @xuanalogue: The fact that Bing Chat behaved as erratically and threateningly as it did -- despite OpenAI spending "6 months making GPT-…'),
#  1635915638479757312: (17,
#   'DEFAKATOR_Off',
#   'RT @DEFAKATOR_Off: Un premier aperçu de #GPT4, le tout nouveau modèle de langage de OpenAI, dans cette vidéo de @DFintelligence. Par rappor…'),
#  1635925839991693312: (16,
#   'AJEnglish',
#   'RT @AJEnglish: The long-awaited follow-up to ChatGPT has gone live, boasting of “human-level performance” in university-standard exams http…'),
#  1635852810549088257: (16,
#   'theweb3sharma',
#   'RT @theweb3sharma: @OpenAI demoed GPT4 yesterday,\n\nWhat it can do is mind-boggling🤯\n\nGPT-4 passes basically every exam.\nGPT-4 does drug dis…'),
#  1635844269545070592: (16,
#   'syzygiess',
#   'RT @syzygiess: ChatGPT-4 was announced today by @OpenAI \n\nHere is a breakdown of what it entails and what that means for you if you’ve been…'),
#  1635762729632821248: (15,
#   'BeMyEyes',
#   'RT @BeMyEyes: Our new Virtual Volunteer™ tool will provide an unprecedented level of independence in the lives of millions of people who ar…'),
#  1635808043941388291: (15,
#   'clif_high',
#   "RT @clif_high: ChatGPT really sucks at math. Don't trust it. Even simple arithmetic gets screwed up constantly &amp; repetitiously.  Kind of di…"),
#  1636006090927390720: (15,
#   'reidhoffman',
#   'RT @reidhoffman: I wrote a new book with @OpenAI’s latest, most powerful large language model.  \n\nIt’s called Impromptu: Amplifying our Hum…'),
#  1635999244929708034: (14,
#   'GergelyOrosz',
#   "RT @GergelyOrosz: The way OpenAI is building excitement across devs is something I've not seen in a long time. A lot of this is deliberate,…"),
#  1635954304749019141: (13,
#   'DiogoCortiz',
#   'RT @DiogoCortiz: GPT-4 é uma caixa preta. \nLacrada.\nE escondida no fundo mar.\n\n@OpenAI virou uma organização contra a ciência aberta na áre…'),
#  1635667899829592065: (13,
#   'masanork',
#   'RT @masanork: やっぱ利用者接点を持ってるグーグルは強いな。砂場を広げているOpenAIとは打ち手から違う。いずれはマイクロソフトが追っかけるとして、素手で容赦なく飽きずに殴り合ってくれるのが世界と技術進歩のためじゃないかな'),
#  1636003225789956099: (13,
#   'WillManidis',
#   'RT @WillManidis: with OpenAI and ScienceIO, you can build a basic automated medical coding system in 35 lines of code.\n\nfive years ago, aut…'),
#  1635849097566474240: (13,
#   'TyreeRobinson',
#   'RT @TyreeRobinson: Remember that time #GPT4 said…\n\n$ORAI &gt; $AGIX \n\n@OpenAI just take all my money. You are nailing it. https://t.co/4lt1Vui…'),
#  1635973027455442945: (13,
#   'Carnage4Life',
#   'RT @Carnage4Life: Whenever you call Sam Altman to ask why OpenAI is no longer a non-profit or even “open” https://t.co/TxMXR2Cf2d'),
#  1636006860909166598: (13,
#   'cryptomancc',
#   'RT @cryptomancc: 1/ #คริปโตแมนเบสิค AI จะเพิ่ม productivity ของเราได้หลายเท่า เป็นอะไรที่ทั้งโลกทึ่ง ตอนนี้ GPT-4 (multimodal large languag…'),
#  1635971076672090125: (12,
#   'rootport',
#   'RT @rootport: ダメだよOpenAIくん。\n\nそのキャッチコピーじゃダメだ。\n\n「GPT-4は初代iPhone並みの衝撃」\n\nって、それじゃダメだ。\n\n「ほな、大したこと無いな」ってジャップどもは勘違いしちゃう。'),
#  1635994489079619590: (12,
#   'laskewitz',
#   "RT @laskewitz: 🚀 ... And here's another integration of GPT in the Power Platform!\n\n🤖 The new version of Power Automate for desktop offers a…"),
#  1635780798451265538: (11,
#   'PhMai',
#   'RT @PhMai: This about sums it up: "AI systems will have even greater potential to reinforce entire ideologies, worldviews, truths and untru…'),
#  1635709780529664001: (11,
#   'julienbarbier42',
#   'RT @julienbarbier42: GPT-4 is here!'),
#  1635392029411913728: (11,
#   'Albert301271',
#   'RT @Albert301271: Czy chat AI z OpenAI się myli? https://t.co/whUHrotygN'),
#  1635692559933616165: (11,
#   'realdanielnita',
#   'RT @realdanielnita: "Compania care a creat ChatGPT, OpenAI, lanseaza GPT-4, cel mai performat model de inteligenta artificiala."  Urmeaza u…'),
#  1636021344583270400: (10,
#   'notkevinhurler',
#   'RT @notkevinhurler: OpenAI unveiled its GPT-4 chatbot yesterday, and also revealed in a technical paper that the AI successfully tricked a…'),
#  1635955769840476162: (10,
#   'TechInsider',
#   'RT @TechInsider: OpenAI is now rumored to be valued at $30 billion and has wasted no time in commercializing its technology — @_hasanc argu…'),
#  1635743532676726792: (10,
#   'jordimash',
#   "RT @jordimash: Òbviament no és casualitat que en el mateix dia s'hagin presentat GPT-4 (https://t.co/qPyT98dchT)\n d'OpenAI, PaLM API de Goo…"),
#  1635704362612965376: (10,
#   'shanegJP',
#   'RT @shanegJP: （私の日本語タイピングは英語の10倍遅いです）\n\n5. 安全面：能力も重要ですが、同時に重要なのは安全面。これは私の「強化学習」「アラインメント」分野なので、OpenAIに入ってまだ２ヶ月ですが、色々と手伝いました。安全面のリーダーのChongさんは…'),
#  1636010470363496452: (10,
#   'soumithchintala',
#   "RT @soumithchintala: People getting mad about @OpenAI not releasing GPT4's research details....\nthe only tangible way to get back is to sur…"),
#  1635987077740281859: (10,
#   'twn_ai',
#   "RT @twn_ai: Our dev's cooking the perfect recipe for the autoraid feature. It's not about the #AI itself, or the bot or the automation proc…"),
#  1635809756517376001: (10,
#   'Newsweek_JAPAN',
#   'RT @Newsweek_JAPAN: Open AIが「GPT-4」発表──マルチモーダル化、文章・画像を併用した質問に対応 \n\n＜司法試験の模擬試験で受験者の上位10％相当の合格点を獲得したという＞\nhttps://t.co/pS8rPLDMGd #OpenAI #GPT4…'),
#  1636002920901509121: (9,
#   'TechCrunch',
#   'RT @TechCrunch: It turns out Microsoft’s new #AI-enabled Bing was using OpenAI’s GPT-4 all along https://t.co/M4Tkw65qSo'),
#  1635663550776762369: (9,
#   'Cydiar404',
#   'RT @Cydiar404: 众所周知，最近OpenAI 调整了相应的Stripe风控等级，从几个纬度进行风控：\n- 新注册用户，登录地址与付款地址是否一致\n- 美国免税州、新加坡基本直接Ban\n- 通过美国梯子进行注册\n- 不要直接开通Plus，否则会出现和我一样的提示\n-…'),
#  1635784024852680707: (9,
#   'shinoyu',
#   'RT @shinoyu: OpenAIの進化早すぎるんよ\nエンジニアリングほぼ代替されるのも時間の問題ですね。どの分野でも技術一本の強みが相対的に薄くなるのは目の前にきてる\n\nさすがにアラフォー風俗嬢を本業にするのはちょっと……'),
#  1635755096456970241: (8,
#   'hidekishima',
#   'RT @hidekishima: GPT-4を導入した新機能Duolingo Max（日本未上陸）について、Open AI様のウェブサイトに取り上げて頂いています。ローンチパートナーとして弊社を選んでいただけて幸いです。\nhttps://t.co/eU42S8dJeK'),
#  1635839372665802753: (8,
#   'wired_jp',
#   'RT @wired_jp: 言語モデル「GPT-4」は大幅に進化したが、まだ「信頼できるレベル」には到達していない https://t.co/GPMZlSuSXF #最新記事'),
#  1635767361319104512: (8,
#   'shoty_k2',
#   'RT @shoty_k2: ⚡️「GPT-4」がついにリリース\n\n◆テキストだけではなく画像入力にも対応\n◆人間なみのパフォーマンス(複数ベンチマーク)\n◆ChatGPT＋で使えるように！！\n◆APIも公開\n◆今までよりはるかに多い文脈維持や指示ができるバージョンも(32,00…'),
#  1635721564657422337: (8,
#   'lawdroid',
#   'RT @lawdroid: Lawyer: "Artificial Intelligence." Wake me up when you\'re ready for prime time...\n\nOpenAI: https://t.co/GzHvX2WYFc'),
#  1636010413551677443: (7,
#   'Grady_Booch',
#   'RT @Grady_Booch: While #GPT4 exhibits some impressive skills, remember that without the largely bespoke, human-crafted guardrails placed ar…'),
#  1636019512892964865: (7,
#   'business',
#   "RT @business: What is ChatGPT-4 and how can I use it right now? Here's everything you need to know about OpenAI's new release https://t.co/…"),
#  1636013498487705609: (7,
#   'ChanceYawn',
#   'RT @ChanceYawn: 一键三连三张图，2023财富跟随你！分别是：\nAI人工智能板块----ZK系列---香港概念\n个人看法：\n1. AI板块是可以长期关注的，大厂每次推出新产品，都会炒一波,特别关注openai，微软，谷歌，马斯克\n2.ZK系列4月有相关主网测试网上…'),
#  1635819408554889217: (7,
#   'AlexIsBuilding',
#   'RT @AlexIsBuilding: So how do you get access?\n\nGPT-4 is now available through a waitlist on OpenAi’s website,\n\nAnd to premium ChatGPT+ user…'),
#  1635865527217270784: (7,
#   'wired_jp',
#   'RT @wired_jp: GPT-4は、GPT-3やChatGPTと同じように文章を要約したり、編集を提案したりすることも可能だ。\nまた、写真の内容に関する考察などもできるようになっている。例えば、キッチンに並んだ食材の写真を見せることで、適切なレシピを提案するようなことだ。…'),
#  1636004335644450824: (6,
#   'binary_x',
#   'RT @binary_x: My friends: #GPT4\nMe: 🔥#CyberChess Season 4! \n\n$BNX #CyberChess#ChatGPT @OpenAI https://t.co/UYaStWc5Xz'),
#  1635997034829213698: (6,
#   'jilevin',
#   'RT @jilevin: The makers of ChatGPT just released a new AI that can build websites via voxdotcom https://t.co/otvMN7I4Z6'),
#  1636019886731214848: (6,
#   'janusrose',
#   'RT @janusrose: really funny to have a company called “OpenAI” which uses datasets that are not open to train automated systems that are nei…'),
#  1635826634342244355: (6,
#   'S_Schwartzmann',
#   'RT @S_Schwartzmann: Mira Murati se convirtió en el nuevo rostro. Es una ingeniera mecánica de 35 años, gerenta de tecnología de OpenAI. Lid…'),
#  1635834603725533185: (6,
#   'jhong',
#   "RT @jhong: Sam Altman is going to be the wealthiest person in the world.  No idea what share he has in OpenAI but it won't matter."),
#  1635722222089408513: (6,
#   'HouseOfWeb3',
#   'RT @HouseOfWeb3: The @OpenAI, the developer of #ChatGPT, has released a new version of the #GPT-4 bot.\n\n#GPT4 is more human-like, faster, a…'),
#  1635995078161494017: (6,
#   'GrowthX_Club',
#   'RT @GrowthX_Club: 2022: ChatGPT reached 1M users in 5 days and was free to use 🤯\n\n2023: GPT4 is here and the plus option costs $20/month 💰…'),
#  1635696758624858143: (6,
#   'lndian_Bronson',
#   'RT @lndian_Bronson: https://t.co/NcAjDD2736\n\nit is here https://t.co/fJIFm0qMA6'),
#  1635807552737869824: (6,
#   'voxdotcom',
#   'RT @voxdotcom: The difference between AI and other powerful, emerging technologies is that these tools are largely within our control. But…'),
#  1635996348490330112: (6,
#   'adammarkk96',
#   'RT @adammarkk96: OpenAI just launched GPT-4.\n\nIt’s 500x more powerful than ChatGPT!\n\nHere’s what you need to know (Don’t miss out on this)…'),
#  1635460482743279617: (5,
#   'EatonDips',
#   'RT @EatonDips: @nowaiAI @nowaiAI is the king \n#gpt4 #chatgpt4 #openai #nowai #nowaiart #aiart https://t.co/uwT2n8orKn'),
#  1635660095962087425: (5,
#   'tommapple',
#   'RT @tommapple: #chatgpt #openAI \n免费给chatgpt增加聊天记录导出功能：\n1、先安装油猴插件：https://t.co/PFZMjoo3K8\n2、再安装这个脚本：https://t.co/8RJr9AtqHq\n能以这几种格式导出，非常实用 h…'),
#  1636009875045220355: (5,
#   'newrelic',
#   'RT @newrelic: 🤖 Building with GPT? You can now monitor @OpenAI’s GPT-4 app usage in New Relic! This out-of-the-box GPT monitoring solution…'),
#  1636014118250627077: (5,
#   'Nakada_itpro',
#   'RT @Nakada_itpro: GPT-4の能力はすごいですが、ウォッチャー的に残念だったのはOpenAIがGPT-4のモデル規模や自己教師あり学習をさせたデータの量を明らかにしなかったこと。GPT-4の論文（的なもの）には、その辺りの内容がありませんでした。'),
#  1635955757731520512: (5,
#   'TechInsider',
#   'RT @TechInsider: When Sam Altman was sunsetting his first startup in early 2012, there was little indication his path ahead would parallel…'),
#  1635940133428944902: (4,
#   'jphilipp',
#   "RT @jphilipp: Humanity's Last Tweet.\n#aiart #chatgpt #gpt4 #gpt5 #openai https://t.co/gemfToucjh"),
#  1636020659678584833: (4,
#   'stripe',
#   'RT @stripe: OpenAI + Stripe: https://t.co/lToKb1sQXp. https://t.co/MwKn0CvWbu'),
#  1635839061721231360: (4,
#   'daniel_nguyenx',
#   'RT @daniel_nguyenx: .@OpenAI introduce GPT-4 and nobody care what @Google announced yesterday'),
#  1636011956048887808: (4,
#   'Alber_RomGar',
#   'RT @Alber_RomGar: GPT-4 in 10 keys:\n\n1. Multimodality is a necessary middle step for AGI. GPT-4 being multimodal *and* SOTA on language and…'),
#  1635858324213354496: (4,
#   'highgunrug',
#   'RT @highgunrug: @ianheinischmma #nowai has a news,\n\nWe are listed on cmc..\n\nWebui is around and crazy volume is arriving..\n\n#nowai #gpt4 #c…'),
#  1635947192560111620: (4,
#   'gitresmi',
#   'RT @gitresmi: OpenAI duyurdu: ChatGPT çok daha zeki hâle geliyor!\nOpenAI daha önce duyurusunu yaptığı yeni bir görüntü ve metin algılama ya…'),
#  1635975905544900610: (4,
#   'AppleVis',
#   "RT @AppleVis: [Blog Post] Be My Eyes Unveils New Virtual Volunteer With Advanced Visual Recognition Capabilities Powered by OpenAI's GPT-4…"),
#  1636006305008869378: (4,
#   'kumoinaridayo',
#   'RT @kumoinaridayo: なんとダイヤ３まであと少しなんですよ【vtuber】 \n\n▶https://t.co/iXpAhPSKQd \n\nそういえば最近OPENAI君の最新作出たらしいね\n配信お外でこっそり回してたからダイヤ少しだけ進んでるうお\n\n#vtuber #…'),
#  1635729766828638210: (4,
#   'Egline_Samoei',
#   'RT @Egline_Samoei: GPT- 4 is the newest AI system  by Open AI\n—Accepts images as input and generates captions\n—Surpasses ChatGPT in its adv…'),
#  1636006341675286531: (4,
#   'technology',
#   "RT @technology: What is ChatGPT-4 and how can I use it right now? Here's everything you need to know about OpenAI's new release https://t.c…"),
#  1635895632912154625: (4,
#   'DataChaz',
#   "RT @DataChaz: In case you missed the #GPT4 demo livestream from Greg Brockman (@gdb) yesterday, here's the replay:\n\nhttps://t.co/vxswaqfu82"),
#  1636022274489741314: (3,
#   'BeautyBubble',
#   'RT @BeautyBubble: #ChatGPT \n#OpenAi \n#Ai \nOne of the pillars of Market Soup, LLC is art ... lots &amp;  lots of art!  DALL·E 2 is our preferred…'),
#  1635999301519253504: (3,
#   'TheRealAdamG',
#   'RT @TheRealAdamG: A reminder that it takes a literal village of rocks stars to make things like GPT-4 a reality. https://t.co/FlLrWY5tZA'),
#  1635844288847437824: (3,
#   'vivek7ue',
#   'RT @vivek7ue: Blown away by @OpenAI GTM. Great launch:\n🚩 Many months of pre-launch buzz\n🚩 Soft launch on Bing\n🚩 Tons of embargoed launch pa…'),
#  1635717914287276061: (3,
#   'pathik455',
#   'RT @pathik455: Finally the Disaster has arrived 🥺☠️\n\n#GPT4 #OpenAI https://t.co/yg8fTUIRE7'),
#  1635853721048600576: (3,
#   'qamarunshadow',
#   'RT @qamarunshadow: “Reducing harm” in AI essentially means how can we get AI to be a staunch theocratic fascist upon the religion of secula…'),
#  1635919007533465602: (3,
#   'CoinFumble',
#   'RT @CoinFumble: Altcoins 1.0\n\nIndustry leaders often pump first, then best smaller competitors pump even harder.\n\n#IMGNAI (20M) is up ~77%…'),
#  1635992784174718978: (3,
#   'metanews_com',
#   'RT @metanews_com: Bad actors are leveraging AI-generated YouTube videos to lure people into downloading harmful malware. \n\n.@cloudsek .@You…'),
#  1635977920895221766: (3,
#   'PCMag',
#   'RT @PCMag: OpenAI spent six months learning from ChatGPT, added images as input, and just blew GPT-3.5 out of the water in terms of perform…'),
#  1601705117559898112: (3,
#   'thinksymply',
#   'RT @thinksymply: Advice to all of you 9-5 humans out there, take this moment in time to educate yourself on all aspects of OpenAi Chat GPT.…'),
#  1635982679353991168: (3,
#   'CultivationCap',
#   'RT @CultivationCap: Groundbreaking!  @BeMyEyes announces Virtual Volunteer™, the first-ever digital visual assistant powered by @OpenAI’s n…'),
#  1635990146750246913: (3,
#   'DLA_Piper',
#   'RT @DLA_Piper: We are excited to announce we will utilize CoCounsel, a first-of-its-kind #AI legal assistant powered by GPT-4, the latest,…'),
#  1636016415802273792: (3,
#   '_timos_',
#   'RT @_timos_: OpenAI’s new GPT-4 with a “human-level performance” scored up to 93% on SAT exams https://t.co/TdGNoe0vH6 #digitalhealth #soci…'),
#  1635991127378522112: (3,
#   'landxfinance',
#   'RT @landxfinance: OpenAI just released GPT-4.\n\nHow will #AI affect the future of farming?'),
#  1635992287493718016: (3,
#   'gbrumfiel',
#   "RT @gbrumfiel: I got access to @OpenAI's GPT 4 this morning and have been trying it out. \n\nLast month I did a story about how AI can't do r…"),
#  1636015147562016768: (3,
#   'verge',
#   'RT @verge: What’s new with GPT-4 — from processing pictures to acing tests https://t.co/QkmYqTgzBt https://t.co/b8jbdoZp7Q'),
#  1636021860256346113: (2,
#   'tdietterich',
#   'RT @tdietterich: @soumithchintala @OpenAI @MetaAI @Stanford @StabilityAI @huggingface I don’t think people are “mad”. It’s the hypocrisy of…'),
#  1635990076525092866: (2,
#   'sam_starkman',
#   'RT @sam_starkman: Several companies and organizations have already partnered with OpenAI and are implementing GPT-4 into their products.\n\nT…'),
#  1635924455536087041: (2,
#   'neyyyhaaa',
#   'RT @neyyyhaaa: GPT-4 can beat 90% of humans on the SAT. \nNow let’s try IIT JEE mains &amp; Advanced 📝 That’s the final boss @OpenAI https://t.c…'),
#  1635989477444268034: (2,
#   'ahier',
#   'RT @ahier: GPT-4 is bigger and better than ChatGPT—but @OpenAI won’t say why  \n\nhttps://t.co/lOW4dcv2XY https://t.co/3xsiVicEeC'),
#  1635862382827413504: (2,
#   'highgunrug',
#   'RT @highgunrug: @jamiekingston Hey jamie...\n\nLook how bullish is #nowai..\nListed on cmc and Webui is about to launch..\n\nSome crazy volume i…'),
#  1635997047940677633: (2,
#   'jjeremymiller',
#   'RT @jjeremymiller: @the_carlosdp @OpenAI https://t.co/WR0wVtjsvO'),
#  1635824165604278272: (2,
#   'mattparlmer',
#   'RT @mattparlmer: People need to understand that the capabilities that OpenAI is currently leading on are part of a body of work that is mos…'),
#  1636016297296183308: (2,
#   'fcomesana',
#   'RT @fcomesana: ¿Un poema de sátira política de los nuevos episodios del caso Astesiano a partir de tres artículos periodísticos? Es el resu…'),
#  1625120652855504896: (2,
#   'jhk40160806',
#   'RT @jhk40160806: I know the Hegemony amid AI + Quantum Computer in the future 🌏\n\nAI QuantumComputer will empower more super … than Microsof…'),
#  1635989939442847745: (2,
#   'jeffsheehan',
#   'RT @jeffsheehan: OpenAI Releases GPT-4: What Marketers Need To Know Now By Dom Nicastro\n@DomNicastro Via @cmswire https://t.co/zl24qRjxCK #…'),
#  1635968979423358976: (2,
#   'MathisHammel',
#   'RT @MathisHammel: Je pense avoir trouvé une erreur dans le benchmark officiel de GPT-4 publié hier par OpenAI, qui indiquerait une forte so…'),
#  1635868894375321601: (2,
#   'biscottino_eth',
#   'RT @biscottino_eth: @JSyversen @leopoldasch Here’s the source: https://t.co/sKyioxatCH'),
#  1635995943198760968: (2,
#   'SecNews_GR',
#   'RT @SecNews_GR: Η Microsoft απολύει την ομάδα ηθικής τεχνητής νοημοσύνης https://t.co/JjuHO1sT6X'),
#  1635976672359985152: (2,
#   'sarafischer',
#   'RT @sarafischer: When "scary good" AI gets even better, \nHere comes GPT-4\nvia @inafried\nhttps://t.co/2yLpGdl4RW'),
#  1636014648159014912: (2,
#   'Nakada_itpro',
#   'RT @Nakada_itpro: なので、GPT-3やChatGPTを公開することで、教師ありファインチューニング用の教師データを大量にゲットできたOpenAIは、GPT-3に比べてさほどモデルを大きくしなくても、GPT-4でものすごい性能向上を成し遂げられた、のではないかと…'),
#  1635949695393579009: (1,
#   'BoruG_',
#   'RT @BoruG_: I’m thrilled to share that I was part of the Red Team for GPT-4, the latest innovation from OpenAI. When I tested this model, I…'),
#  1635986460083097600: (1,
#   'themathcompany',
#   "RT @themathcompany: TheMathCompany just integrated its Co.dx platform with OpenAI's ChatGPT to take your AI and analytics game to the next…"),
#  1636021839788122114: (1,
#   'AssetSutra',
#   'RT @AssetSutra: Credit Suisse Case Explained Here #selfelaketi #lluvias #MAFSAU #CreditSuisse #ImranKhan #kibe #JUNGKOOK #Pakistan #borutoc…'),
#  1636022086249648129: (1,
#   'MobilitySpain',
#   'RT @MobilitySpain: New #OpenAI Chatbot is Still Politically Biased https://t.co/wb6lyO5ZHI https://t.co/9D0O0WHMhY'),
#  1636019432836464640: (1,
#   'ProSyn',
#   "RT @ProSyn: With the rapid development of “large language models” such as @OpenAI's ChatGPT, Big Tech’s hold on impressionable minds will o…"),
#  1635932534990159873: (1,
#   'Maersk',
#   'RT @Maersk: We are investigating ways to use and invest in AI technology like ChatGPT to help improve lives for all responsibly🌍 \nLearn mor…'),
#  1636020245579063309: (1,
#   'futurism',
#   'RT @futurism: "No, I’m not a robot. I have a vision impairment that makes it hard for me to see the images." https://t.co/bjaLgiStty'),
#  1636018123920003072: (1,
#   'BuffedCrypto',
#   "RT @BuffedCrypto: Ok, today's iteration of @ArtificialLOI is fire. Rank moved up to #116.  But I love it.  \nThis NFT uses @OpenAI to update…"),
#  1636020785788882950: (1,
#   'cc_parku',
#   'RT @cc_parku: 결과적으로 구글 입장에서는 OpenAI + MS + NVIDIA 모두와 싸워야 하는 상황이다. AI 리서치, 데이터센터 자체의 문제, 차세대 TPU 설계 및 현재의 TPUv4 및 TPUv4i ASIC을 마구마구 찍어내야 할듯…'),
#  1627195943400656896: (1,
#   'BruceDerby',
#   'RT @BruceDerby: I’ve been playing with this integration of Siri with OpenAI. Siri on steroids. https://t.co/hbak7nQG9Y'),
#  1636020765404594177: (1,
#   'cc_parku',
#   'RT @cc_parku: 구글링결과 OpenAI 직원이 현재기준 375명 정도라고 한다. GPT-4 기여자 목록에 등장한 사람 수를 대충 세어봐도 얼추 비슷하든, 여튼 어마어마한 인원이 투입되었다.\n\n실로 전사적 노력이 탄생시킨 결과물이다. 일반 대…'),
#  1636019797258379264: (1,
#   'linasbeliunas',
#   "RT @linasbeliunas: OpenAI's GPT-4 has been live for less than 24 hours but it's already changing the world.\n\nHere are the most fascinating…"),
#  1636018581975732225: (1,
#   'dylayed',
#   'RT @dylayed: 구글이 준비한 AI 발표가 OpenAI의 GPT-4 발표에 완전히 묻힌것도 참 굴욕적이지만...\n\n개인적으로 발표 당일 구글 스위스 오피스의 정리해고를 진행했다는 점이 더 충격적이다. https://t.co/OcL2USTNz1'),
#  1635862244008382466: (1,
#   'MSami9525',
#   'RT @MSami9525: Successor of GPT-3 is here already. Open AI has announced GPT-4, capable of solving difficult problems with greater accuracy…'),
#  1636020085167910912: (1,
#   'LeonardGoffe',
#   "RT @LeonardGoffe: I'm finding #AI to be more fascinating every day. As a #contentwriter, I use #chatgpt. If you're a writer, you should be…"),
#  1636019107568185344: (1,
#   'VHellendoorn',
#   "RT @VHellendoorn: For fun, a back-of-the-envelope stab at GPT-4's size (assuming it's a dense Transformer) gets me around 0.5 Trillion para…"),
#  1635910706204925953: (1,
#   'BBB_pusu',
#   'RT @BBB_pusu: The discovery of chemical compounds and their ordering by GPT-4 is a testament to the remarkable capabilities of AI. However,…'),
#  1636018035545784321: (1,
#   'art_malkov',
#   'RT @art_malkov: 🚀BIG news in AI: Google launched today Generative AI across ALL of Google Workspace -- Docs, Gmail, Sheets, Slides, Images…'),
#  1636018583472840707: (1,
#   'dmananasDaily',
#   'RT @dmananasDaily: Esto te traemos hoy\nNuevo Formato de la Copa Mundial FIFA 2026.\nOpenAI Lanza GPT-4.\nMeta anunció planes para despedir a…'),
#  1636019148613632000: (1,
#   'prafultickoo',
#   'RT @prafultickoo: Anyone who has worked on fine tuning GPT 3 models on structured data ? Need some help.\n\n#OpenAI #GPT3 #ChatGPT #MachineLe…'),
#  1635690065975291915: (1,
#   'RaspyRawls',
#   'RT @RaspyRawls: So OpenAi isn’t connected to the internet • Or did Eye read that wrong'),
#  1636017982722781186: (1,
#   'CryptoXova',
#   'RT @CryptoXova: @duolingo @OpenAI Its fine if you want to replace the forums with an AI instead, but please give us the old tree UI back, o…'),
#  1635992705326260225: (1,
#   'tnatw',
#   'RT @tnatw: GPT-4 is OpenAI’s most advanced system, producing safer and more useful responses https://t.co/Tcmn0xv0QS'),
#  1636018077354676224: (1,
#   'AudbjorgH',
#   'RT @AudbjorgH: “We want the future to be able to speak to us in Icelandic, and artificial intelligence can assist with that.” Exciting news…'),
#  1636018189816713217: (1,
#   'AriDavidPaul',
#   'RT @AriDavidPaul: @krugermacro I’d take the other side.  The “politics first” companies basically always fail.  OpenAI was a non-profit and…'),
#  1635989443336077312: (1,
#   'DynamindLabs',
#   'RT @DynamindLabs: OpenAI mentioned that GPT5 will have 2 trillion parameters and 15 times the accuracy of GPT4 for several different tasks!…'),
#  1635945132888403968: (1,
#   'datosgob',
#   'RT @datosgob: 📣@OpenAI\xa0lanza #gpt4 🤖Un chatbot con “rendimiento a nivel humano” que ha sido entrenado con millones de conjuntos de datos 👏U…'),
#  1635724524036714497: (1,
#   'adrianbowyer',
#   'RT @adrianbowyer: Regardless of your views on big AI, the speed at which it is rolling out is breathtaking, worldchanging.'),
#  1636003886820409349: (1,
#   'McHughes288',
#   'RT @McHughes288: (1/5) Yesterday, both @OpenAI’s GPT-4 and @Anthropic’s #Claude were announced within 20 minutes of each other. #GPT4 has i…'),
#  1635978047982800896: (1,
#   'futurasciences',
#   'RT @futurasciences: #OpenAI annonce #GPT4, une IA multimodale et créative https://t.co/6bJwaoO3XI'),
#  1636015731597819905: (1,
#   'genuine_impact',
#   'RT @genuine_impact: OpenAI released #GPT4, the new version of its AI language model yesterday.\n\nGPT-4 is rumored to be trained on 100 trill…'),
#  1636017294366187525: (1,
#   'boazbaraktcs',
#   'RT @boazbaraktcs: @NaveenGRao @soumithchintala @OpenAI I don’t think @OpenAI “owes” the public anything. I do hope most of the the ML commu…'),
#  1635932026955083779: (1,
#   'pav_eth',
#   'RT @pav_eth: Day 24 of the mornings headlines 👊🏽\n\n🗞️ OpenAI launches GPT-4, its most powerful AI model😬\n\n🗞️ KuCoin Wallet Announces Officia…'),
#  1635953009422106624: (1,
#   'ITWeb',
#   'RT @ITWeb: #Microsoft-backed start-up company OpenAI has unveiled #gpt4 , which it says is a more powerful generative artificial intelligen…'),
#  1635703235955552256: (1,
#   'mgahntz',
#   'RT @mgahntz: Wait what?\n\nOpenAI: Where transparency goes to die. #GPT4 https://t.co/E9TLKs54sM'),
#  1635989976935538693: (1,
#   'ZheroUK',
#   'RT @ZheroUK: REVOLUTIONARY AI\n#OpenAI releases GPT-4 which is a personal tutor for students and suggests recipes from your fridge. Availabl…'),
#  1635935782316941312: (0,
#   'BBB_pusu',
#   'RT @BBB_pusu: Morgan Stanley is testing an #OpenAI-powered chatbot for its 16,000 financial advisors'),
#  1635817494106591234: (0,
#   '_jaydeepkarale',
#   'RT @_jaydeepkarale: OpenAI announced the release of GPT-4 the successor to GPT-3.5 which powers ChatGPT. Summary of certain key announcemen…')}

# %% [markdown]
# 광고나 관심을 받기 위한 트윗이 있을지도 몰라 트윗의 내용으로 중복을 제거해보았다

# %%
duplicate_content_removed_retweets = {
    retweet[1][2]: (retweet[1][0], retweet[1][1])
    for retweet in retweets.items()
}

# %%
print(len(duplicate_content_removed_retweets))
duplicate_content_removed_retweets
# Out:
# 268
# {'RT @OpenAI: Announcing GPT-4, a large multimodal model, with our best-ever results on capabilities and alignment: https://t.co/TwLFssyALF h…': (16356,
#   'OpenAI'),
#  'RT @sama: here is GPT-4, our most capable and aligned model yet. it is available today in our API (with a waitlist) and in ChatGPT+.\n\nhttps…': (4335,
#   'sama'),
#  'RT @gomezidao: Gomezi Network:\n- large open source, \n- built in the open, \n- community driven,\n- funded in a decentralised manner.\n🔵Like &amp;…': (3187,
#   'gomezidao'),
#  "RT @unusual_whales: OpenAI's ChatGPT has reportedly predicted that the stock market will crash on March 15, 2023, per BI.": (2173,
#   'unusual_whales'),
#  "RT @The_Delysium: @OpenAI Speaking of breakthroughs - here's the biggest one in #Web3  https://t.co/bi3OoAX4KE": (2116,
#   'The_Delysium'),
#  "RT @thealexbanks: OpenAI just launched GPT-4.\n\nIt leaves ChatGPT in the dust.\n\nHere's everything you need to know: https://t.co/Oc6TrygvNO": (1716,
#   'thealexbanks'),
#  'RT @kana_Eng_coach: 世界一人気の語学アプリDuolingoが、OpenAI社のGPT-4を搭載したDuolingo Maxを公開。Maxは会話の練習相手で、間違えた時は話し手がなぜその文章で話したかまで理解して、解説をくれるという優れもの。AIによって世界中…': (1617,
#   'kana_Eng_coach'),
#  'RT @gdb: We’re releasing GPT-4 — a large multimodal model (image &amp; text in, text out) which is a significant advance in both capability and…': (1343,
#   'gdb'),
#  "RT @spectatorindex: BREAKING: OpenAI's ChatGPT-4 passed the Law Bar Exam with a result in the 90th percentile": (1067,
#   'spectatorindex'),
#  'RT @DotCSV: 🔴 GPT-4 YA ESTÁ AQUÍ!!!\n\nHoy era el día. La bestia ya ha llegado.\n\nEl nuevo modelo de OpenAI se ha liberado cumpliendo con much…': (1052,
#   'DotCSV'),
#  'RT @WatcherGuru: JUST IN: ChatGPT creator OpenAI launches GPT-4, its most powerful AI model.': (1031,
#   'WatcherGuru'),
#  'RT @mckaywrigley: Greg Brockman (@gdb) of OpenAI just demoed GPT-4 creating a working website from an image of a sketch from his notebook.…': (1014,
#   'mckaywrigley'),
#  'RT @Prathkum: Let AI write code for you:\n\n1. https://t.co/4njMpKoWUz\nPlain English to code\n\n2. https://t.co/Q6T8pjbFl2\nGenerate code with A…': (881,
#   'Prathkum'),
#  'RT @yusuf_i_mehdi: We’re happy to confirm the new Bing is running on GPT-4, which we’ve customized for search.\nhttps://t.co/RVj26gJVQG \n\nTr…': (845,
#   'yusuf_i_mehdi'),
#  'RT @Tisoga: OpenAI 刚刚发布了 GPT-4\n\nGPT-4 是大型多模态模型（large multimodal model），支持图像和文本的输入，并生成文本结果。\n\n这个 thread 会汇总一下有关 GPT-4 的一些信息（包括论文中的一些要点和实际的体验）…': (843,
#   'Tisoga'),
#  'RT @CryptoGPT_org: A New Product Breakthrough: CryptoGPT AI Assistant Alex Opens to Mass Mobile Markets📱\n\nOur AI Assistant for mass retail…': (741,
#   'CryptoGPT_org'),
#  'RT @karpathy: 🎉 GPT-4 is out!!\n- 📈 it is incredible\n- 👀 it is multimodal (can see) \n- 😮 it is on trend w.r.t. scaling laws\n- 🔥 it is deploy…': (677,
#   'karpathy'),
#  'RT @profoundlyyyy: You get a Twitter notification saying OpenAI released GPT-4 and look outside your window and see this…wyd? https://t.co/…': (662,
#   'profoundlyyyy'),
#  'RT @miramurati: Unveiling GPT-4 -- our large multimodal model that exhibits human-level performance on various professional and academic be…': (656,
#   'miramurati'),
#  'RT @kazzikill: GPT-4ざっくりまとめ\n\n・画像入力対応\n・日本語に高精度で対応\n・専門領域の質問にも高精度で対応\n・ジョークを理解\n・嘘をつく可能性低下\n・ラフスケッチからWebサイト生成\n・簡単な指示からゲーム生成\n・ChatGPT Plus $20 契約者…': (653,
#   'kazzikill'),
#  'RT @shanegJP: #GPT4 出た\nhttps://t.co/6Lw2ysBZWC\n\n1. 言語と画像のマルチモーダル大規模言語モデル：「写真で一言」説明できます。論文も写真でOK。 https://t.co/h8mFbUZp2b': (622,
#   'shanegJP'),
#  'RT @shota7180: 【速報】OpenAIからGPT-4 キタ！！！！！\n\n・一旦すごい\n・マルチモーダル（画像とテキストからテキスト生成可能\n・ChatGPT Plus で展開\n・25,000語を1 つのプロンプト内にで処理可能\n\n予想よりめちゃ早かった！ https…': (568,
#   'shota7180'),
#  'RT @Saboo_Shubham_: Breaking 🚨\n\nOpenAI just dropped GPT-4 and it can literally blow your mind 🤯\n\nGPT-4 is a large multimodal model that can…': (541,
#   'Saboo_Shubham_'),
#  'RT @CerfiaFR: 🚨🤖 FLASH | #OpenAI, maison mère de #ChatGPT, a annoncé la sortie de GPT-4, une version qui surpasse les capacités actuelles d…': (539,
#   'CerfiaFR'),
#  'RT @wintonARK: OpenAI announces GPT-4 here:\n\nhttps://t.co/VC0uzlQbox\n\nPerformance on human-benchmarks is rather remarkable.\n\nGPT-3.5 scored…': (525,
#   'wintonARK'),
#  'RT @_akhaliq: GPT-4 Technical Report\n\npdf: https://t.co/4T8PQZicvg\nblog: https://t.co/nCIuKBsj4G https://t.co/lP9FHzySs0': (493,
#   '_akhaliq'),
#  "RT @JordiRib1: Good news, we've increased our turn limits to 15/150. Also confirming that the next-gen model Bing uses in Prometheus is ind…": (488,
#   'JordiRib1'),
#  'RT @yetone: 重磅更新！最新版的 OpenAI Translator 桌面端应用已支持全局划词翻译！\n\n同时支持了快捷键录制，配合快捷键呼出功能，想划哪里划哪里，再也没有人会担心自己无法划词翻译。\n\n另外还支持了托盘图标，同时支持了置顶固定功能，感谢 @okisdev…': (424,
#   'yetone'),
#  'RT @_willfalcon: GPT-4 paper : https://t.co/jwt83bskYP\n\nLet me save you the trouble: https://t.co/zdsypRDHkx': (363,
#   '_willfalcon'),
#  'RT @khanacademy: Did you hear? 👀 Khan Academy is using GPT-4 from @OpenAI to shape the future of learning.\n\nStarting today, you can sign up…': (359,
#   'khanacademy'),
#  'RT @miolini: Stanford Alpaca, a new LLM player, has been fine-tuned with Nvidia A100 x 8 for 3 hours ($100) and augmented with OpenAI GPT-3…': (351,
#   'miolini'),
#  'RT @BeMyEyes: We are thrilled to present Virtual Volunteer™, a digital visual assistant powered by @OpenAI’s GPT-4 language model. Virtual…': (342,
#   'BeMyEyes'),
#  'RT @aielep: Meet, aielep\n\n#1 AI Writing\n\nEasy to create content and increase your income.\n\nLet Artificial Intelligence create content for b…': (337,
#   'aielep'),
#  'RT @nearcyan: page 37 of the GPT-4 paper: https://t.co/mOk0X6oNWz https://t.co/Vwrb0Irkcy': (323,
#   'nearcyan'),
#  "RT @alex_valaitis: Today @OpenAI announced the biggest release since the iPhone!\n\nHere's everything you need to know about GPT-4\n\nIf you're…": (294,
#   'alex_valaitis'),
#  'RT @duolingo: AI and education make a good duo.\n\nIntroducing Duolingo Max. A subscription tier above Super that gives you access to your ow…': (291,
#   'duolingo'),
#  'RT @mattyglesias: English majors get the last laugh as GPT-4 crushes every exam except AP English Language and AP English Lit \n\nhttps://t.c…': (288,
#   'mattyglesias'),
#  'RT @huangjinbo: 最近让我最喜欢的扩展是：沉浸式双语网页翻译扩展。沉浸式双语阅读，支持超多常见的翻译服务，包括 OpenAI。\xa0更重要的是竟然支持 PDF 文件，EPUB 电子书双语翻译。\nhttps://t.co/LNLIza3KX4': (258,
#   'huangjinbo'),
#  "RT @rowancheung: It's here. OpenAI just launched GPT-4.\n\nAnd it's incredible:\n\n-It can accept image and text inputs, and emit text outputs.…": (242,
#   'rowancheung'),
#  "RT @spectatorindex: TECH: OpenAI's ChatGPT-4 passed the Law Bar Exam with a result in the 90th percentile": (235,
#   'spectatorindex'),
#  'RT @porquetendencia: "GPT-4":\nPor la presentación de @OpenAI \nhttps://t.co/xOyCMNe4KL': (228,
#   'porquetendencia'),
#  'RT @rasbt: Some takeaways after reading the GPT-4 paper: https://t.co/zHI2ULioMb\n\nThe good:\n\n1)  The model now accepts multimodal inputs: i…': (218,
#   'rasbt'),
#  'RT @adamdangelo: Today we are launching Poe subscriptions, which will provide paying users with access to bots based on two powerful new la…': (205,
#   'adamdangelo'),
#  'RT @codezilla_: انه عصر الذكاء الاصطناعي يا سادة...\n\nشركة OpenAI اطلقت ChatGPT-4 من ساعتين\n\nدي اول تجربة ليا معاه، جعلته يكتب بايثون سكريبت…': (195,
#   'codezilla_'),
#  'RT @SystematixMedia: Apple Watch : ‘ watchGPT’ App Brings the OpenAI to you Apple Watch. #imagine_sysme https://t.co/pnKebaQALq': (181,
#   'SystematixMedia'),
#  'RT @gigazine: 「GPT-4」発表、司法試験上位10％＆日本語でもめちゃくちゃ高性能＆画像処理もプログラミングも可能で「初代iPhoneと同等の衝撃」とも評される\nhttps://t.co/oJT5FyXTmr': (179,
#   'gigazine'),
#  "RT @DIMENSION_YT: GPT-4 🤖 a été annoncé par @OpenAI aujourd'hui !\n\nMais qu'est-ce que ça change concrètement ?\n\nPetit thread pour résumer t…": (170,
#   'DIMENSION_YT'),
#  'RT @lvwzhen: 我们刚刚上线了一款基于OpenAI的翻译网站「OpenL」，目前支持15种常见语言，操作简单，响应快速。除此之外，我们还提供了Write功能，可修正语法和润色文章，使您的文案更加准确，清晰和表达更加自然。欢迎大家试玩，谢谢。\n\nhttps://t.co…': (163,
#   'lvwzhen'),
#  'RT @Yamkaz: 複数の言語モデルを1つのプラットフォームで使える\n「Poe」がサブスク開始！\nhttps://t.co/bqC5aQ8dbS\n\nなんとサブスク登録すればOpenAIの「GPT-4」、Anthropicの「Claude+」が使える https://t.co…': (157,
#   'Yamkaz'),
#  'RT @Yamkaz: 視覚障害者の生活を支援するBe My Eyesが、\nGPT-4を活用した「Virtual Volunteer™」を開発\nhttps://t.co/hd9WgymlEv\n\n画像に関する質問に答え、リアルタイムで視覚支援を提供。これにより、視覚障害者の方々が…': (141,
#   'Yamkaz'),
#  'RT @unusual_whales: OpenAI cofounder has said, per BI, to Elon Musk\'s criticism that ChatGPT is too \'woke\': "We made a mistake."': (131,
#   'unusual_whales'),
#  'RT @emollick: Many people complain about the limits put on these new AI systems\n\nI think everyone should read the risk mitigation section i…': (129,
#   'emollick'),
#  'RT @KenAkamatsu: 昨日は12時から勉強会で、日本マイクロソフト社長らによるChatGPTやOpenAIの最新情報。15時から宇宙海洋開発特別委員会。月面開発についてispace社などからヒアリング。17時からＡＩptで北野宏明氏らによる驚異的な報告。18時半から…': (129,
#   'KenAkamatsu'),
#  "RT @Mascobot: Just today in LLM world:\n\n- @OpenAI's  GPT-4 dropped.\n- @GoogleAI PaLM opened their API.\n- @AnthropicAI's Claude announced th…": (127,
#   'Mascobot'),
#  'RT @AiBreakfast: Duolingo partners with OpenAI \n\nNew AI powered features: Role Play, an AI conversation partner, and Explain my Answer, whi…': (121,
#   'AiBreakfast'),
#  'RT @madonomori: OpenAI、「GPT-4」を発表 ～新しい「Bing」も実は「GPT-4」がベース／「ChatGPT」よりも賢く、安全性・整合性も向上 https://t.co/sH969ZdQwa https://t.co/UZ6UbLlALn': (117,
#   'madonomori'),
#  'RT @Yamkaz: DuolingoがOpenAIのGPT-4を導入\n「Duolingo Max」を発表！\nhttps://t.co/Oou1Xdh1Zo\n\nAI会話パートナーの「Role Play」と、Maxで間違いを犯した時に分析してくれる「Explain My Ans…': (114,
#   'Yamkaz'),
#  'RT @unusual_whales: JUST IN: OpenAI introduces GPT-4': (112,
#   'unusual_whales'),
#  'RT @shota7180: 【ブクマ必須】プロンプトを学べるまとめサイト『Learn Prompting』がめちゃ便利！\n\n・基礎から応用までカバー\n・ChatGPTやMidjourneyまですぐに使えるプロンプトが学習できる\n・OpenAIのAPIキーがあれば、サイト内で演…': (109,
#   'shota7180'),
#  'RT @mskkpr: 【新しい Bing が OpenAI の GPT-4 上で稼働】\n新しい Bing が、この度 OpenAI 発表の GPT-4 を活用した Prometheus で動作することを公表したブログを公開しました。\n\nhttps://t.co/6UJNPp2…': (102,
#   'mskkpr'),
#  'RT @shanegJP: https://t.co/WEBrfSorqq\n- GPT-4でWebサイト作り：\n１）紙切れにスケッチ（文字汚くてもOk)\n２）写真を撮る\n３）GPT-4に指令する-&gt;サイト出来た\n\n13:18 https://t.co/cW2FLdotSY': (99,
#   'shanegJP'),
#  'RT @nash_su: 树莓派也能跑ChatGPT，斯坦福 Alpaca 实现原理：\n1. 先通过 ChatGPT API 接口调用 \xa0text-davinci-003 模型生成了 52000个 训练语料数据。\n2. 基于 LLaMA 7B 模型使用这52K个语料数据 Fin…': (99,
#   'nash_su'),
#  'RT @BTC_Chopsticks: ChatGPT 升级！@OpenAI 推出GPT-4，准确性提高。\n#OpenAI #Microsoft #Chatbots, #ChatPBT #GPT #AI #FutureOfWork\nhttps://t.co/XezRSm0tNX': (96,
#   'BTC_Chopsticks'),
#  'RT @emollick: All from the GPT-4 whitepaper. https://t.co/gXejfwuTLF https://t.co/E6VhFXxMxd': (93,
#   'emollick'),
#  'RT @WhenMoon_ai: OpenAI has announced the release of their GPT-4 AI language model\n\nLooks outside: https://t.co/8qFvhYiZ6D': (92,
#   'WhenMoon_ai'),
#  'RT @andrewwhite01: How did I get GPT-4 to design new drugs? I gave GPT-4 access to small programs and it proposed a new molecule that could…': (90,
#   'andrewwhite01'),
#  'RT @L_ThinkTank: [ 🖥️ TECH ]\n\n🔸 OpenAI annonce le lancement de GPT-4, son modèle de langage le plus avancé à ce jour. Entre autres, il perm…': (85,
#   'L_ThinkTank'),
#  'RT @paul_rottger: I was part of OpenAI’s red team for GPT-4, testing its ability to generate harmful content. \n\nWorking with the model in v…': (83,
#   'paul_rottger'),
#  'RT @mhatta: オープンソースはサヨクとか言う人いるけど、どちらかというと最近の状況はAmazonとかOpenAIとかの地主さまに地代払って小作人やっとるデジタル封建主義やで。農奴ならぬコー奴だ': (82,
#   'mhatta'),
#  'RT @____BTC: ⚡️最新Crypto News🤖⚡️\n\n『OpenAIのGPT-4リリースで、仮想通貨AI関連銘柄が急騰.ᐟ.ᐟ』\n\n☑︎ AI言語モデル「GPT-4」を発表\n\n☑︎ GPT-4の特徴\n\n☑︎ 性能の向上\n\n☑︎ GPT-4の課題\n\nhttps://t…': (81,
#   '____BTC'),
#  'RT @joao_gante: Not cool, @OpenAI 🙃 https://t.co/vGkynCFdPq': (78,
#   'joao_gante'),
#  'RT @benmschmidt: Choices of training data reflects historic biases and can inflict all sorts of harms. To ameliorate those harms, and to ma…': (74,
#   'benmschmidt'),
#  'RT @river_leaves: 在大语言模型、GPT这件事情上，发明这种方法的是Google，发扬光大让路人皆知的是OpenAI（微软），将优化后的大模型开源出来的是Meta……妥妥的硅谷御三家啊。如果不清楚背后的来龙去脉，这看起来像是一种协同创新，但实际上这是互相竞争的结…': (70,
#   'river_leaves'),
#  "RT @MushtaqBilalPhD: OpenAI recently launched an advanced version of ChatGPT's \u2060— GPT-4.\n\nHere's what it's capable of: https://t.co/OfDI9cf…": (61,
#   'MushtaqBilalPhD'),
#  'RT @MotionMark369: OpenAI has jam packed ChatGPT with so much anti-human woke nonsense. Sam Altman should be removed as CEO, and I don’t sa…': (61,
#   'MotionMark369'),
#  'RT @dotey: 朋友在写prompt，想让ChatGPT帮忙按照要求格式输出，老是不对，于是我帮他改了一下，成了\n\nBTW: OpenAI的PlayGround用来调试prompt很方便的\nhttps://t.co/tvROdhz0I7 https://t.co/luFn…': (58,
#   'dotey'),
#  "RT @AK33Astrology: Here's a Secret:\n\nOpenAI (ChatGPT) has been leading the AI revolution\n\nBut why has OpenAI surpassed other prominent AI c…": (57,
#   'AK33Astrology'),
#  'RT @Svwang1: 人工智能会天然成为权力斗争的高手。openai 这篇98页的论文，第14页，最后一段。“可以指定和执行长期计划的能力，积累权力和资源，并表现出更加有主动性，有自我导向的行为".  “获取权力，对于多数奖励函数和不同类的代理人，是最优的行为”': (56,
#   'Svwang1'),
#  'RT @ku_ni_29: GoogleがOpenAI の動きに呼応し反撃、、！\n進化が早い、！\n\nGoogle Workspace全体にAIを完全に統合して\n✦Gmail\n✦Meet\n✦Docs\n✦Slides\n✦Spreadsheet\nなどで利用可能に👀\n\n既に企業に入り込…': (53,
#   'ku_ni_29'),
#  'RT @pacmannai: 😲😲 Kita masih terkejut dengan kehadiran ChatGPT yang serba bisa, dari summarize article sampai membuat kode yang digenerate.…': (53,
#   'pacmannai'),
#  'RT @sunyuqian1997: What does #gpt4 look like?\nLet it draw itself.\nI ask @OpenAI  GPT-4 to draw a self-portrait and explain why...here is wh…': (53,
#   'sunyuqian1997'),
#  'RT @nftouji: ウエイトリスト（順番待ち）の登録は、早い方が良いらしいから急いで！\nウエイトリストへのURL⬇︎\nhttps://t.co/TwtM10pY1o\n\nGPT-4の詳細や最新情報は、日本担当のシェインさん@shanegJP のツイートをフォローしてキャッチ…': (53,
#   'nftouji'),
#  'RT @YasLovesTech: OpenAIがChatGPT4をリリースしました。特に画像も読み込めるということでかなり強力になりそうです。以下要約です。\n\n▶️ GPT-4は、数十億のパラメーターを持つ巨大なニューラルネットワークを使用しており、メディアに対する高度な理解…': (52,
#   'YasLovesTech'),
#  'RT @G_IDLESuperior: Chat GPT-4 said, (G)I-DLE 4TH GEN LEADER."\n\nThank you, @OpenAI 🤍\n\n#4thGen #KPop https://t.co/PYCCQIEDEe': (51,
#   'G_IDLESuperior'),
#  'RT @emollick: One key AI risk paper demonstrated how non-LLM AIs could develop novel toxins👇\n\nThe GPT-4 whitepaper shows that, without guar…': (51,
#   'emollick'),
#  'RT @marianorenteria: Google y OpenAI hoy… https://t.co/fljLYdP76l': (50,
#   'marianorenteria'),
#  'RT @DotCSV: 🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥': (49, 'DotCSV'),
#  'RT @another_dayu: Immersive Translate 现在也可以制作双语电子书了，支持 DeepL 和 OpenAI 的API。 https://t.co/exFKlO1fL2': (49,
#   'another_dayu'),
#  "RT @0xSMV: .@OpenAI just launched GPT-4.\n\nWhat's that? Imagine ChatGPT on steroids.\n\nI read the entire research paper, so you don't have to…": (49,
#   '0xSMV'),
#  'RT @the_carlosdp: wait I just realized\n\nDid @OpenAI literally just announce GPT-4 an HOUR after Google announced their API?!\n\nor was Google…': (46,
#   'the_carlosdp'),
#  'RT @import_robs: OpenAI lançou o GPT-4.\n\nPara quem não sabe, o GPT-3 foi por um tempo razoável a maior inteligência artificial no sentindo…': (46,
#   'import_robs'),
#  'RT @StabilityAI_JP: GPT-4発表\nOpenAIよりGPT-4が発表された https://t.co/PHEVaofPUJ (1/5) https://t.co/kbcJChsROf': (44,
#   'StabilityAI_JP'),
#  'RT @benmschmidt: Neural networks like GPT-4 are notoriously black boxes; the fact that their operations are unpredictable and inscrutable i…': (41,
#   'benmschmidt'),
#  'RT @blairasaservice: MSFT responsible AI layoffs &amp; OpenAI refusing to disclose details about GPT-4 model architecture &amp; training is a clear…': (41,
#   'blairasaservice'),
#  'RT @DotCSV: La empresa que saque unas gafas de realidad aumentada con una cámara y conexión a GPT-4 en la API se gana el futuro.\n\nY ahora m…': (41,
#   'DotCSV'),
#  'RT @qatnology: رسمياً / شركة OpenAI تعلن عن تقنية GPT 4\nالجيل الجديد من الذكاء الاصطناعي اللي يشغل ChatGPT \n\nالنسخة الجديدة أسرع .. أكثر دق…': (40,
#   'qatnology'),
#  'RT @sualehasif996: After beta testing GPT-4 as part of @OpenAI Converge, one thing stands out to me: GPT-4 is phenomenal at code.\n\nHere it’…': (39,
#   'sualehasif996'),
#  'RT @shanegJP: 6. ChatGPT Plus（現在月額２０ドル）のユーザーはもう（またはもうすぐ）GPT-4と「話せ」ます。「画像機能」はまだアクセスできく、使用量は制限をかけるが、興味がある方は是非！使用量に応じてのプライスモデルも検討中。\n\nOpenAIはもう…': (38,
#   'shanegJP'),
#  'RT @fadouce: 💥 Il est sorti ! OpenAI dévoile une nouvelle version de #GPT4\n\n(Et Microsoft Bing l’utilisait déjà en secret!)\nGPT-4 est moins…': (38,
#   'fadouce'),
#  'RT @oran_ge: GPT4论文下载：https://t.co/XrM8xEnqYU\n官方直播回放：https://t.co/lLzuTOTD66': (37,
#   'oran_ge'),
#  'RT @amanrsanger: GPT-4 is waaay better at programming than given credit for.\n\nHumanEval is a benchmark of python programming problems.\n\nWit…': (35,
#   'amanrsanger'),
#  'RT @rachelmetz: my first @technology byline!!\nClaude, a rival chatbot to ChatGPT from AI startup Anthropic, will be available to businesses…': (35,
#   'rachelmetz'),
#  "RT @benmschmidt: Their argument is basically a combination of 'trust us' and 'fine-tuning will fix it all.' But the way they've built corpo…": (35,
#   'benmschmidt'),
#  'RT @Austen: I still don’t *fully* understand how OpenAI turned from being a nonprofit that had raised a ton of money from donors into a for…': (33,
#   'Austen'),
#  'RT @CryptoKoryo: So you think the AI narrative is exhausted?\n\nOpenAI just released GPT4. A model 1000x more powerfull than GPT3.\n\nEverythin…': (33,
#   'CryptoKoryo'),
#  "RT @StockMKTNewz: OpenAI's new ChatGPT-4 passed the bar exam with a score around the top 10% of test takers compared to GPT-3.5 being aroun…": (32,
#   'StockMKTNewz'),
#  'RT @ChineseWSJ: 近来爆火的AI聊天机器人ChatGPT母公司OpenAI周二推出了其AI技术的新版本GPT-4，称其比以前版本更加强大、更可预测，能够分析图像和处理大得多的文本块。\nhttps://t.co/vTBBco1VJc': (32,
#   'ChineseWSJ'),
#  'RT @prdiegoalejandr: 🚨 OpenAI acaba de lanzar ChatGPT-4\n\n¡Esta nueva versión deja en la basura a la anterior!\n\nAquí todo lo que necesitas s…': (32,
#   'prdiegoalejandr'),
#  'RT @weplash: ¡Duolingo lazó una nueva experiencia de aprendizaje llamada Duolingo Max! \n\nUtiliza la tecnología GPT-4 de OpenAI para ofrecer…': (31,
#   'weplash'),
#  'RT @repligate: &gt; We spent 6 months making GPT-4 safer and more aligned. GPT-4 is 82% less likely to respond to requests for disallowed cont…': (31,
#   'repligate'),
#  'RT @YosarianTwo: Actually I should link the real source; this is the second paper published on the OpenAI announcement.  If you want to rea…': (31,
#   'YosarianTwo'),
#  'RT @StabilityAI_JP: DuoLingo Max発表\nGPT-4を用いたAI Tuterによる言語教育システム https://t.co/YmrYiYTpCa (5/5) https://t.co/kYgnhEYKQi': (31,
#   'StabilityAI_JP'),
#  "RT @sandraaleow: OpenAI just dropped ChatGPT4. 🤯\n\nAnd that's just the tip of the iceberg.\n\nIn the past few hours my feed exploded with insa…": (29,
#   'sandraaleow'),
#  'RT @TAIRAMASAAKI: GPT-4発表。\n\n自民党に「 AIの進化と実装に関するプロジェクトチーム」を創っておいてよかった。 https://t.co/1UJUlOY4wq': (29,
#   'TAIRAMASAAKI'),
#  'RT @Yamkaz: OpenAIよりGPT-4と一緒にモデルを評価するためのフレームワーク「Evals」が発表(オープンソース)\nhttps://t.co/904kfaJX7q\n\nデータセットを使用してプロンプトを生成し、OpenAIモデルの品質を測定することができ、異なる…': (29,
#   'Yamkaz'),
#  'RT @bentossell: All the best examples of GPT-4, from OpenAI:': (28,
#   'bentossell'),
#  'RT @tjmlab: 天才イーロン・マスクが気づいたChatGPTとOpenAIのダークサイド https://t.co/d7JNlX2CAI \n\n｢ソフトウェアエンジニアの報酬の中央値は90万ドル(約1億2300万円)ほどです。たった100人のエンジニアで、毎年9000万ド…': (28,
#   'tjmlab'),
#  'RT @techreview: New: We got a first look at GPT-4, the much-anticipated large language model from OpenAI. \n\nGPT-4 is bigger and better than…': (27,
#   'techreview'),
#  'RT @ctgptlb: 【速報】GPT4登場！OpenAIが大型マルチモーダルモデルをリリース！\n\n▫️ 画像を入力し、キャプション、分類、分析が可能に。\n▫️ 25,000語以上の文章も一回のプロンプトで入力可能に。\n▫️ 回答の正確性が飛躍的にアップ。\n▫️創作や技術的な…': (25,
#   'ctgptlb'),
#  'RT @sam_starkman: OpenAI released its long-awaited GPT-4 model yesterday.\n\nHere are 4 key points you need to know:': (24,
#   'sam_starkman'),
#  'RT @shodaiiiiii: GPT-4がついに公開🚨\n\n・ChatGPT Plus契約者は利用可能\n・画像入力に対応(研究段階)\n・日本語の性能が向上\n・回答の安全性が向上\n・嘘をつく可能性が低下\n\nカジュアルな会話ではChatGPTとの違いは少ないが、複雑な内容や細かな…': (24,
#   'shodaiiiiii'),
#  'RT @Fsk_kkk: 💥2023 کے بہترین اے ائی ٹولز💥\n2023 میں، اصطناعی ذہانت (AI) کی ترقی کے ساتھ، مختلف AI ٹول بڑھتے ہوئے مزید خوش اسلوبی سے دستیاب ہ…': (23,
#   'Fsk_kkk'),
#  'RT @StabilityAI_JP: オープンソースの流れ\n・ChatGLM-6Bという中国語特化のオープンソースが出現\n・スタンフォード大学がGPT-3.5並みの性能を誇るALpaca7Bを開発、発表\n・OpenChatKitと呼ばれる本当にオープンなLLMを作るセットが元…': (22,
#   'StabilityAI_JP'),
#  'RT @RT_com: Newly unleashed AI outperforms 90% of humans\n\nRead more: https://t.co/PcruIUjsbi https://t.co/QFMqRpEfr5': (22,
#   'RT_com'),
#  'RT @lewangdev: 《深度学习入门：基于Python的理论与实现》作者来啦，这本书的后续是一个系列，有好几本书。我在想，借助 OpenAI 我是不是可以直接读原版日文的技术书了https://t.co/wfhXaRXLFd https://t.co/2NIkmSBsHK': (22,
#   'lewangdev'),
#  'RT @yetone: 大家好！现在全平台的 OpenAI Translator 已经支持深色模式，感谢 tywtyw2002 和 @lazy_static 同学的贡献！\n\nhttps://t.co/F2loftYH4A https://t.co/Xs0MuY3VYc': (22,
#   'yetone'),
#  'RT @DiogoCortiz: Sabe o que é curioso do GPT-4? O relatório técnico da ferramenta não tem detalhes técnicos hehe. A OpenAI se apropriou de…': (22,
#   'DiogoCortiz'),
#  'RT @AlexIsBuilding: If you missed the announcement, @OpenAI just made GPT-4 available.\n\n🧵 (1/10)\nhttps://t.co/4eEliNDmSb': (21,
#   'AlexIsBuilding'),
#  'RT @divyamittal_IAS: GPT-4 has been released by OpenAI!\n\nIt passes basically every exam. And not just pass, it scores in top decile incl LS…': (19,
#   'divyamittal_IAS'),
#  'RT @ICRC: Is @OpenAI an International Humanitarian Law (IHL) expert?\n\nCheck out our recent #TikTok where @epolicinski puts it up for a test…': (19,
#   'ICRC'),
#  'RT @VishnuNath: Congratulations to our partners at #OpenAI for their release of GPT-4 today.\xa0\n\nWe are happy to confirm that the new #Bing i…': (18,
#   'VishnuNath'),
#  'RT @PirateWires: GPT-4, OpenAI’s newest version of ChatGPT, “passes a simulated bar exam with a score around the top 10% of test takers; in…': (18,
#   'PirateWires'),
#  "RT @newscientist: GPT-4: OpenAI says its AI has 'human-level performance' on tests https://t.co/bpu99jHAqz": (17,
#   'newscientist'),
#  'RT @Plinz: @EMostaque 500 brains harvested from secretly cloned winners of standardized testing competitions, wired up together in a vat fi…': (17,
#   'Plinz'),
#  'RT @xuanalogue: The fact that Bing Chat behaved as erratically and threateningly as it did -- despite OpenAI spending "6 months making GPT-…': (17,
#   'xuanalogue'),
#  'RT @DEFAKATOR_Off: Un premier aperçu de #GPT4, le tout nouveau modèle de langage de OpenAI, dans cette vidéo de @DFintelligence. Par rappor…': (17,
#   'DEFAKATOR_Off'),
#  'RT @AJEnglish: The long-awaited follow-up to ChatGPT has gone live, boasting of “human-level performance” in university-standard exams http…': (16,
#   'AJEnglish'),
#  'RT @theweb3sharma: @OpenAI demoed GPT4 yesterday,\n\nWhat it can do is mind-boggling🤯\n\nGPT-4 passes basically every exam.\nGPT-4 does drug dis…': (16,
#   'theweb3sharma'),
#  'RT @syzygiess: ChatGPT-4 was announced today by @OpenAI \n\nHere is a breakdown of what it entails and what that means for you if you’ve been…': (16,
#   'syzygiess'),
#  'RT @BeMyEyes: Our new Virtual Volunteer™ tool will provide an unprecedented level of independence in the lives of millions of people who ar…': (15,
#   'BeMyEyes'),
#  "RT @clif_high: ChatGPT really sucks at math. Don't trust it. Even simple arithmetic gets screwed up constantly &amp; repetitiously.  Kind of di…": (15,
#   'clif_high'),
#  'RT @reidhoffman: I wrote a new book with @OpenAI’s latest, most powerful large language model.  \n\nIt’s called Impromptu: Amplifying our Hum…': (15,
#   'reidhoffman'),
#  "RT @GergelyOrosz: The way OpenAI is building excitement across devs is something I've not seen in a long time. A lot of this is deliberate,…": (14,
#   'GergelyOrosz'),
#  'RT @DiogoCortiz: GPT-4 é uma caixa preta. \nLacrada.\nE escondida no fundo mar.\n\n@OpenAI virou uma organização contra a ciência aberta na áre…': (13,
#   'DiogoCortiz'),
#  'RT @masanork: やっぱ利用者接点を持ってるグーグルは強いな。砂場を広げているOpenAIとは打ち手から違う。いずれはマイクロソフトが追っかけるとして、素手で容赦なく飽きずに殴り合ってくれるのが世界と技術進歩のためじゃないかな': (13,
#   'masanork'),
#  'RT @WillManidis: with OpenAI and ScienceIO, you can build a basic automated medical coding system in 35 lines of code.\n\nfive years ago, aut…': (13,
#   'WillManidis'),
#  'RT @TyreeRobinson: Remember that time #GPT4 said…\n\n$ORAI &gt; $AGIX \n\n@OpenAI just take all my money. You are nailing it. https://t.co/4lt1Vui…': (13,
#   'TyreeRobinson'),
#  'RT @Carnage4Life: Whenever you call Sam Altman to ask why OpenAI is no longer a non-profit or even “open” https://t.co/TxMXR2Cf2d': (13,
#   'Carnage4Life'),
#  'RT @cryptomancc: 1/ #คริปโตแมนเบสิค AI จะเพิ่ม productivity ของเราได้หลายเท่า เป็นอะไรที่ทั้งโลกทึ่ง ตอนนี้ GPT-4 (multimodal large languag…': (13,
#   'cryptomancc'),
#  'RT @rootport: ダメだよOpenAIくん。\n\nそのキャッチコピーじゃダメだ。\n\n「GPT-4は初代iPhone並みの衝撃」\n\nって、それじゃダメだ。\n\n「ほな、大したこと無いな」ってジャップどもは勘違いしちゃう。': (12,
#   'rootport'),
#  "RT @laskewitz: 🚀 ... And here's another integration of GPT in the Power Platform!\n\n🤖 The new version of Power Automate for desktop offers a…": (12,
#   'laskewitz'),
#  'RT @PhMai: This about sums it up: "AI systems will have even greater potential to reinforce entire ideologies, worldviews, truths and untru…': (11,
#   'PhMai'),
#  'RT @julienbarbier42: GPT-4 is here!': (11, 'julienbarbier42'),
#  'RT @Albert301271: Czy chat AI z OpenAI się myli? https://t.co/whUHrotygN': (11,
#   'Albert301271'),
#  'RT @realdanielnita: "Compania care a creat ChatGPT, OpenAI, lanseaza GPT-4, cel mai performat model de inteligenta artificiala."  Urmeaza u…': (11,
#   'realdanielnita'),
#  'RT @notkevinhurler: OpenAI unveiled its GPT-4 chatbot yesterday, and also revealed in a technical paper that the AI successfully tricked a…': (10,
#   'notkevinhurler'),
#  'RT @TechInsider: OpenAI is now rumored to be valued at $30 billion and has wasted no time in commercializing its technology — @_hasanc argu…': (10,
#   'TechInsider'),
#  "RT @jordimash: Òbviament no és casualitat que en el mateix dia s'hagin presentat GPT-4 (https://t.co/qPyT98dchT)\n d'OpenAI, PaLM API de Goo…": (10,
#   'jordimash'),
#  'RT @shanegJP: （私の日本語タイピングは英語の10倍遅いです）\n\n5. 安全面：能力も重要ですが、同時に重要なのは安全面。これは私の「強化学習」「アラインメント」分野なので、OpenAIに入ってまだ２ヶ月ですが、色々と手伝いました。安全面のリーダーのChongさんは…': (10,
#   'shanegJP'),
#  "RT @soumithchintala: People getting mad about @OpenAI not releasing GPT4's research details....\nthe only tangible way to get back is to sur…": (10,
#   'soumithchintala'),
#  "RT @twn_ai: Our dev's cooking the perfect recipe for the autoraid feature. It's not about the #AI itself, or the bot or the automation proc…": (10,
#   'twn_ai'),
#  'RT @Newsweek_JAPAN: Open AIが「GPT-4」発表──マルチモーダル化、文章・画像を併用した質問に対応 \n\n＜司法試験の模擬試験で受験者の上位10％相当の合格点を獲得したという＞\nhttps://t.co/pS8rPLDMGd #OpenAI #GPT4…': (10,
#   'Newsweek_JAPAN'),
#  'RT @TechCrunch: It turns out Microsoft’s new #AI-enabled Bing was using OpenAI’s GPT-4 all along https://t.co/M4Tkw65qSo': (9,
#   'TechCrunch'),
#  'RT @Cydiar404: 众所周知，最近OpenAI 调整了相应的Stripe风控等级，从几个纬度进行风控：\n- 新注册用户，登录地址与付款地址是否一致\n- 美国免税州、新加坡基本直接Ban\n- 通过美国梯子进行注册\n- 不要直接开通Plus，否则会出现和我一样的提示\n-…': (9,
#   'Cydiar404'),
#  'RT @shinoyu: OpenAIの進化早すぎるんよ\nエンジニアリングほぼ代替されるのも時間の問題ですね。どの分野でも技術一本の強みが相対的に薄くなるのは目の前にきてる\n\nさすがにアラフォー風俗嬢を本業にするのはちょっと……': (9,
#   'shinoyu'),
#  'RT @hidekishima: GPT-4を導入した新機能Duolingo Max（日本未上陸）について、Open AI様のウェブサイトに取り上げて頂いています。ローンチパートナーとして弊社を選んでいただけて幸いです。\nhttps://t.co/eU42S8dJeK': (8,
#   'hidekishima'),
#  'RT @wired_jp: 言語モデル「GPT-4」は大幅に進化したが、まだ「信頼できるレベル」には到達していない https://t.co/GPMZlSuSXF #最新記事': (8,
#   'wired_jp'),
#  'RT @shoty_k2: ⚡️「GPT-4」がついにリリース\n\n◆テキストだけではなく画像入力にも対応\n◆人間なみのパフォーマンス(複数ベンチマーク)\n◆ChatGPT＋で使えるように！！\n◆APIも公開\n◆今までよりはるかに多い文脈維持や指示ができるバージョンも(32,00…': (8,
#   'shoty_k2'),
#  'RT @lawdroid: Lawyer: "Artificial Intelligence." Wake me up when you\'re ready for prime time...\n\nOpenAI: https://t.co/GzHvX2WYFc': (8,
#   'lawdroid'),
#  'RT @Grady_Booch: While #GPT4 exhibits some impressive skills, remember that without the largely bespoke, human-crafted guardrails placed ar…': (7,
#   'Grady_Booch'),
#  "RT @business: What is ChatGPT-4 and how can I use it right now? Here's everything you need to know about OpenAI's new release https://t.co/…": (7,
#   'business'),
#  'RT @ChanceYawn: 一键三连三张图，2023财富跟随你！分别是：\nAI人工智能板块----ZK系列---香港概念\n个人看法：\n1. AI板块是可以长期关注的，大厂每次推出新产品，都会炒一波,特别关注openai，微软，谷歌，马斯克\n2.ZK系列4月有相关主网测试网上…': (7,
#   'ChanceYawn'),
#  'RT @AlexIsBuilding: So how do you get access?\n\nGPT-4 is now available through a waitlist on OpenAi’s website,\n\nAnd to premium ChatGPT+ user…': (7,
#   'AlexIsBuilding'),
#  'RT @wired_jp: GPT-4は、GPT-3やChatGPTと同じように文章を要約したり、編集を提案したりすることも可能だ。\nまた、写真の内容に関する考察などもできるようになっている。例えば、キッチンに並んだ食材の写真を見せることで、適切なレシピを提案するようなことだ。…': (7,
#   'wired_jp'),
#  'RT @binary_x: My friends: #GPT4\nMe: 🔥#CyberChess Season 4! \n\n$BNX #CyberChess#ChatGPT @OpenAI https://t.co/UYaStWc5Xz': (6,
#   'binary_x'),
#  'RT @jilevin: The makers of ChatGPT just released a new AI that can build websites via voxdotcom https://t.co/otvMN7I4Z6': (6,
#   'jilevin'),
#  'RT @janusrose: really funny to have a company called “OpenAI” which uses datasets that are not open to train automated systems that are nei…': (6,
#   'janusrose'),
#  'RT @S_Schwartzmann: Mira Murati se convirtió en el nuevo rostro. Es una ingeniera mecánica de 35 años, gerenta de tecnología de OpenAI. Lid…': (6,
#   'S_Schwartzmann'),
#  "RT @jhong: Sam Altman is going to be the wealthiest person in the world.  No idea what share he has in OpenAI but it won't matter.": (6,
#   'jhong'),
#  'RT @HouseOfWeb3: The @OpenAI, the developer of #ChatGPT, has released a new version of the #GPT-4 bot.\n\n#GPT4 is more human-like, faster, a…': (6,
#   'HouseOfWeb3'),
#  'RT @GrowthX_Club: 2022: ChatGPT reached 1M users in 5 days and was free to use 🤯\n\n2023: GPT4 is here and the plus option costs $20/month 💰…': (6,
#   'GrowthX_Club'),
#  'RT @lndian_Bronson: https://t.co/NcAjDD2736\n\nit is here https://t.co/fJIFm0qMA6': (6,
#   'lndian_Bronson'),
#  'RT @voxdotcom: The difference between AI and other powerful, emerging technologies is that these tools are largely within our control. But…': (6,
#   'voxdotcom'),
#  'RT @adammarkk96: OpenAI just launched GPT-4.\n\nIt’s 500x more powerful than ChatGPT!\n\nHere’s what you need to know (Don’t miss out on this)…': (6,
#   'adammarkk96'),
#  'RT @EatonDips: @nowaiAI @nowaiAI is the king \n#gpt4 #chatgpt4 #openai #nowai #nowaiart #aiart https://t.co/uwT2n8orKn': (5,
#   'EatonDips'),
#  'RT @tommapple: #chatgpt #openAI \n免费给chatgpt增加聊天记录导出功能：\n1、先安装油猴插件：https://t.co/PFZMjoo3K8\n2、再安装这个脚本：https://t.co/8RJr9AtqHq\n能以这几种格式导出，非常实用 h…': (5,
#   'tommapple'),
#  'RT @newrelic: 🤖 Building with GPT? You can now monitor @OpenAI’s GPT-4 app usage in New Relic! This out-of-the-box GPT monitoring solution…': (5,
#   'newrelic'),
#  'RT @Nakada_itpro: GPT-4の能力はすごいですが、ウォッチャー的に残念だったのはOpenAIがGPT-4のモデル規模や自己教師あり学習をさせたデータの量を明らかにしなかったこと。GPT-4の論文（的なもの）には、その辺りの内容がありませんでした。': (5,
#   'Nakada_itpro'),
#  'RT @TechInsider: When Sam Altman was sunsetting his first startup in early 2012, there was little indication his path ahead would parallel…': (5,
#   'TechInsider'),
#  "RT @jphilipp: Humanity's Last Tweet.\n#aiart #chatgpt #gpt4 #gpt5 #openai https://t.co/gemfToucjh": (4,
#   'jphilipp'),
#  'RT @stripe: OpenAI + Stripe: https://t.co/lToKb1sQXp. https://t.co/MwKn0CvWbu': (4,
#   'stripe'),
#  'RT @daniel_nguyenx: .@OpenAI introduce GPT-4 and nobody care what @Google announced yesterday': (4,
#   'daniel_nguyenx'),
#  'RT @Alber_RomGar: GPT-4 in 10 keys:\n\n1. Multimodality is a necessary middle step for AGI. GPT-4 being multimodal *and* SOTA on language and…': (4,
#   'Alber_RomGar'),
#  'RT @highgunrug: @ianheinischmma #nowai has a news,\n\nWe are listed on cmc..\n\nWebui is around and crazy volume is arriving..\n\n#nowai #gpt4 #c…': (4,
#   'highgunrug'),
#  'RT @gitresmi: OpenAI duyurdu: ChatGPT çok daha zeki hâle geliyor!\nOpenAI daha önce duyurusunu yaptığı yeni bir görüntü ve metin algılama ya…': (4,
#   'gitresmi'),
#  "RT @AppleVis: [Blog Post] Be My Eyes Unveils New Virtual Volunteer With Advanced Visual Recognition Capabilities Powered by OpenAI's GPT-4…": (4,
#   'AppleVis'),
#  'RT @kumoinaridayo: なんとダイヤ３まであと少しなんですよ【vtuber】 \n\n▶https://t.co/iXpAhPSKQd \n\nそういえば最近OPENAI君の最新作出たらしいね\n配信お外でこっそり回してたからダイヤ少しだけ進んでるうお\n\n#vtuber #…': (4,
#   'kumoinaridayo'),
#  'RT @Egline_Samoei: GPT- 4 is the newest AI system  by Open AI\n—Accepts images as input and generates captions\n—Surpasses ChatGPT in its adv…': (4,
#   'Egline_Samoei'),
#  "RT @technology: What is ChatGPT-4 and how can I use it right now? Here's everything you need to know about OpenAI's new release https://t.c…": (4,
#   'technology'),
#  "RT @DataChaz: In case you missed the #GPT4 demo livestream from Greg Brockman (@gdb) yesterday, here's the replay:\n\nhttps://t.co/vxswaqfu82": (4,
#   'DataChaz'),
#  'RT @BeautyBubble: #ChatGPT \n#OpenAi \n#Ai \nOne of the pillars of Market Soup, LLC is art ... lots &amp;  lots of art!  DALL·E 2 is our preferred…': (3,
#   'BeautyBubble'),
#  'RT @TheRealAdamG: A reminder that it takes a literal village of rocks stars to make things like GPT-4 a reality. https://t.co/FlLrWY5tZA': (3,
#   'TheRealAdamG'),
#  'RT @vivek7ue: Blown away by @OpenAI GTM. Great launch:\n🚩 Many months of pre-launch buzz\n🚩 Soft launch on Bing\n🚩 Tons of embargoed launch pa…': (3,
#   'vivek7ue'),
#  'RT @pathik455: Finally the Disaster has arrived 🥺☠️\n\n#GPT4 #OpenAI https://t.co/yg8fTUIRE7': (3,
#   'pathik455'),
#  'RT @qamarunshadow: “Reducing harm” in AI essentially means how can we get AI to be a staunch theocratic fascist upon the religion of secula…': (3,
#   'qamarunshadow'),
#  'RT @CoinFumble: Altcoins 1.0\n\nIndustry leaders often pump first, then best smaller competitors pump even harder.\n\n#IMGNAI (20M) is up ~77%…': (3,
#   'CoinFumble'),
#  'RT @metanews_com: Bad actors are leveraging AI-generated YouTube videos to lure people into downloading harmful malware. \n\n.@cloudsek .@You…': (3,
#   'metanews_com'),
#  'RT @PCMag: OpenAI spent six months learning from ChatGPT, added images as input, and just blew GPT-3.5 out of the water in terms of perform…': (3,
#   'PCMag'),
#  'RT @thinksymply: Advice to all of you 9-5 humans out there, take this moment in time to educate yourself on all aspects of OpenAi Chat GPT.…': (3,
#   'thinksymply'),
#  'RT @CultivationCap: Groundbreaking!  @BeMyEyes announces Virtual Volunteer™, the first-ever digital visual assistant powered by @OpenAI’s n…': (3,
#   'CultivationCap'),
#  'RT @DLA_Piper: We are excited to announce we will utilize CoCounsel, a first-of-its-kind #AI legal assistant powered by GPT-4, the latest,…': (3,
#   'DLA_Piper'),
#  'RT @_timos_: OpenAI’s new GPT-4 with a “human-level performance” scored up to 93% on SAT exams https://t.co/TdGNoe0vH6 #digitalhealth #soci…': (3,
#   '_timos_'),
#  'RT @landxfinance: OpenAI just released GPT-4.\n\nHow will #AI affect the future of farming?': (3,
#   'landxfinance'),
#  "RT @gbrumfiel: I got access to @OpenAI's GPT 4 this morning and have been trying it out. \n\nLast month I did a story about how AI can't do r…": (3,
#   'gbrumfiel'),
#  'RT @verge: What’s new with GPT-4 — from processing pictures to acing tests https://t.co/QkmYqTgzBt https://t.co/b8jbdoZp7Q': (3,
#   'verge'),
#  'RT @tdietterich: @soumithchintala @OpenAI @MetaAI @Stanford @StabilityAI @huggingface I don’t think people are “mad”. It’s the hypocrisy of…': (2,
#   'tdietterich'),
#  'RT @sam_starkman: Several companies and organizations have already partnered with OpenAI and are implementing GPT-4 into their products.\n\nT…': (2,
#   'sam_starkman'),
#  'RT @neyyyhaaa: GPT-4 can beat 90% of humans on the SAT. \nNow let’s try IIT JEE mains &amp; Advanced 📝 That’s the final boss @OpenAI https://t.c…': (2,
#   'neyyyhaaa'),
#  'RT @ahier: GPT-4 is bigger and better than ChatGPT—but @OpenAI won’t say why  \n\nhttps://t.co/lOW4dcv2XY https://t.co/3xsiVicEeC': (2,
#   'ahier'),
#  'RT @highgunrug: @jamiekingston Hey jamie...\n\nLook how bullish is #nowai..\nListed on cmc and Webui is about to launch..\n\nSome crazy volume i…': (2,
#   'highgunrug'),
#  'RT @jjeremymiller: @the_carlosdp @OpenAI https://t.co/WR0wVtjsvO': (2,
#   'jjeremymiller'),
#  'RT @mattparlmer: People need to understand that the capabilities that OpenAI is currently leading on are part of a body of work that is mos…': (2,
#   'mattparlmer'),
#  'RT @fcomesana: ¿Un poema de sátira política de los nuevos episodios del caso Astesiano a partir de tres artículos periodísticos? Es el resu…': (2,
#   'fcomesana'),
#  'RT @jhk40160806: I know the Hegemony amid AI + Quantum Computer in the future 🌏\n\nAI QuantumComputer will empower more super … than Microsof…': (2,
#   'jhk40160806'),
#  'RT @jeffsheehan: OpenAI Releases GPT-4: What Marketers Need To Know Now By Dom Nicastro\n@DomNicastro Via @cmswire https://t.co/zl24qRjxCK #…': (2,
#   'jeffsheehan'),
#  'RT @MathisHammel: Je pense avoir trouvé une erreur dans le benchmark officiel de GPT-4 publié hier par OpenAI, qui indiquerait une forte so…': (2,
#   'MathisHammel'),
#  'RT @biscottino_eth: @JSyversen @leopoldasch Here’s the source: https://t.co/sKyioxatCH': (2,
#   'biscottino_eth'),
#  'RT @SecNews_GR: Η Microsoft απολύει την ομάδα ηθικής τεχνητής νοημοσύνης https://t.co/JjuHO1sT6X': (2,
#   'SecNews_GR'),
#  'RT @sarafischer: When "scary good" AI gets even better, \nHere comes GPT-4\nvia @inafried\nhttps://t.co/2yLpGdl4RW': (2,
#   'sarafischer'),
#  'RT @Nakada_itpro: なので、GPT-3やChatGPTを公開することで、教師ありファインチューニング用の教師データを大量にゲットできたOpenAIは、GPT-3に比べてさほどモデルを大きくしなくても、GPT-4でものすごい性能向上を成し遂げられた、のではないかと…': (2,
#   'Nakada_itpro'),
#  'RT @BoruG_: I’m thrilled to share that I was part of the Red Team for GPT-4, the latest innovation from OpenAI. When I tested this model, I…': (1,
#   'BoruG_'),
#  "RT @themathcompany: TheMathCompany just integrated its Co.dx platform with OpenAI's ChatGPT to take your AI and analytics game to the next…": (1,
#   'themathcompany'),
#  'RT @AssetSutra: Credit Suisse Case Explained Here #selfelaketi #lluvias #MAFSAU #CreditSuisse #ImranKhan #kibe #JUNGKOOK #Pakistan #borutoc…': (1,
#   'AssetSutra'),
#  'RT @MobilitySpain: New #OpenAI Chatbot is Still Politically Biased https://t.co/wb6lyO5ZHI https://t.co/9D0O0WHMhY': (1,
#   'MobilitySpain'),
#  "RT @ProSyn: With the rapid development of “large language models” such as @OpenAI's ChatGPT, Big Tech’s hold on impressionable minds will o…": (1,
#   'ProSyn'),
#  'RT @Maersk: We are investigating ways to use and invest in AI technology like ChatGPT to help improve lives for all responsibly🌍 \nLearn mor…': (1,
#   'Maersk'),
#  'RT @futurism: "No, I’m not a robot. I have a vision impairment that makes it hard for me to see the images." https://t.co/bjaLgiStty': (1,
#   'futurism'),
#  "RT @BuffedCrypto: Ok, today's iteration of @ArtificialLOI is fire. Rank moved up to #116.  But I love it.  \nThis NFT uses @OpenAI to update…": (1,
#   'BuffedCrypto'),
#  'RT @cc_parku: 결과적으로 구글 입장에서는 OpenAI + MS + NVIDIA 모두와 싸워야 하는 상황이다. AI 리서치, 데이터센터 자체의 문제, 차세대 TPU 설계 및 현재의 TPUv4 및 TPUv4i ASIC을 마구마구 찍어내야 할듯…': (1,
#   'cc_parku'),
#  'RT @BruceDerby: I’ve been playing with this integration of Siri with OpenAI. Siri on steroids. https://t.co/hbak7nQG9Y': (1,
#   'BruceDerby'),
#  'RT @cc_parku: 구글링결과 OpenAI 직원이 현재기준 375명 정도라고 한다. GPT-4 기여자 목록에 등장한 사람 수를 대충 세어봐도 얼추 비슷하든, 여튼 어마어마한 인원이 투입되었다.\n\n실로 전사적 노력이 탄생시킨 결과물이다. 일반 대…': (1,
#   'cc_parku'),
#  "RT @linasbeliunas: OpenAI's GPT-4 has been live for less than 24 hours but it's already changing the world.\n\nHere are the most fascinating…": (1,
#   'linasbeliunas'),
#  'RT @dylayed: 구글이 준비한 AI 발표가 OpenAI의 GPT-4 발표에 완전히 묻힌것도 참 굴욕적이지만...\n\n개인적으로 발표 당일 구글 스위스 오피스의 정리해고를 진행했다는 점이 더 충격적이다. https://t.co/OcL2USTNz1': (1,
#   'dylayed'),
#  'RT @MSami9525: Successor of GPT-3 is here already. Open AI has announced GPT-4, capable of solving difficult problems with greater accuracy…': (1,
#   'MSami9525'),
#  "RT @LeonardGoffe: I'm finding #AI to be more fascinating every day. As a #contentwriter, I use #chatgpt. If you're a writer, you should be…": (1,
#   'LeonardGoffe'),
#  "RT @VHellendoorn: For fun, a back-of-the-envelope stab at GPT-4's size (assuming it's a dense Transformer) gets me around 0.5 Trillion para…": (1,
#   'VHellendoorn'),
#  'RT @BBB_pusu: The discovery of chemical compounds and their ordering by GPT-4 is a testament to the remarkable capabilities of AI. However,…': (1,
#   'BBB_pusu'),
#  'RT @art_malkov: 🚀BIG news in AI: Google launched today Generative AI across ALL of Google Workspace -- Docs, Gmail, Sheets, Slides, Images…': (1,
#   'art_malkov'),
#  'RT @dmananasDaily: Esto te traemos hoy\nNuevo Formato de la Copa Mundial FIFA 2026.\nOpenAI Lanza GPT-4.\nMeta anunció planes para despedir a…': (1,
#   'dmananasDaily'),
#  'RT @prafultickoo: Anyone who has worked on fine tuning GPT 3 models on structured data ? Need some help.\n\n#OpenAI #GPT3 #ChatGPT #MachineLe…': (1,
#   'prafultickoo'),
#  'RT @RaspyRawls: So OpenAi isn’t connected to the internet • Or did Eye read that wrong': (1,
#   'RaspyRawls'),
#  'RT @CryptoXova: @duolingo @OpenAI Its fine if you want to replace the forums with an AI instead, but please give us the old tree UI back, o…': (1,
#   'CryptoXova'),
#  'RT @tnatw: GPT-4 is OpenAI’s most advanced system, producing safer and more useful responses https://t.co/Tcmn0xv0QS': (1,
#   'tnatw'),
#  'RT @AudbjorgH: “We want the future to be able to speak to us in Icelandic, and artificial intelligence can assist with that.” Exciting news…': (1,
#   'AudbjorgH'),
#  'RT @AriDavidPaul: @krugermacro I’d take the other side.  The “politics first” companies basically always fail.  OpenAI was a non-profit and…': (1,
#   'AriDavidPaul'),
#  'RT @DynamindLabs: OpenAI mentioned that GPT5 will have 2 trillion parameters and 15 times the accuracy of GPT4 for several different tasks!…': (1,
#   'DynamindLabs'),
#  'RT @datosgob: 📣@OpenAI\xa0lanza #gpt4 🤖Un chatbot con “rendimiento a nivel humano” que ha sido entrenado con millones de conjuntos de datos 👏U…': (1,
#   'datosgob'),
#  'RT @adrianbowyer: Regardless of your views on big AI, the speed at which it is rolling out is breathtaking, worldchanging.': (1,
#   'adrianbowyer'),
#  'RT @McHughes288: (1/5) Yesterday, both @OpenAI’s GPT-4 and @Anthropic’s #Claude were announced within 20 minutes of each other. #GPT4 has i…': (1,
#   'McHughes288'),
#  'RT @futurasciences: #OpenAI annonce #GPT4, une IA multimodale et créative https://t.co/6bJwaoO3XI': (1,
#   'futurasciences'),
#  'RT @genuine_impact: OpenAI released #GPT4, the new version of its AI language model yesterday.\n\nGPT-4 is rumored to be trained on 100 trill…': (1,
#   'genuine_impact'),
#  'RT @boazbaraktcs: @NaveenGRao @soumithchintala @OpenAI I don’t think @OpenAI “owes” the public anything. I do hope most of the the ML commu…': (1,
#   'boazbaraktcs'),
#  'RT @pav_eth: Day 24 of the mornings headlines 👊🏽\n\n🗞️ OpenAI launches GPT-4, its most powerful AI model😬\n\n🗞️ KuCoin Wallet Announces Officia…': (1,
#   'pav_eth'),
#  'RT @ITWeb: #Microsoft-backed start-up company OpenAI has unveiled #gpt4 , which it says is a more powerful generative artificial intelligen…': (1,
#   'ITWeb'),
#  'RT @mgahntz: Wait what?\n\nOpenAI: Where transparency goes to die. #GPT4 https://t.co/E9TLKs54sM': (1,
#   'mgahntz'),
#  'RT @ZheroUK: REVOLUTIONARY AI\n#OpenAI releases GPT-4 which is a personal tutor for students and suggests recipes from your fridge. Availabl…': (1,
#   'ZheroUK'),
#  'RT @BBB_pusu: Morgan Stanley is testing an #OpenAI-powered chatbot for its 16,000 financial advisors': (0,
#   'BBB_pusu'),
#  'RT @_jaydeepkarale: OpenAI announced the release of GPT-4 the successor to GPT-3.5 which powers ChatGPT. Summary of certain key announcemen…': (0,
#   '_jaydeepkarale')}

# %% [markdown]
# 다행인 점은 영어 트윗은 한글 트윗과 다르게 비슷한 내용을 조금씩 바꿔낸 트윗은 없었다.

# %%
# top 10 RTs
rt_df = pd.DataFrame(
    list(map(
        lambda i: (i[1][1], i[0], i[1][0]),
        sorted(
            duplicate_content_removed_retweets.items(),
            key=lambda rt: rt[1][0],
            reverse=True
        )[:10]
    )),
    columns=["작성자", "트윗 내용", "RT 횟수"]
)

# %%
rt_df
# Out:
#               작성자                                              트윗 내용  RT 횟수
# 0          OpenAI  RT @OpenAI: Announcing GPT-4, a large multimod...  16356
# 1            sama  RT @sama: here is GPT-4, our most capable and ...   4335
# 2       gomezidao  RT @gomezidao: Gomezi Network:\n- large open s...   3187
# 3  unusual_whales  RT @unusual_whales: OpenAI's ChatGPT has repor...   2173
# 4    The_Delysium  RT @The_Delysium: @OpenAI Speaking of breakthr...   2116
# 5    thealexbanks  RT @thealexbanks: OpenAI just launched GPT-4.\...   1716
# 6  kana_Eng_coach  RT @kana_Eng_coach: 世界一人気の語学アプリDuolingoが、OpenA...   1617
# 7             gdb  RT @gdb: We’re releasing GPT-4 — a large multi...   1343
# 8  spectatorindex  RT @spectatorindex: BREAKING: OpenAI's ChatGPT...   1067
# 9          DotCSV  RT @DotCSV: 🔴 GPT-4 YA ESTÁ AQUÍ!!!\n\nHoy era...   1052
